# %% [markdown]
# # Swarm intelligence for new materials 🧬🔬
#
# This project implements and explores a novel hybrid swarm intelligence algorithm to optimize neural network parameters for predicting material properties, specifically focusing on crystal structure energies. The approach aims to enhance the efficiency and accuracy of traditional neural network models in the field of computational materials science, aiding in the discovery and design of new materials.
#
# The core methodology is inspired by the paper "Swarm intelligence for new materials", which proposes an improved genetic algorithm (GA) by integrating Particle Swarm Optimization (PSO) and Bayesian optimization techniques.
# The main goal of the paper is to accelerate the discovery and design of new materials. The authors achieve this by creating a novel hybrid swarm intelligence algorithm (combining Genetic Algorithm, Particle Swarm, and Bayesian optimization) to optimize the parameters of neural networks, making them more efficient and accurate.
#
# The neural network is used as a high-speed predictive model to determine the stability of materials predicting the energy of crystal structures based on their local atomic environments. This predictive capability is crucial for identifying stable new materials quickly, which is essential in various applications such as electronics, energy storage, and catalysis.  It acts as a fast and low-cost replacement for expensive first-principles calculations and complex experiments, thereby speeding up the process of identifying stable new materials.

# %% [markdown]
# # Setup phase

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import heapq
import time
import skopt
import os
import shutil
import time
import numpy as np
from sklearn.model_selection import train_test_split
import torch
from torch import nn, optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
import ray

# %%
# Set the random seed for reproducibility
def setup_seed(seed):
   torch.manual_seed(seed)
   np.random.seed(seed)
   random.seed(seed)

setup_seed(38)

# %%
# defining constants
file_scale = './temp_files/scale.txt'
file_shift = './temp_files/shift.txt' 
xsfs = 2240
least_loss = 0.0001
BATCH = 8

# %% [markdown]
# ### What is Ray & Why it's Useful Here? 🚀
# Ray is a framework for running Python applications in parallel, even across multiple machines.
#
# In this project, Ray is used to speed up the optimization process.
# The PGB algorithm needs to train and evaluate many neural networks. Ray allows these evaluations to happen simultaneously on multiple CPU cores.

# %%
WORKPLACE=os.getcwd() 
os.system('ray start --head --port=8381')
ray.init()
# Out:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.9/bin/ray", line 8, in <module>
#     sys.exit(main())
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/scripts/scripts.py", line 2800, in main
#     return cli()
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/click/core.py", line 1128, in __call__
#     return self.main(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/click/core.py", line 1053, in main
#     rv = self.invoke(ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/click/core.py", line 1659, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/click/core.py", line 1395, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/click/core.py", line 754, in invoke
#     return __callback(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/autoscaler/_private/cli_logger.py", line 823, in wrapper
#     return f(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/scripts/scripts.py", line 990, in start
#     raise ConnectionError(
# ConnectionError: Ray is trying to start at 127.0.0.1:8381, but is already running at 127.0.0.1:8381. Please specify a different port using the `--port` flag of `ray start` command.
# 2025-06-12 12:22:57,499	INFO worker.py:1694 -- Connecting to existing Ray cluster at address: 127.0.0.1:8381...
# 2025-06-12 12:22:57,525	INFO worker.py:1888 -- Connected to Ray cluster.
# 2025-06-12 12:22:57,353	INFO usage_lib.py:472 -- Usage stats collection is enabled. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2025-06-12 12:22:57,353	INFO scripts.py:971 -- Local node IP: 127.0.0.1
# RayContext(dashboard_url='', python_version='3.9.8', ray_version='2.46.0', ray_commit='c3dd2ca0c2a24ddf327a213d2e936bd4eaa4ca0a')

# %% [markdown]
# ## TiO₂ – Titanium Dioxide
#
# - **Crystal Structures**: Rutile, Anatase, Brookite
# - **Properties**:
#   - White pigment in paints and cosmetics
#   - **Photocatalytic** under UV light: used in self-cleaning surfaces
#   - Also used in solar cells and water-splitting technologies

# %%
import ase
import nglview as nv

a = 4.59
c = 2.96
u = 0.305

tio2_manual = ase.Atoms(
    symbols=['Ti', 'Ti', 'O', 'O', 'O', 'O'],
    scaled_positions=[
        (0.0, 0.0, 0.0),            # Ti
        (0.5, 0.5, 0.5),            # Ti
        (u, u, 0.0),                # O
        (1.0 - u, 1.0 - u, 0.0),    # O
        (0.5 + u, 0.5 - u, 0.5),    # O
        (0.5 - u, 0.5 + u, 0.5),    # O
    ],
    cell=[[a, 0, 0], [0, a, 0], [0, 0, c]],
    pbc=True
)


view_unit_cell = nv.show_ase(tio2_manual)
view_unit_cell.add_representation('ball+stick', radius_scale=0.3, aspect_ratio=2)
view_unit_cell.add_unitcell()
view_unit_cell.center()
view_unit_cell
# Out:
# NGLWidget()

# %%
import nglview as nv

periodic_molecule = tio2_manual * (2, 2, 1)
view = nv.show_ase(periodic_molecule)
view.add_representation('ball+stick', radius_scale=0.3, aspect_ratio=2)
view.add_unitcell()
view.center()
view
# Out:
# NGLWidget()

# %%
import nglview as nv

periodic_molecule = tio2_manual * (4, 4, 3)
view = nv.show_ase(periodic_molecule)
view.add_representation('ball+stick', radius_scale=0.3, aspect_ratio=2)
view.add_unitcell()
view.center()
view
# Out:
# NGLWidget()

# %% [markdown]
# ## Inspecting the Dataset
#
# Be sure to download the dataset from the original source (see readme) and place it in the `data` directory.

# %%
import ase.io
from ase.visualize.plot import plot_atoms
import matplotlib.pyplot as plt
import nglview as nv
import random, os

random.seed(42)

# Randomly take a .xsf from the test dataset
file_to_read = './data/TiO2/raw_data/test'
file_to_read = os.path.join(file_to_read, random.choice(os.listdir(file_to_read)))
print(f"Reading structure from: {file_to_read}")
ase_atom = ase.io.read(file_to_read)

fig, ax = plt.subplots()
plot_atoms(ase_atom, ax, radii=0.5, rotation=('45x,45y,0z'))
plt.title(f"Structure from {file_to_read}")
plt.show()


# Create an interactive view from the ase object
view = nv.show_ase(ase_atom)
view.add_unitcell()
view
# Out:
# Reading structure from: ./data/TiO2/raw_data/test/structure100000002247.xsf
# NGLWidget()

# %%
import ase.io
from ase.visualize.plot import plot_atoms
import matplotlib.pyplot as plt
import nglview as nv
import random, os

random.seed(43)

# Randomly take a .xsf from the test dataset
file_to_read = './data/TiO2/raw_data/test'
file_to_read = os.path.join(file_to_read, random.choice(os.listdir(file_to_read)))
print(f"Reading structure from: {file_to_read}")
ase_atom = ase.io.read(file_to_read)

fig, ax = plt.subplots()
plot_atoms(ase_atom, ax, radii=0.5, rotation=('45x,45y,0z'))
plt.title(f"Structure from {file_to_read}")
plt.show()


# Create an interactive view from the ase object
view = nv.show_ase(ase_atom)
view.add_unitcell()
view
# Out:
# Reading structure from: ./data/TiO2/raw_data/test/structure100000033752.xsf
# NGLWidget()

# %%
import ase.io
from ase.visualize.plot import plot_atoms
import matplotlib.pyplot as plt
import nglview as nv
import random, os

random.seed(44)

# Randomly take a .xsf from the test dataset
file_to_read = './data/TiO2/raw_data/test'
file_to_read = os.path.join(file_to_read, random.choice(os.listdir(file_to_read)))
print(f"Reading structure from: {file_to_read}")
ase_atom = ase.io.read(file_to_read)

fig, ax = plt.subplots()
plot_atoms(ase_atom, ax, radii=0.5, rotation=('45x,45y,0z'))
plt.title(f"Structure from {file_to_read}")
plt.show()


# Create an interactive view from the ase object
view = nv.show_ase(ase_atom)
view.add_unitcell()
view
# Out:
# Reading structure from: ./data/TiO2/raw_data/test/structure10002385115.xsf
# NGLWidget()

# %% [markdown]
# # Data Loading

# %% [markdown]
# ### Input to the neural network: Chebyshev Polynomials
#
# **Chebyshev polynomials** are special **orthogonal polynomials** used in approximation theory and numerical methods.
#
# #### Two Main Types
#
# - **First Kind** ($T_n(x)$):
#   - Recurrence:
#     - $T_0(x) = 1$
#     - $T_1(x) = x$
#     - $T_{n+1}(x) = 2xT_n(x) - T_{n-1}(x)$
#   - Alternative definition:
#     - $T_n(x) = \cos(n \arccos(x))$
#
# - **Second Kind** ($U_n(x)$):
#   - Recurrence:
#     - $U_0(x) = 1$
#     - $U_1(x) = 2x$
#     - $U_{n+1}(x) = 2xU_n(x) - U_{n-1}(x)$
#   - Alternative definition:
#     - $U_n(x) = \dfrac{\sin((n+1)\theta)}{\sin(\theta)}$ where $x = \cos(\theta)$
#
# #### Key Properties
#
# - **Orthogonality**:
#   - $T_n(x)$ is orthogonal on $[-1, 1]$ with weight $1/\sqrt{1 - x^2}$
#   - $U_n(x)$ is orthogonal on $[-1, 1]$ with weight $\sqrt{1 - x^2}$
#
# - **Roots (Chebyshev Nodes)**:
#   - Roots of $T_n(x)$ minimize interpolation error and reduce Runge's phenomenon.
#
# - **Minimax Property**:
#   - $T_n(x)$ minimizes the maximum deviation from zero on $[-1, 1]$ among monic polynomials.
#
# - **Application in ML**:
#   - Used to describe atomic environments as inputs for neural networks in materials science.

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial import chebyshev

# Generate x values in [-1, 1]
x = np.linspace(-1, 1, 400)

# Plot first 5 Chebyshev polynomials of the first kind (T0 to T4)
plt.figure(figsize=(8, 6))
for n in range(5):
    y = chebyshev.Chebyshev.basis(n)(x)
    plt.plot(x, y, label=f'$T_{n}(x)$')

plt.title('Chebyshev Polynomials of the First Kind')
plt.xlabel('$x$')
plt.ylabel('$T_n(x)$')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def train_prepare():
    with open( './train/generate.in', 'r') as f_read:
        for i, line in enumerate(f_read):
            if i == 3:
                num_type = int(line.split()[0]) 
    if num_type == 1:
        nfeatures = 22
    else:
        nfeatures = 44
    return nfeatures,num_type

nfeatures, num_type = train_prepare()

# %%
from get_dataset import get_dataset

# Load the dataset for training
data = get_dataset('./train', '/train/trainset_with_scaled_normalized.txt', nfeatures)

print(f"Number of features: {nfeatures}, Type: {num_type}")
print("Data loaded successfully.")
# Out:
# Number of features: 44, Type: 2
# Data loaded successfully.

# %% [markdown]
# ## Distribution of data
#
# <p align="center">
#   <img src="./img/distribution.png" alt="Neural network" width="1000"/>
# </p>

# %%
samples_to_plot = 3

for i in range(samples_to_plot):
  if i < len(data):
    coeff_list = data[i][0]

    coeff_values = np.array(coeff_list, dtype=float)
    coeff_values = coeff_values.reshape(-1, nfeatures).T
    
    print(f"Plotting Sample {i}, Shape of feature values: {coeff_values.shape}")

    plt.figure(figsize=(10, 4))
    plt.plot(coeff_values, marker='o', linestyle='-')
    plt.title(f"Chebyshev Features for Sample {i}")
    plt.xlabel("Feature Index")
    plt.ylabel("Feature Value")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
  else:
    print(f"Sample index {i} is out of bounds for the loaded data (size: {len(data)}).")
    break
# Out:
# Plotting Sample 0, Shape of feature values: (44, 30)
# Plotting Sample 1, Shape of feature values: (44, 30)
# Plotting Sample 2, Shape of feature values: (44, 30)

# %% [markdown]
# # Neural Network
#
# The neural network is used to **predict the energy of crystal structures**. The goal is to build a model that can learn the relationship between a material's atomic structure and its energy. This approach aims to speed up the discovery and design of new materials.
#
# ### Core Purpose
# * The network is designed to fit the atomic energy of crystal structures, working on the principle that structures will favor lower energy states.
# * It calculates the energy for each atom in a crystal; these individual atomic energies are then summed up in the output layer to determine the total energy of the entire structure.
#
# ### Neural Network Architecture
# * The network consists of four layers:
#     * One **input layer** (which takes the Chebyshev polynomial descriptors).
#     * Two **hidden layers**.
#     * One **output layer** (which outputs the fitted atomic energy).
# * Each of the two hidden layers is composed of 10 neurons.
#
# <p align="center">
#   <img src="./img/neural_network.png" alt="Neural network" width="800"/>
# </p>

# %%
file_scale = './temp_files/scale.txt'
scale = 0
    
class NeuralNetwork(nn.Module):
    def __init__(self, nfeat, w_b = None):
        super().__init__()
        self.nfeat = nfeat
        self.types = self._load_types('./train/generate.in')
        architecture = nn.Sequential(
                    nn.Linear(self.nfeat, 10),
                    nn.Tanh(),
                    nn.Linear(10, 10),
                    nn.Tanh(),
                    nn.Linear(10, 1)
                )
        for t in self.types:
            setattr(self, f"{t}_forward", architecture)

        if w_b is not None:
            self._assign_weights(w_b)

    def _load_types(self, filepath):
        with open(filepath, 'r') as f:
            lines = f.readlines()
        num_type = int(lines[3].split()[0])
        return [lines[i].split()[0] for i in range(4, 4 + num_type)]

    def _assign_weights(self, w_b):
        for idx, module in enumerate(
            filter(lambda m: isinstance(m, nn.Linear), self.modules()), start=1
        ):
            w_key, b_key = f"w_{idx}", f"b_{idx}"
            if w_key in w_b and b_key in w_b:
                module.weight = nn.Parameter(w_b[w_key])
                module.bias = nn.Parameter(w_b[b_key])

    def forward(self, x, flag_list):
        outputs = []
        tmp_all = []

        for sample_idx in range(x.size(0)):
            tmp = []
            for feature_idx, flag in enumerate(flag_list):
                forward_name = f"{flag[sample_idx]}_forward"
                if hasattr(self, forward_name):
                    forward_func = getattr(self, forward_name)
                    tmp.append(forward_func(x[sample_idx][feature_idx]))
            tmp_all.append(len(tmp))
            outputs.append(torch.stack(tmp, 0).sum())

        out_tensor = torch.stack(outputs, 0).view(x.size(0), 1)
        return out_tensor, tmp_all

# %% [markdown]
# ## Initialization parameters of the neural network
#
# Here we initialize the parameters of the neural network such that they are compatible with our architecture. These parameters will be optimized during the training process.

# %%
def _extract_and_shape_single_network_params(popunum_block, nfeatures, key_idx_prefix):
    params = {}
    current_idx = 0

    layer_configs = [
        (10, nfeatures),  # Layer 1: nfeatures -> 10
        (10, 10),         # Layer 2: 10 -> 10
        (1, 10),          # Layer 3: 10 -> 1
    ]

    for i, (out_dim, in_dim) in enumerate(layer_configs):
        # Weights
        w_len = out_dim * in_dim
        params[f'w_{key_idx_prefix + i}'] = torch.Tensor(
            popunum_block[current_idx : current_idx + w_len]
        ).view(out_dim, in_dim)
        current_idx += w_len

        # Biases
        b_len = out_dim  # Bias has 'out_dim' elements
        params[f'b_{key_idx_prefix + i}'] = torch.Tensor(
            popunum_block[current_idx : current_idx + b_len]
        )
        current_idx += b_len
    
    return params

def init_w_b(popunum, num_type, nfeatures):
    
    all_network_params = {}
    current_popunum_offset = 0

    elements_per_network_block = (10 * nfeatures) + 10 + (10 * 10) + 10 + (1 * 10) + 1

    for i in range(num_type):
        key_idx_prefix_for_current_block = (3 * i) + 1
        
        start_idx = current_popunum_offset
        end_idx = current_popunum_offset + elements_per_network_block
        popunum_block = popunum[start_idx:end_idx]
        
        block_params = _extract_and_shape_single_network_params(
            popunum_block, nfeatures, key_idx_prefix_for_current_block
        )
        all_network_params.update(block_params)
        
        current_popunum_offset = end_idx
        
    return all_network_params

# %% [markdown]
# # Loss Function: RMSE
#
# The loss is computed using the formula:
#
# $$
# \text{loss} = \frac{1}{s} \sqrt{ \frac{1}{M} \sum_{i=1}^{M} \frac{1}{2} \left( \frac{x_i - y_i}{N} \right)^2 }
# $$
#
# where M is the total number of elements in the batch, N is the number of atoms in the crystal structure, and s is a scaling factor.

# %%
class RMSE(nn.Module):
  def __init__(self):
    super(RMSE, self).__init__()
  def forward(self, inputs, targets, natoms):
    global scale
    if scale == 0 and os.path.exists(file_scale):
        with open(file_scale, 'r') as f:
            for line in f:
                scale = float(line.strip().split()[0])
    loss = torch.pow((inputs - targets) / torch.tensor(natoms), 2) * 0.5
    loss = loss.mean().sqrt() / scale
    return loss

# %% [markdown]
# ## Early Stopping
# Early stopping is a technique used to prevent overfitting during training. It monitors the validation loss and stops training when the loss does not improve for a specified number of epochs (patience). This helps in finding the optimal model without unnecessary training.

# %%
class EarlyStopping:
    def __init__(self, patience=10, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss)
            self.counter = 0

    def save_checkpoint(self, val_loss):
        self.val_loss_min = val_loss

# %% [markdown]
# ## Training process
#
# The training process involves the following steps:
# 1. **Data Preparation**: Load the crystal structures and their corresponding energies, shuffle the data and splitting it into batches.
# 2. **Model Initialization**: Create the neural network model with the specified architecture.
# 3. **Training Loop**:
#    - For each epoch:
#      - For each batch:
#        - Forward pass: Compute the predicted energies using the neural network.
#        - Compute the loss using the RMSE function.
#        - Backward pass: Update the model parameters using the optimizer.
#         - Check for early stopping conditions.
# 4. **Validation**: After each epoch, evaluate the model on the validation set to monitor performance.
#
# All this is done in parallel using Ray to speed up the training process among multiple CPU cores (and many neural networks). Moreover the optimization process is done using the PGB algorithm (explained later).

# %%
from get_dataset import TrainDataset

def train_process(nfeat, popunum, f_main, thread_index):
    setup_seed(100)
    
    with open('./train/generate.in', 'r') as f_read:
        for i, line in enumerate(f_read):
            if i == 3:
                num_type = int(line.split()[0])

    w_b = init_w_b(popunum, num_type, nfeat)
    
    train_data, vali_data = train_test_split(data, test_size=0.1, random_state=42)

    device = torch.device("cuda" if thread_index == 9999 and torch.cuda.is_available() else "cpu")
    
    train_dataset = TrainDataset(train_data, device)
    vali_dataset = TrainDataset(vali_data, device)
    train_loader = DataLoader(train_dataset, batch_size=BATCH, shuffle=True)
    vali_loader = DataLoader(vali_dataset, batch_size=1, shuffle=False)

    model = NeuralNetwork(nfeat, w_b).to(device)
    min_vali, history_train, history_val = train_model(model, train_loader, vali_loader, f_main, thread_index, device)
    
    return min_vali, history_train, history_val


def train_model(model, train_loader, vali_loader, f_main, thread_index, device):
    EPOCHS = 500 if thread_index == 9999 else 1
    min_vali = float('inf')

    criterion = RMSE()
    optimizer = optim.Adamax(model.parameters(), lr=1e-3, betas=(0.9, 0.999), eps=1e-8, weight_decay=0)
    early_stopping = EarlyStopping(patience=40, verbose=True)

    history_train_loss = []
    history_vali_loss = []

    for epoch in range(EPOCHS):
        st = time.time()
        loss_train, loss_vali, real_loss = {}, {}, {}

        # === Training ===
        model.train()
        for i, (x, flag_list, y, struct_name) in enumerate(train_loader, start=1):
            x = x
            y = y
            flag_list = flag_list

            out, num_nopad = model(x, flag_list)
            loss = criterion(out, y, num_nopad)

            loss_train[struct_name] = loss.item()

            optimizer.zero_grad()
            if loss.item() != 0.0:
                loss.backward()
            optimizer.step()

        train_loss = sum(loss_train.values()) / len(loss_train)
        history_train_loss.append(train_loss)

        # === Validation ===
        model.eval()
        with torch.no_grad():
            for i, (x, flag_list, y, struct_name) in enumerate(vali_loader, start=1):
                x = x
                y = y
                flag_list = flag_list

                out, num_nopad = model(x, flag_list)
                loss = criterion(out, y, num_nopad)
                loss_vali[struct_name] = loss.item()

                real_diff = (out.data[0] - y.data[0]) / scale
                real_loss[struct_name] = abs(real_diff)

        avg_real_loss = sum(real_loss.values()).numpy()[0] / len(real_loss)
        max_real_loss = max(real_loss.values()).numpy()[0]
        vali_loss = sum(loss_vali.values()) / len(loss_vali)
        history_vali_loss.append(vali_loss)

        print(f"[{epoch:03d}/{EPOCHS}], time: {time.time() - st:.3f}s, "
              f"train_loss: {train_loss:.6f}, vali_loss: {vali_loss:.6f}, "
              f"avg_real_loss: {avg_real_loss:.6f}, max_real_loss: {max_real_loss:.6f}")

        early_stopping(vali_loss)
        model_dir = os.path.join(WORKPLACE, 'model', 'model_' + str(thread_index) + '/model.pkl')
        print(f"Model directory: {model_dir}")

        if vali_loss < min_vali:
            min_vali = vali_loss
            if thread_index == 9999:
                print(f"Saving model to {model_dir}")
                torch.save(model.state_dict(), model_dir)

        if early_stopping.early_stop:
            break

    return min_vali, history_train_loss, history_vali_loss

# %% [markdown]
# ## Fitness Evaluation
# The fitness evaluation is a crucial step in the genetic algorithm where each individual in the population is assessed based on how well it performs the task at hand. In our case, the task is to train a neural network to predict the energy of crystal structures.

# %%
@ray.remote
def fitnessFunction(population_vector, thread_index):
    log_path = f'output_all/log{thread_index}.txt'
    with open(log_path, 'a+') as log_file:

        temp_file = os.path.join(WORKPLACE, 'train', 'file.temp')
        if os.path.exists(temp_file):
            os.remove(temp_file)

        os.system(f'cp {WORKPLACE}/train/generate.in ./temp_files/')

        model_path = os.path.join(WORKPLACE, 'train', 'model.pkl')
        if os.path.exists(model_path):
            os.remove(model_path)

        n_features = 44
        min_val, history_train, history_val = train_process(n_features, population_vector, log_file, thread_index)

    return -min_val, history_train, history_val

# Calculates the fitness value of a population of chromosomes by evaluating each 
# chromosome's performance.
def getFitnessValue(decode, thread_index=0):

    history_train = []
    history_val = []
    
    if thread_index == 9999:
        fitness_value, history_train, history_val = ray.get(fitnessFunction.remote(decode, thread_index))
        fitness_values = np.array([fitness_value])
    else:
        pop_size, _ = decode.shape
        results = [fitnessFunction.remote(decode[i], i) for i in range(pop_size)]
        fitness_values = np.array([res[0] for res in ray.get(results)])

    print(f"Fitness values: {fitness_values}")

    total_fitness = np.sum(fitness_values)
    probability = fitness_values / total_fitness if total_fitness != 0 else np.ones_like(fitness_values) / len(fitness_values)
    cum_probability = np.cumsum(probability)

    return fitness_values, cum_probability, history_train, history_val

# %% [markdown]
# # PGB (Particle swarm Genetic Bayesian) Algorithm
# The PGB algorithm is a hybrid method that mixes Genetic Algorithm (GA), Particle Swarm Optimization (PSO), and Bayesian Optimization to fine-tune neural network parameters, especially for materials science. The main goal is to boost model's accuracy (at the cost of some computational resources).
#
# ## How PGB Works
#
# 1.  **Start**: It begins by setting up the neural network and creating an initial "population" of possible parameter sets.
# 2.  **Check Fitness**: Each parameter set is tested by training a neural network and seeing how well it performs.
# 3.  **Bayes optimization**: If the algorithm isn't finding better solutions after a while, Bayesian optimization steps in to suggest new, diverse parameter sets to try.
# 4.  **Evolve**: The algorithm then uses GA techniques:
#     * **Selection**: Good-performing parameter sets are chosen.
#     * **Crossover**: These sets are combined, notably by mixing them with the current best-performing set.
#     * **Mutation**: Parameters are slightly changed using a mix of PSO-like adjustments and standard random changes. The balance between these mutation types adapts as the search progresses.
# 5.  **Repeat**: These steps are repeated until a stopping condition is met. The best parameters found are then used for the final neural network training.
#
# ## Why PGB?
#
# By blending these techniques, PGB aims to:
# * Explore a wide range of possible solutions (thanks to GA).
# * Quickly find promising areas (thanks to PSO).
# * Avoid getting stuck on solutions that aren't truly the best (thanks to Bayesian Optimization).
#
# The overall aim is to get more stable, efficient, and precise neural network models for tasks like predicting material energies.
#
#
# <p align="center">
#   <img src="./img/full_algorithm.png" alt="Alt text" width="800"/>
# </p>

# %% [markdown]
# # Genetic Algorithm (GA) Overview
#
# The genetic algorithm (GA) is an optimization method inspired by the process of biological evolution, specifically the concept of "natural selection, survival of the fittest".
#
# 1.  **Initialization**: The process begins by creating an initial population of individuals. Each individual represents a potential solution and is typically encoded in some form (e.g., as a string of parameters).
# 2.  **Fitness Evaluation**: Each individual in the population is evaluated based on a "fitness value". This value quantifies how good the solution represented by the individual is. For instance, the root mean square error (RMSE) can be used as a fitness value, where a lower RMSE indicates a better fitness.
# 3.  **Selection**: Individuals are selected from the current population to create a basis for the next generation. This selection is typically based on their fitness values, with fitter individuals having a higher chance of being chosen.
# 4.  **Genetic Operators**:
#     * **Crossover**: New individuals (offspring) are generated by combining genetic material from selected parent individuals. This involves exchanging parts of their encoded representations (chromosomes). In a specific application mentioned, each individual might be crossed with the current global best individual in the population.
#     * **Mutation**: Random alterations are introduced into the new individuals at a certain probability. This helps maintain diversity in the population and explore new areas of the solution space. One form of mutation is real number mutation, where a gene of an individual is randomly changed within a defined range.
# 5.  **New Generation and Iteration**: The new individuals generated through crossover and mutation form the next generation of the population. This entire process (fitness evaluation, selection, crossover, and mutation) is repeated for a number of generations or until certain convergence conditions are met, such as reaching a maximum number of iterations or when the improvement in fitness stagnates.
#
# The goal is that over generations, the population will evolve towards better solutions to the problem being optimized.
#
# <p align="center">
#   <img src="./img/genetic_flowchart.jpg" alt="Alt text" width="300"/>
# </p>

# %% [markdown]
# ## Initialization
#
# The initialization of the genetic algorithm involves setting up the initial population of individuals, each representing a potential solution to the optimization problem. The parameters for each individual are randomly generated within specified ranges.

# %%
from scipy.optimize import fsolve

# Generates an initial binary population (chromosomes) for a genetic algorithm.
def getinitialPopulation(length, populationSize):
  chromsomes = np.zeros((populationSize, length), dtype=int)
  for popusize in range(populationSize):
      chromsomes[popusize, :] = np.random.randint(0, 2, length)
  return chromsomes

# %% [markdown]
# ## Encoding and Decoding
#
# In the context of the genetic algorithm, encoding refers to how the parameters of each individual are represented. In this case, each individual is encoded as a list of binary numbers, where each number corresponds to a specific parameter of the neural network. On the other hand, decoding is the process of converting these encoded parameters back into a format that can be used by the neural network. This typically involves mapping the binary numbers to the actual weights and biases of the neural network.

# %%
# Calculates the number of bits needed to encode each decision variable based on its range 
# and a desired precision (delta).
def getEncodeLength(decisionvariables, delta):
  lengths = []
  for decisionvar in decisionvariables:
      uper = decisionvar[1]
      low = decisionvar[0]
      res = fsolve(lambda x: ((uper - low) / delta - 2 ** x + 1), 30)
      length = int(np.ceil(res[0]))
      lengths.append(length)
  return lengths

# Converts a binary chromosome to a binary representation of real values based on the encoding length and decision range.
def getEncodeBinary(real_values, encode_length, decision_range):
  lower, upper = decision_range[0]
  num_bits = encode_length[0]

  # Scale and quantize
  normalized = ((real_values - lower) / (upper - lower)) * (2 ** num_bits - 1)
  quantized = np.round(normalized).astype(int)

  # Convert to binary strings and pad
  def to_binary(x):
    return list(map(int, format(x, f'0{num_bits}b')))

  binary_encoded = np.array([to_binary(val) for val in quantized.flatten()])
  binary_encoded = binary_encoded.reshape(real_values.shape[0], -1)

  return binary_encoded

# Converts a binary population (chromosomes) back to real values based on the encoding length and decision range.
def getDecode(binary_population, encode_length, decision_range):
  lower, upper = decision_range[0]
  num_bits = encode_length[0]
  n_samples = binary_population.shape[0]
  n_vars = binary_population.shape[1] // num_bits

  # Reshape and interpret as binary integers
  reshaped = binary_population.reshape(n_samples, n_vars, num_bits)
  powers = 2 ** np.arange(num_bits - 1, -1, -1)
  integer_values = np.sum(reshaped * powers, axis=2)

  # Scale back to real values
  real_values = lower + integer_values * (upper - lower) / (2 ** num_bits - 1)
  return real_values

# %% [markdown]
# ## Selection population
# The selection process in a genetic algorithm is designed to choose individuals from the current population to create the next generation. The goal is to favor individuals with higher fitness values, ensuring that better solutions have a higher chance of being passed on.
#
#
# <p align="center">
#   <img src="./img/selection.png" alt="Selection" width="700"/>
# </p>

# %%
def selectNewPopulation(decoded_population, cumulative_probabilities):
    num_individuals, _ = decoded_population.shape
    new_population = np.zeros_like(decoded_population)

    for i in range(num_individuals):
        r = np.random.rand()
        for j in range(num_individuals):
            if r < cumulative_probabilities[j]:
                new_population[i] = decoded_population[j]
                break

    return new_population


def evaluate_population(binary_population, encoding_lengths, variable_bounds):
    decoded_population = getDecode(binary_population, encoding_lengths, variable_bounds)
    fitness_values, cumulative_probabilities, _, _ = getFitnessValue(decoded_population)
    return decoded_population, fitness_values, cumulative_probabilities

# %% [markdown]
# ## Crossover
# Crossover is a genetic operator used to combine the genetic information of two parent individuals to create one or more offspring. This process mimics biological reproduction and is essential for introducing diversity into the population.
#
# <p align="center">
#   <img src="./img/crossover.png" alt="Selection" width="1000"/>
# </p>

# %%
# performs crossover on a population based on the best individual.
def crossover_population(population, crossover_prob, fitness_scores):
    num_individuals, num_genes = population.shape
    best_idx = np.argmax(fitness_scores)
    num_to_cross = int(np.round(num_individuals * crossover_prob))

    # Ensure an even number for pairing
    if num_to_cross % 2 != 0:
        num_to_cross += 1

    # Prepare new population
    new_population = np.copy(population)

    # Select individuals for crossover
    selected_indices = random.sample(range(num_individuals), num_to_cross)
    
    for idx in selected_indices:
        crossover_point = np.random.randint(1, num_genes)  # avoid 0 to prevent no crossover
        if np.random.rand() < 0.5:
            new_population[idx, crossover_point:] = population[best_idx, crossover_point:]
        else:
            new_population[idx, :crossover_point] = population[best_idx, :crossover_point]

    return new_population

# Selects the top individuals from a population based on their fitness scores.
def select_top_individuals(population, fitness_scores, num_selected, top_k):
    flat_scores = fitness_scores.flatten()
    top_indices = heapq.nlargest(top_k, range(len(flat_scores)), key=flat_scores.__getitem__)
    
    top_population = np.zeros((num_selected, population.shape[1]))
    top_fitness = np.zeros(num_selected)

    for i, idx in enumerate(top_indices[:num_selected]):
        top_population[i] = population[idx]
        top_fitness[i] = fitness_scores[idx]

    return top_population, top_fitness

# %% [markdown]
# ## Mutation
# Mutation is a genetic operator used in genetic algorithms to introduce random changes to individuals in the population. This process helps maintain genetic diversity and allows the algorithm to explore new areas of the solution space. In
#
# * Randomly alters genes in individuals.
# * Helps explore **new areas** of the search space.
# * Reduces risk of **premature convergence**.
#
# <p align="center">
#   <img src="./img/mutation.png" alt="Selection" width="1000"/>
# </p>
#
# ### PSO (Particle Swarm Optimization)
# PSO improves individuals by learning from their own best past performance, called the personal best, and from the best solution found by the entire population, called the global best. It balances exploration, which is trying new solutions, and exploitation, which is refining good ones. PSO uses a velocity-based update to guide the movement of individuals through the solution space.
#
# <p align="center">
#   <img src="./img/particle_swarm.png" alt="Selection" width="400"/>
# </p>

# %%
def apply_mutation_and_pso(population, fitness_values, pso_idx, mutation_idx, mutation_prob):

    # --- PSO hyperparameters ---
    w_inertia = 0.5
    c_personal = 2.0
    c_social = 3.0
    value_bounds = (-1.0, 1.0)

    # Find global and personal bests
    global_best = population[np.argmax(fitness_values)].copy()
    personal_best = population[pso_idx].copy()

    # Apply mutation to the selected individual
    population[mutation_idx] = mutate_individual(population[mutation_idx], mutation_prob)

    # PSO-style update to the selected individual
    r1, r2 = np.random.rand(2)
    current = population[pso_idx]
    velocity_update = (
        w_inertia * current +
        c_personal * r1 * (personal_best - current) +
        c_social * r2 * (global_best - current)
    )
    # Clamp to bounds
    population[pso_idx] = np.clip(velocity_update, *value_bounds)

    return population

# Mutates an individual by randomly changing a certain number of genes based on the mutation probability.
def mutate_individual(individual, mutation_prob):
    mutated = np.copy(individual)
    num_genes = mutated.shape[-1]

    # Flatten if needed
    if mutated.ndim == 2:
        mutated = mutated.reshape(-1, num_genes)

    total_genes = mutated.size
    num_mutations = int(total_genes * mutation_prob)
    indices_to_mutate = random.sample(range(total_genes), num_mutations)

    for idx in indices_to_mutate:
        row = idx // num_genes
        col = idx % num_genes
        mutated[row, col] = np.random.uniform(-1.0, 1.0)

    return mutated

# %% [markdown]
# Function to perform crossover and mutation.

# %%
def crossover_and_mutate(population, crossover_probability, fitness, encoding_lengths, bounds, stagnation_counter, initial_pso_rate, mutation_base_prob):
    crossed_population = crossover_population(population, crossover_probability, fitness)
    decoded_crossed = getDecode(crossed_population, encoding_lengths, bounds)

    pso_rate = max(0, initial_pso_rate - 0.1 * stagnation_counter)
    mutation_prob = min(0.5, mutation_base_prob * stagnation_counter)

    population_size = decoded_crossed.shape[0]
    pso_indices = random.sample(range(population_size), int(population_size * pso_rate))
    other_indices = list(set(range(population_size)) - set(pso_indices))

    mutated_decoded = apply_mutation_and_pso(decoded_crossed, fitness, pso_indices, other_indices, mutation_prob)
    mutated_population = getEncodeBinary(mutated_decoded, encoding_lengths, bounds)

    return mutated_population, mutated_decoded

# %% [markdown]
# ## Bayesian Optimization
#
# Bayesian Optimization is a strategy for global optimization of expensive-to-evaluate functions. It builds a probabilistic model (e.g., Random Forest, Gaussian Process) of the objective function and uses it to select the most promising points to evaluate next, balancing exploration and exploitation.
# In our case we use the random forest in a search space of `[-1.0, 1.0]` for each parameter with the Expected Improvement (EI) acquisition function.
#
# **Expected Improvement (EI)** quantifies how much improvement over the current best solution is expected by sampling a candidate point. It guides the optimizer to choose points that either have high predicted performance or high uncertainty, effectively balancing exploration of unknown areas and exploitation of known good areas.
#
# The optimizer:
# 1. Receives past samples (`tell`) with their fitness.
# 2. Suggests new candidates (`ask`) to improve the current solution.

# %%
def get_num_para_from_input(file_path='./train/generate.in', target_line=3):
    with open(file_path, 'r') as f:
        for i, line in enumerate(f):
            if i == target_line:
                num_type = int(line.split()[0])
                break
    return {1: 351, 2: 1142, 3: 1713}.get(num_type, None)

num_para = get_num_para_from_input()

# Initialize the Bayesian optimizer
opt_bayes = skopt.Optimizer(
    [skopt.space.Real(-1.0, 1.0, name=f'x{i}') for i in range(num_para)],
    n_initial_points=0,
    base_estimator='RF',
    acq_func='EI',
    acq_optimizer='auto',
    random_state=0,
    n_jobs=10,
)

def bayesian_optimization_step(
    combined_population, combined_decoded, combined_fitness,
    encoding_lengths, bounds, resolution,
    bayes_pool_decoded, bayes_pool_fitness,
    n_replace=10
):
    # Inform the Bayesian optimizer about the current sampled points and their (negated) fitness
    opt_bayes.tell(bayes_pool_decoded.tolist(), (-1 * bayes_pool_fitness).tolist())

    # Request new candidate points from the Bayesian optimizer
    new_candidates = np.array(opt_bayes.ask(n_replace))

    # Evaluate the fitness of the new candidates
    new_fitness_values, _, _, _ = getFitnessValue(new_candidates)

    # Encode the new candidates into the binary representation used by the population
    new_encoded_candidates = getEncodeBinary(new_candidates, encoding_lengths, bounds)

    # Find indices of the worst performing individuals to replace
    flat_values = combined_fitness.flatten().tolist()
    worst_indices = list(map(flat_values.index, heapq.nlargest(n_replace, flat_values)))

    # Replace the worst individuals with the new candidates
    combined_population[worst_indices] = new_encoded_candidates
    combined_decoded[worst_indices] = new_candidates
    combined_fitness[worst_indices] = new_fitness_values

    return new_candidates, new_fitness_values

# %% [markdown]
# ## Training without PGB
# First, we train the neural network without the PGB algorithm to establish a baseline performance.

# %%
# Plot the training and validation loss history
def plot_loss_history(history_train, history_val):
  plt.figure(figsize=(12, 6))
  plt.plot(history_train, label='Training Loss', color='blue')
  plt.plot(history_val, label='Validation Loss', color='orange')
  plt.title('Training and Validation Loss History')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)

# %%
BOUNDS = [[-1.0, 1.0]] * num_para
RESOLUTION = 0.0001

# Initialize population and encoding
encoding_lengths = getEncodeLength(BOUNDS, RESOLUTION)
population = getinitialPopulation(sum(encoding_lengths), 1)
parameters = getDecode(population, encoding_lengths, BOUNDS)

min_vali, cum_proba, history_train, history_val = getFitnessValue(np.array(parameters[0]), 9999)
plot_loss_history(history_train, history_val)

print("Best fitness value:", min_vali)
# Out:
# (raylet) Warning: The remote function __main__.fitnessFunction is very large (55 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# (fitnessFunction pid=74400) /var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_74153/282539720.py:14: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:212.)
# (fitnessFunction pid=74400) [000/500], time: 2.363s, train_loss: 2.139261, vali_loss: 1.145608, avg_real_loss: 19.198627, max_real_loss: 69.779732
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [001/500], time: 2.244s, train_loss: 1.317003, vali_loss: 0.782396, avg_real_loss: 13.146425, max_real_loss: 57.032284
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [002/500], time: 2.232s, train_loss: 0.917324, vali_loss: 0.568461, avg_real_loss: 9.606281, max_real_loss: 46.253864
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [003/500], time: 2.212s, train_loss: 0.686924, vali_loss: 0.436177, avg_real_loss: 7.379189, max_real_loss: 38.183994
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [004/500], time: 2.229s, train_loss: 0.548603, vali_loss: 0.368882, avg_real_loss: 6.244559, max_real_loss: 31.975151
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [005/500], time: 2.201s, train_loss: 0.479738, vali_loss: 0.338738, avg_real_loss: 5.648521, max_real_loss: 26.307373
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [006/500], time: 2.201s, train_loss: 0.436573, vali_loss: 0.315928, avg_real_loss: 5.224452, max_real_loss: 21.969522
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [007/500], time: 2.248s, train_loss: 0.405700, vali_loss: 0.306851, avg_real_loss: 5.024778, max_real_loss: 21.074308
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [008/500], time: 2.444s, train_loss: 0.382749, vali_loss: 0.290894, avg_real_loss: 4.726568, max_real_loss: 19.680794
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [009/500], time: 2.312s, train_loss: 0.365007, vali_loss: 0.285837, avg_real_loss: 4.652790, max_real_loss: 17.706238
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [010/500], time: 2.484s, train_loss: 0.353115, vali_loss: 0.272302, avg_real_loss: 4.400508, max_real_loss: 18.217413
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [011/500], time: 2.378s, train_loss: 0.339118, vali_loss: 0.260230, avg_real_loss: 4.229630, max_real_loss: 18.532324
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [012/500], time: 2.571s, train_loss: 0.332918, vali_loss: 0.257344, avg_real_loss: 4.197620, max_real_loss: 17.827936
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [013/500], time: 2.604s, train_loss: 0.318356, vali_loss: 0.251015, avg_real_loss: 4.113413, max_real_loss: 17.324553
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [014/500], time: 2.808s, train_loss: 0.310062, vali_loss: 0.240765, avg_real_loss: 4.020698, max_real_loss: 17.233622
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [015/500], time: 2.402s, train_loss: 0.306314, vali_loss: 0.242320, avg_real_loss: 3.991945, max_real_loss: 15.279093
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [016/500], time: 2.444s, train_loss: 0.292438, vali_loss: 0.234281, avg_real_loss: 3.839658, max_real_loss: 14.704993
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [017/500], time: 2.326s, train_loss: 0.288512, vali_loss: 0.228452, avg_real_loss: 3.774912, max_real_loss: 16.050291
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [018/500], time: 2.319s, train_loss: 0.283850, vali_loss: 0.230974, avg_real_loss: 3.782544, max_real_loss: 16.803650
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [019/500], time: 2.277s, train_loss: 0.275018, vali_loss: 0.224080, avg_real_loss: 3.682160, max_real_loss: 15.506982
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [020/500], time: 2.391s, train_loss: 0.271472, vali_loss: 0.219270, avg_real_loss: 3.600990, max_real_loss: 15.585142
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [021/500], time: 2.374s, train_loss: 0.264995, vali_loss: 0.217206, avg_real_loss: 3.629697, max_real_loss: 16.163134
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [022/500], time: 2.271s, train_loss: 0.262068, vali_loss: 0.216629, avg_real_loss: 3.555839, max_real_loss: 17.439745
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [023/500], time: 2.218s, train_loss: 0.256451, vali_loss: 0.214779, avg_real_loss: 3.532741, max_real_loss: 17.402075
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [024/500], time: 2.239s, train_loss: 0.254363, vali_loss: 0.212930, avg_real_loss: 3.497211, max_real_loss: 17.918518
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [025/500], time: 2.224s, train_loss: 0.248168, vali_loss: 0.205631, avg_real_loss: 3.410066, max_real_loss: 17.707727
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [026/500], time: 2.225s, train_loss: 0.242119, vali_loss: 0.205731, avg_real_loss: 3.387751, max_real_loss: 18.435316
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [027/500], time: 2.280s, train_loss: 0.239039, vali_loss: 0.204493, avg_real_loss: 3.345819, max_real_loss: 18.476730
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [028/500], time: 2.706s, train_loss: 0.235522, vali_loss: 0.202187, avg_real_loss: 3.311401, max_real_loss: 18.680832
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [029/500], time: 2.547s, train_loss: 0.230118, vali_loss: 0.191607, avg_real_loss: 3.201439, max_real_loss: 17.290846
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [030/500], time: 2.631s, train_loss: 0.229655, vali_loss: 0.188697, avg_real_loss: 3.152699, max_real_loss: 17.858248
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [031/500], time: 2.586s, train_loss: 0.225127, vali_loss: 0.187501, avg_real_loss: 3.114194, max_real_loss: 17.950972
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [032/500], time: 2.615s, train_loss: 0.224380, vali_loss: 0.182652, avg_real_loss: 3.047092, max_real_loss: 18.341068
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [033/500], time: 3.067s, train_loss: 0.219276, vali_loss: 0.182919, avg_real_loss: 3.066158, max_real_loss: 19.507576
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [034/500], time: 2.551s, train_loss: 0.215149, vali_loss: 0.182565, avg_real_loss: 3.022220, max_real_loss: 19.962227
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [035/500], time: 2.254s, train_loss: 0.217281, vali_loss: 0.181161, avg_real_loss: 3.015419, max_real_loss: 20.190977
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [036/500], time: 2.315s, train_loss: 0.210768, vali_loss: 0.180233, avg_real_loss: 2.967333, max_real_loss: 20.669977
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [037/500], time: 2.317s, train_loss: 0.210381, vali_loss: 0.174345, avg_real_loss: 2.888516, max_real_loss: 19.939682
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [038/500], time: 2.276s, train_loss: 0.207037, vali_loss: 0.177004, avg_real_loss: 2.915544, max_real_loss: 20.489159
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [039/500], time: 2.368s, train_loss: 0.203812, vali_loss: 0.168842, avg_real_loss: 2.804815, max_real_loss: 20.015276
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [040/500], time: 2.168s, train_loss: 0.203155, vali_loss: 0.167111, avg_real_loss: 2.764658, max_real_loss: 20.239628
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [041/500], time: 2.266s, train_loss: 0.200202, vali_loss: 0.169176, avg_real_loss: 2.802914, max_real_loss: 21.139141
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [042/500], time: 2.200s, train_loss: 0.200497, vali_loss: 0.160921, avg_real_loss: 2.701510, max_real_loss: 20.114613
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [043/500], time: 2.232s, train_loss: 0.195173, vali_loss: 0.160395, avg_real_loss: 2.686416, max_real_loss: 20.441181
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [044/500], time: 2.264s, train_loss: 0.195384, vali_loss: 0.158008, avg_real_loss: 2.672769, max_real_loss: 20.085249
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [045/500], time: 2.265s, train_loss: 0.193107, vali_loss: 0.156740, avg_real_loss: 2.627021, max_real_loss: 20.374126
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [046/500], time: 2.237s, train_loss: 0.188946, vali_loss: 0.157758, avg_real_loss: 2.618340, max_real_loss: 21.110477
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [047/500], time: 2.241s, train_loss: 0.190581, vali_loss: 0.149533, avg_real_loss: 2.544494, max_real_loss: 19.897820
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [048/500], time: 2.355s, train_loss: 0.186985, vali_loss: 0.151261, avg_real_loss: 2.533583, max_real_loss: 20.950697
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [049/500], time: 2.304s, train_loss: 0.187407, vali_loss: 0.151308, avg_real_loss: 2.521226, max_real_loss: 21.242579
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [050/500], time: 2.231s, train_loss: 0.183470, vali_loss: 0.148749, avg_real_loss: 2.489913, max_real_loss: 21.128534
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [051/500], time: 2.341s, train_loss: 0.183069, vali_loss: 0.143316, avg_real_loss: 2.435225, max_real_loss: 20.377792
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [052/500], time: 2.424s, train_loss: 0.181295, vali_loss: 0.144728, avg_real_loss: 2.429933, max_real_loss: 21.180782
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [053/500], time: 2.314s, train_loss: 0.178568, vali_loss: 0.139110, avg_real_loss: 2.402191, max_real_loss: 20.135433
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [054/500], time: 2.279s, train_loss: 0.179076, vali_loss: 0.140681, avg_real_loss: 2.397917, max_real_loss: 20.613451
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [055/500], time: 2.220s, train_loss: 0.177475, vali_loss: 0.148520, avg_real_loss: 2.490350, max_real_loss: 22.041103
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [056/500], time: 2.208s, train_loss: 0.175071, vali_loss: 0.143977, avg_real_loss: 2.428354, max_real_loss: 21.828913
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [057/500], time: 2.202s, train_loss: 0.172596, vali_loss: 0.142513, avg_real_loss: 2.404727, max_real_loss: 21.953339
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [058/500], time: 2.298s, train_loss: 0.172682, vali_loss: 0.140880, avg_real_loss: 2.385425, max_real_loss: 21.787832
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [059/500], time: 2.396s, train_loss: 0.173293, vali_loss: 0.138969, avg_real_loss: 2.359214, max_real_loss: 21.688217
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [060/500], time: 2.498s, train_loss: 0.169316, vali_loss: 0.142030, avg_real_loss: 2.384784, max_real_loss: 22.262901
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [061/500], time: 2.257s, train_loss: 0.169187, vali_loss: 0.133923, avg_real_loss: 2.309658, max_real_loss: 21.512552
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [062/500], time: 2.207s, train_loss: 0.167643, vali_loss: 0.138969, avg_real_loss: 2.378550, max_real_loss: 21.598291
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [063/500], time: 3.250s, train_loss: 0.170088, vali_loss: 0.137291, avg_real_loss: 2.333693, max_real_loss: 22.545340
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [064/500], time: 2.431s, train_loss: 0.165433, vali_loss: 0.134969, avg_real_loss: 2.307937, max_real_loss: 22.342268
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [065/500], time: 2.420s, train_loss: 0.163635, vali_loss: 0.132602, avg_real_loss: 2.297012, max_real_loss: 20.754852
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [066/500], time: 2.297s, train_loss: 0.164284, vali_loss: 0.137389, avg_real_loss: 2.341994, max_real_loss: 22.234074
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [067/500], time: 2.318s, train_loss: 0.164240, vali_loss: 0.138619, avg_real_loss: 2.343611, max_real_loss: 23.103907
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [068/500], time: 2.262s, train_loss: 0.162410, vali_loss: 0.132752, avg_real_loss: 2.286093, max_real_loss: 21.794270
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [069/500], time: 2.448s, train_loss: 0.161510, vali_loss: 0.133305, avg_real_loss: 2.287123, max_real_loss: 22.351192
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [070/500], time: 2.239s, train_loss: 0.161642, vali_loss: 0.135829, avg_real_loss: 2.313250, max_real_loss: 23.243879
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [071/500], time: 2.301s, train_loss: 0.161178, vali_loss: 0.130236, avg_real_loss: 2.259192, max_real_loss: 21.854454
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [072/500], time: 2.776s, train_loss: 0.159785, vali_loss: 0.137791, avg_real_loss: 2.350514, max_real_loss: 22.970900
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [073/500], time: 2.418s, train_loss: 0.159091, vali_loss: 0.131386, avg_real_loss: 2.258845, max_real_loss: 23.360653
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [074/500], time: 2.356s, train_loss: 0.157598, vali_loss: 0.131121, avg_real_loss: 2.258397, max_real_loss: 22.785135
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [075/500], time: 2.339s, train_loss: 0.159850, vali_loss: 0.130016, avg_real_loss: 2.242204, max_real_loss: 22.683533
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [076/500], time: 2.802s, train_loss: 0.155326, vali_loss: 0.132450, avg_real_loss: 2.280260, max_real_loss: 23.316822
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [077/500], time: 2.415s, train_loss: 0.157012, vali_loss: 0.135492, avg_real_loss: 2.310906, max_real_loss: 23.954937
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [078/500], time: 2.515s, train_loss: 0.154816, vali_loss: 0.128364, avg_real_loss: 2.215921, max_real_loss: 23.268469
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [079/500], time: 2.466s, train_loss: 0.153359, vali_loss: 0.129700, avg_real_loss: 2.231830, max_real_loss: 23.639198
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [080/500], time: 2.547s, train_loss: 0.152245, vali_loss: 0.130550, avg_real_loss: 2.242348, max_real_loss: 23.546047
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [081/500], time: 2.453s, train_loss: 0.153849, vali_loss: 0.123386, avg_real_loss: 2.178341, max_real_loss: 21.809710
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [082/500], time: 2.376s, train_loss: 0.150258, vali_loss: 0.124052, avg_real_loss: 2.181794, max_real_loss: 22.153421
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [083/500], time: 2.362s, train_loss: 0.150863, vali_loss: 0.132758, avg_real_loss: 2.276521, max_real_loss: 24.111946
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [084/500], time: 2.615s, train_loss: 0.148602, vali_loss: 0.128825, avg_real_loss: 2.209627, max_real_loss: 24.125437
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [085/500], time: 2.494s, train_loss: 0.151305, vali_loss: 0.127877, avg_real_loss: 2.196375, max_real_loss: 23.800514
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [086/500], time: 2.442s, train_loss: 0.150442, vali_loss: 0.124793, avg_real_loss: 2.185698, max_real_loss: 22.967155
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [087/500], time: 2.324s, train_loss: 0.147301, vali_loss: 0.124593, avg_real_loss: 2.166142, max_real_loss: 23.595074
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [088/500], time: 2.296s, train_loss: 0.149314, vali_loss: 0.126558, avg_real_loss: 2.182839, max_real_loss: 23.791758
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [089/500], time: 2.360s, train_loss: 0.142837, vali_loss: 0.122054, avg_real_loss: 2.125752, max_real_loss: 23.015137
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [090/500], time: 2.339s, train_loss: 0.146519, vali_loss: 0.122987, avg_real_loss: 2.135815, max_real_loss: 22.941526
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [091/500], time: 2.285s, train_loss: 0.146721, vali_loss: 0.123285, avg_real_loss: 2.137641, max_real_loss: 23.566702
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [092/500], time: 2.309s, train_loss: 0.145163, vali_loss: 0.122626, avg_real_loss: 2.134343, max_real_loss: 23.566198
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [093/500], time: 2.325s, train_loss: 0.141733, vali_loss: 0.120984, avg_real_loss: 2.121355, max_real_loss: 22.615953
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [094/500], time: 2.293s, train_loss: 0.146490, vali_loss: 0.123336, avg_real_loss: 2.133861, max_real_loss: 23.737949
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [095/500], time: 2.227s, train_loss: 0.142918, vali_loss: 0.118607, avg_real_loss: 2.083504, max_real_loss: 22.552698
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [096/500], time: 2.440s, train_loss: 0.142411, vali_loss: 0.122560, avg_real_loss: 2.119279, max_real_loss: 23.429773
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [097/500], time: 2.552s, train_loss: 0.143850, vali_loss: 0.120459, avg_real_loss: 2.093659, max_real_loss: 23.807491
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [098/500], time: 2.379s, train_loss: 0.139339, vali_loss: 0.121577, avg_real_loss: 2.100316, max_real_loss: 24.368109
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [099/500], time: 2.296s, train_loss: 0.139338, vali_loss: 0.117943, avg_real_loss: 2.059111, max_real_loss: 23.351007
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [100/500], time: 2.287s, train_loss: 0.142474, vali_loss: 0.121396, avg_real_loss: 2.090663, max_real_loss: 24.107628
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [101/500], time: 2.355s, train_loss: 0.138703, vali_loss: 0.119949, avg_real_loss: 2.088462, max_real_loss: 23.696802
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [102/500], time: 2.478s, train_loss: 0.139087, vali_loss: 0.115676, avg_real_loss: 2.022356, max_real_loss: 23.591127
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [103/500], time: 3.057s, train_loss: 0.140058, vali_loss: 0.114233, avg_real_loss: 2.011083, max_real_loss: 23.242708
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [104/500], time: 2.325s, train_loss: 0.138821, vali_loss: 0.119442, avg_real_loss: 2.065687, max_real_loss: 24.141613
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [105/500], time: 2.253s, train_loss: 0.139105, vali_loss: 0.115273, avg_real_loss: 2.020083, max_real_loss: 23.516323
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [106/500], time: 2.231s, train_loss: 0.140074, vali_loss: 0.116198, avg_real_loss: 2.019217, max_real_loss: 24.468105
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [107/500], time: 2.285s, train_loss: 0.136172, vali_loss: 0.115164, avg_real_loss: 2.006471, max_real_loss: 23.691843
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [108/500], time: 2.177s, train_loss: 0.137925, vali_loss: 0.114831, avg_real_loss: 2.021402, max_real_loss: 22.853693
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [109/500], time: 2.320s, train_loss: 0.136342, vali_loss: 0.114142, avg_real_loss: 1.994710, max_real_loss: 23.850657
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [110/500], time: 2.249s, train_loss: 0.136418, vali_loss: 0.119402, avg_real_loss: 2.066574, max_real_loss: 24.200794
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [111/500], time: 2.178s, train_loss: 0.133283, vali_loss: 0.114643, avg_real_loss: 1.993994, max_real_loss: 23.966530
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [112/500], time: 2.220s, train_loss: 0.136172, vali_loss: 0.112740, avg_real_loss: 1.973756, max_real_loss: 23.968185
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [113/500], time: 2.367s, train_loss: 0.134219, vali_loss: 0.114327, avg_real_loss: 1.994899, max_real_loss: 23.819384
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [114/500], time: 2.256s, train_loss: 0.134139, vali_loss: 0.111005, avg_real_loss: 1.963077, max_real_loss: 22.962650
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [115/500], time: 2.205s, train_loss: 0.133264, vali_loss: 0.111911, avg_real_loss: 1.964197, max_real_loss: 23.532091
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [116/500], time: 2.183s, train_loss: 0.132768, vali_loss: 0.109641, avg_real_loss: 1.947922, max_real_loss: 22.918129
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [117/500], time: 2.336s, train_loss: 0.132561, vali_loss: 0.112645, avg_real_loss: 1.966481, max_real_loss: 24.059816
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [118/500], time: 2.292s, train_loss: 0.131902, vali_loss: 0.113307, avg_real_loss: 1.975119, max_real_loss: 24.002174
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [119/500], time: 2.209s, train_loss: 0.133016, vali_loss: 0.113792, avg_real_loss: 1.990130, max_real_loss: 24.362078
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [120/500], time: 2.195s, train_loss: 0.132388, vali_loss: 0.111175, avg_real_loss: 1.957042, max_real_loss: 24.127855
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [121/500], time: 2.253s, train_loss: 0.129929, vali_loss: 0.113023, avg_real_loss: 1.977316, max_real_loss: 23.783300
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [122/500], time: 2.256s, train_loss: 0.131399, vali_loss: 0.117366, avg_real_loss: 2.024936, max_real_loss: 24.223057
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [123/500], time: 2.226s, train_loss: 0.129320, vali_loss: 0.107674, avg_real_loss: 1.919902, max_real_loss: 22.692850
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [124/500], time: 2.169s, train_loss: 0.129112, vali_loss: 0.108148, avg_real_loss: 1.898958, max_real_loss: 23.689777
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [125/500], time: 2.234s, train_loss: 0.127409, vali_loss: 0.107345, avg_real_loss: 1.908975, max_real_loss: 22.771551
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [126/500], time: 2.233s, train_loss: 0.129266, vali_loss: 0.108980, avg_real_loss: 1.907951, max_real_loss: 23.990969
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [127/500], time: 2.192s, train_loss: 0.130943, vali_loss: 0.111906, avg_real_loss: 1.949016, max_real_loss: 24.306988
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [128/500], time: 2.298s, train_loss: 0.130666, vali_loss: 0.106436, avg_real_loss: 1.869242, max_real_loss: 23.493135
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [129/500], time: 2.276s, train_loss: 0.130980, vali_loss: 0.109154, avg_real_loss: 1.914729, max_real_loss: 24.208115
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [130/500], time: 2.327s, train_loss: 0.128548, vali_loss: 0.106192, avg_real_loss: 1.865684, max_real_loss: 23.803343
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [131/500], time: 2.246s, train_loss: 0.128848, vali_loss: 0.105188, avg_real_loss: 1.857490, max_real_loss: 23.560410
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [132/500], time: 2.373s, train_loss: 0.128148, vali_loss: 0.103269, avg_real_loss: 1.850623, max_real_loss: 22.477606
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [133/500], time: 2.271s, train_loss: 0.127186, vali_loss: 0.106850, avg_real_loss: 1.880705, max_real_loss: 23.963110
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [134/500], time: 2.327s, train_loss: 0.127392, vali_loss: 0.105695, avg_real_loss: 1.880983, max_real_loss: 23.294504
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [135/500], time: 2.340s, train_loss: 0.126029, vali_loss: 0.101294, avg_real_loss: 1.817781, max_real_loss: 22.635420
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [136/500], time: 2.375s, train_loss: 0.126373, vali_loss: 0.101276, avg_real_loss: 1.808956, max_real_loss: 22.645790
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [137/500], time: 2.368s, train_loss: 0.127337, vali_loss: 0.104322, avg_real_loss: 1.824846, max_real_loss: 24.257029
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [138/500], time: 2.306s, train_loss: 0.125328, vali_loss: 0.101690, avg_real_loss: 1.793765, max_real_loss: 23.853035
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [139/500], time: 2.446s, train_loss: 0.126815, vali_loss: 0.103760, avg_real_loss: 1.828306, max_real_loss: 23.561460
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [140/500], time: 2.268s, train_loss: 0.126742, vali_loss: 0.103151, avg_real_loss: 1.836718, max_real_loss: 23.201408
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [141/500], time: 2.304s, train_loss: 0.125115, vali_loss: 0.101620, avg_real_loss: 1.793374, max_real_loss: 23.722994
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [142/500], time: 2.307s, train_loss: 0.124186, vali_loss: 0.102024, avg_real_loss: 1.793970, max_real_loss: 23.683413
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [143/500], time: 2.189s, train_loss: 0.125287, vali_loss: 0.100222, avg_real_loss: 1.787140, max_real_loss: 23.510752
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [144/500], time: 2.227s, train_loss: 0.123093, vali_loss: 0.101000, avg_real_loss: 1.796225, max_real_loss: 23.465834
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [145/500], time: 2.225s, train_loss: 0.124924, vali_loss: 0.104794, avg_real_loss: 1.872601, max_real_loss: 23.312746
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [146/500], time: 2.260s, train_loss: 0.122222, vali_loss: 0.104467, avg_real_loss: 1.838129, max_real_loss: 24.055140
# ...
# (fitnessFunction pid=74400) [280/500], time: 2.458s, train_loss: 0.098252, vali_loss: 0.081222, avg_real_loss: 1.457026, max_real_loss: 23.281988
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [281/500], time: 2.562s, train_loss: 0.098539, vali_loss: 0.083946, avg_real_loss: 1.501441, max_real_loss: 24.029579
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [282/500], time: 2.731s, train_loss: 0.099334, vali_loss: 0.082684, avg_real_loss: 1.486949, max_real_loss: 23.045399
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [283/500], time: 2.651s, train_loss: 0.101823, vali_loss: 0.083543, avg_real_loss: 1.507065, max_real_loss: 23.247219
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [284/500], time: 2.515s, train_loss: 0.098788, vali_loss: 0.083694, avg_real_loss: 1.505565, max_real_loss: 23.447020
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [285/500], time: 2.533s, train_loss: 0.099778, vali_loss: 0.082641, avg_real_loss: 1.475956, max_real_loss: 23.313723
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [286/500], time: 2.656s, train_loss: 0.097101, vali_loss: 0.081654, avg_real_loss: 1.460229, max_real_loss: 24.160101
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [287/500], time: 2.697s, train_loss: 0.098644, vali_loss: 0.080018, avg_real_loss: 1.430592, max_real_loss: 23.773169
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [288/500], time: 2.505s, train_loss: 0.100057, vali_loss: 0.081649, avg_real_loss: 1.462731, max_real_loss: 23.966602
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [289/500], time: 2.437s, train_loss: 0.097248, vali_loss: 0.079929, avg_real_loss: 1.434135, max_real_loss: 23.086351
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [290/500], time: 2.415s, train_loss: 0.096202, vali_loss: 0.080889, avg_real_loss: 1.447570, max_real_loss: 23.536154
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [291/500], time: 2.417s, train_loss: 0.099882, vali_loss: 0.082562, avg_real_loss: 1.496529, max_real_loss: 23.410961
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [292/500], time: 2.417s, train_loss: 0.097642, vali_loss: 0.079425, avg_real_loss: 1.425426, max_real_loss: 23.332365
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [293/500], time: 2.395s, train_loss: 0.098326, vali_loss: 0.080849, avg_real_loss: 1.446373, max_real_loss: 23.227570
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [294/500], time: 2.685s, train_loss: 0.096515, vali_loss: 0.080248, avg_real_loss: 1.440952, max_real_loss: 22.996677
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [295/500], time: 2.505s, train_loss: 0.097398, vali_loss: 0.080979, avg_real_loss: 1.443407, max_real_loss: 23.582285
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [296/500], time: 2.479s, train_loss: 0.097639, vali_loss: 0.079138, avg_real_loss: 1.418018, max_real_loss: 23.196245
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [297/500], time: 2.398s, train_loss: 0.096778, vali_loss: 0.082481, avg_real_loss: 1.471120, max_real_loss: 23.415079
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [298/500], time: 2.393s, train_loss: 0.098894, vali_loss: 0.078378, avg_real_loss: 1.413573, max_real_loss: 22.589527
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [299/500], time: 2.393s, train_loss: 0.097494, vali_loss: 0.080158, avg_real_loss: 1.442374, max_real_loss: 23.005657
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [300/500], time: 2.347s, train_loss: 0.097580, vali_loss: 0.080881, avg_real_loss: 1.446628, max_real_loss: 23.186821
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [301/500], time: 2.757s, train_loss: 0.097897, vali_loss: 0.080552, avg_real_loss: 1.447765, max_real_loss: 23.278280
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [302/500], time: 2.714s, train_loss: 0.098466, vali_loss: 0.079909, avg_real_loss: 1.437225, max_real_loss: 22.897272
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [303/500], time: 2.670s, train_loss: 0.096227, vali_loss: 0.082233, avg_real_loss: 1.465471, max_real_loss: 23.716938
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [304/500], time: 2.538s, train_loss: 0.096325, vali_loss: 0.081437, avg_real_loss: 1.461485, max_real_loss: 23.025642
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [305/500], time: 2.517s, train_loss: 0.097358, vali_loss: 0.083222, avg_real_loss: 1.471491, max_real_loss: 24.409689
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [306/500], time: 2.438s, train_loss: 0.098099, vali_loss: 0.081805, avg_real_loss: 1.460277, max_real_loss: 23.274897
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [307/500], time: 2.510s, train_loss: 0.098675, vali_loss: 0.079648, avg_real_loss: 1.431489, max_real_loss: 22.651140
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [308/500], time: 2.424s, train_loss: 0.096992, vali_loss: 0.080547, avg_real_loss: 1.441467, max_real_loss: 23.477251
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [309/500], time: 2.371s, train_loss: 0.097064, vali_loss: 0.080861, avg_real_loss: 1.452491, max_real_loss: 22.611122
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [310/500], time: 2.336s, train_loss: 0.098411, vali_loss: 0.078877, avg_real_loss: 1.418192, max_real_loss: 22.741884
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [311/500], time: 2.469s, train_loss: 0.098242, vali_loss: 0.079711, avg_real_loss: 1.426015, max_real_loss: 22.957109
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [312/500], time: 2.404s, train_loss: 0.097604, vali_loss: 0.081963, avg_real_loss: 1.465230, max_real_loss: 23.615221
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [313/500], time: 2.414s, train_loss: 0.096649, vali_loss: 0.080257, avg_real_loss: 1.437948, max_real_loss: 23.151968
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [314/500], time: 2.364s, train_loss: 0.097807, vali_loss: 0.080206, avg_real_loss: 1.437027, max_real_loss: 23.123705
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [315/500], time: 2.696s, train_loss: 0.095907, vali_loss: 0.085246, avg_real_loss: 1.518504, max_real_loss: 23.884752
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [316/500], time: 2.679s, train_loss: 0.096325, vali_loss: 0.081671, avg_real_loss: 1.455015, max_real_loss: 23.511026
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [317/500], time: 2.567s, train_loss: 0.095795, vali_loss: 0.081020, avg_real_loss: 1.460692, max_real_loss: 23.441042
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [318/500], time: 2.635s, train_loss: 0.097921, vali_loss: 0.080692, avg_real_loss: 1.446248, max_real_loss: 22.439932
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [319/500], time: 2.673s, train_loss: 0.095562, vali_loss: 0.080206, avg_real_loss: 1.432553, max_real_loss: 23.508646
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [320/500], time: 2.839s, train_loss: 0.094044, vali_loss: 0.082567, avg_real_loss: 1.457335, max_real_loss: 24.022123
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [321/500], time: 2.564s, train_loss: 0.096331, vali_loss: 0.079768, avg_real_loss: 1.425876, max_real_loss: 23.324152
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [322/500], time: 2.496s, train_loss: 0.096755, vali_loss: 0.082119, avg_real_loss: 1.461151, max_real_loss: 23.182899
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [323/500], time: 2.742s, train_loss: 0.096201, vali_loss: 0.080399, avg_real_loss: 1.432368, max_real_loss: 23.157276
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [324/500], time: 2.618s, train_loss: 0.093618, vali_loss: 0.081448, avg_real_loss: 1.451904, max_real_loss: 22.893772
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [325/500], time: 2.473s, train_loss: 0.095903, vali_loss: 0.078427, avg_real_loss: 1.407735, max_real_loss: 22.633177
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [326/500], time: 2.420s, train_loss: 0.097352, vali_loss: 0.083756, avg_real_loss: 1.492795, max_real_loss: 23.162561
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [327/500], time: 2.425s, train_loss: 0.094119, vali_loss: 0.080159, avg_real_loss: 1.431739, max_real_loss: 22.690153
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [328/500], time: 2.374s, train_loss: 0.096352, vali_loss: 0.079272, avg_real_loss: 1.419444, max_real_loss: 22.516026
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [329/500], time: 2.619s, train_loss: 0.094626, vali_loss: 0.080926, avg_real_loss: 1.441155, max_real_loss: 23.043295
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [330/500], time: 2.473s, train_loss: 0.096417, vali_loss: 0.079229, avg_real_loss: 1.408941, max_real_loss: 23.183556
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [331/500], time: 2.404s, train_loss: 0.095387, vali_loss: 0.078482, avg_real_loss: 1.392335, max_real_loss: 22.945250
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [332/500], time: 2.646s, train_loss: 0.096420, vali_loss: 0.082841, avg_real_loss: 1.467185, max_real_loss: 23.609158
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [333/500], time: 2.439s, train_loss: 0.094680, vali_loss: 0.078713, avg_real_loss: 1.404628, max_real_loss: 22.671852
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [334/500], time: 3.430s, train_loss: 0.095610, vali_loss: 0.081204, avg_real_loss: 1.444994, max_real_loss: 23.494825
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [335/500], time: 2.968s, train_loss: 0.095575, vali_loss: 0.080503, avg_real_loss: 1.422466, max_real_loss: 23.843243
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [336/500], time: 2.494s, train_loss: 0.092855, vali_loss: 0.080408, avg_real_loss: 1.424153, max_real_loss: 23.335363
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=74400) [337/500], time: 2.523s, train_loss: 0.093622, vali_loss: 0.080408, avg_real_loss: 1.439187, max_real_loss: 23.459854
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# Fitness values: [-0.07837813]
# (fitnessFunction pid=74400) [338/500], time: 3.456s, train_loss: 0.096263, vali_loss: 0.080916, avg_real_loss: 1.430686, max_real_loss: 23.570375
# (fitnessFunction pid=74400) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# Best fitness value: [-0.07837813]

# %% [markdown]
# # Evaluation on the test set

# %%
from get_dataset import PredictDataset

def predict_model(f_format, nfeat):
    
    model = NeuralNetwork(nfeat)
    model.load_state_dict(torch.load('./model/model_9999/model.pkl', map_location=torch.device('cpu')))
    model.eval()

    # Load prediction data
    data = np.load('./predict_data/predict.npy', allow_pickle=True)

    # Set device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Prepare dataset and dataloader
    dataset = PredictDataset(data, device)
    dataloader = DataLoader(dataset, batch_size=1)

    # Load normalization parameters
    with open(file_scale, 'r') as f:
        scale = float(f.readline().strip().split()[0])
    with open(file_shift, 'r') as f:
        shift = float(f.readline().strip().split()[0])

    predictions_scaled = {}
    predictions_unscaled = {}
    structure_ids = []
    prediction_values = []

    # Run inference
    for x, flag_list, struct_name in dataloader:
        x_var = Variable(x)
        output, atom_count = model(x_var, flag_list)
        
        struct = struct_name[0]
        raw_prediction = output.data[0].item()

        structure_ids.append(struct)
        prediction_values.append(raw_prediction)

        predictions_scaled[struct] = raw_prediction
        predictions_unscaled[struct] = (raw_prediction / scale) + (float(atom_count[0]) * shift)

    # Save predictions to file
    output_path = os.path.join(os.path.abspath(os.path.dirname(f_format)), 'vasp_candidate.txt')
    with open(output_path, 'w') as f:
        for struct in structure_ids:
            f.write(f"{struct},{predictions_unscaled[struct]}\n")

# %% [markdown]
# ## Metrics for Evaluation

# %%
from sklearn.metrics import r2_score
from sklearn import metrics


def result_conn():
    for model_index in range(1, 2):
        result_path = f'./predict/predict{model_index}/'
        ga_predict_file = os.path.join(result_path, 'GA_predict.txt')
        vasp_candidate_file = os.path.join(result_path, 'vasp_candidate.txt')
        result_con_file = os.path.join(result_path, 'result_con.txt')
        dft_result_file = './predict_data/result_DFT.txt'

        def generate_ga_predictions():
            if os.path.exists(ga_predict_file):
                os.remove(ga_predict_file)

            with open(vasp_candidate_file, 'r') as f_read, open(ga_predict_file, 'a') as f_write:
                for line in f_read:
                    parts = line.strip().split(',')
                    if len(parts) >= 2:
                        id_ga = parts[0][8:]
                        energy = parts[1]
                        f_write.write(f'{id_ga} {energy}\n')

        def combine_ga_dft_results():
            if os.path.exists(result_con_file):
                os.remove(result_con_file)

            # Read GA predictions into a dictionary for fast lookup
            ga_predictions = {}
            with open(ga_predict_file, 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) == 2:
                        ga_predictions[parts[0]] = parts[1]

            with open(dft_result_file, 'r') as f_dft, open(result_con_file, 'a') as f_out:
                for line in f_dft:
                    parts = line.strip().split()
                    if len(parts) == 2:
                        id_ga, energy_ga = parts
                        energy_dft = ga_predictions.get(id_ga)
                        if energy_dft is not None:
                            f_out.write(f'{id_ga} {energy_ga} {energy_dft}\n')
                        else:
                            f_out.write(f'{id_ga} {energy_ga}\n')

        generate_ga_predictions()
        combine_ga_dft_results()


def mape(y_true, y_pred):
    return np.mean(np.abs((y_pred - y_true) / y_true)) 

def smape(y_true, y_pred):
    return 2.0 * np.mean(np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true))) 

def RMSE_calu():

    R2_all = []
    MSE_all = []
    RMSE_all = []
    MAE_all = []
    MAPE_all = []

    for model_index in range(1,2):
        result_path = './predict/predict%s/'%model_index
        real = []
        predict = []
        with open(result_path + 'result_con.txt', 'r') as f_read:
            for i, line in enumerate(f_read):
                line = line.strip()
                standred = float(line.split()[1])
                GA_predict = float(line.split()[2])
                real.append(standred)
                predict.append(GA_predict)

        real = np.array(real)
        predict = np.array(predict)
        
        MSE_all.append(metrics.mean_squared_error(real, predict))
        RMSE_all.append(np.sqrt(metrics.mean_squared_error(real, predict)))
        MAE_all.append(metrics.mean_absolute_error(real, predict))
        MAPE_all.append(mape(real, predict))
        R2_all.append(r2_score(real,predict))

def result_conn2():
    for model_index in range(1, 2):
        result_path = f'./predict/predict{model_index}/'
        ga_predict_file = os.path.join(result_path, 'GA_predict.txt')
        ga_predict_num_file = os.path.join(result_path, 'GA_predict_atomenergy_num.txt')
        ga_atomenergy_file = os.path.join(result_path, 'GA_predict_atomenergy.txt')
        dft_numbers_file = './predict_data/numbers.txt'
        dft_atomenergy_file = './predict_data/result_DFT_atomenergy.txt'
        result_con_file = os.path.join(result_path, 'result_con.txt')

        def match_ga_with_atom_counts():
            # Load a mapping from ID → atom count
            id_to_atom_count = {}
            with open(dft_numbers_file, 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) >= 2:
                        id_to_atom_count[parts[0]] = parts[1]

            # Write GA predictions + atom count to a file
            with open(ga_predict_file, 'r') as f_read, open(ga_predict_num_file, 'w') as f_write:
                for line in f_read:
                    parts = line.strip().split()
                    if len(parts) >= 2:
                        xsf_id, energy = parts
                        atom_count = id_to_atom_count.get(xsf_id)
                        if atom_count:
                            f_write.write(f'{xsf_id} {energy} {atom_count}\n')

        def compute_atom_energy():
            # Divide total energy by atom count
            with open(ga_predict_num_file, 'r') as f_read, open(ga_atomenergy_file, 'w') as f_write:
                for line in f_read:
                    parts = line.strip().split()
                    if len(parts) == 3:
                        xsf_id, total_energy, atom_count = parts
                        try:
                            atom_energy = float(total_energy) / float(atom_count)
                            f_write.write(f'{xsf_id} {atom_energy:.6f}\n')
                        except ZeroDivisionError:
                            continue

        def combine_ga_dft_atom_energy():
            if os.path.exists(result_con_file):
                os.remove(result_con_file)

            # Load GA atom energies into a dictionary
            ga_atom_energies = {}
            with open(ga_atomenergy_file, 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) == 2:
                        ga_atom_energies[parts[0]] = parts[1]

            # Combine with DFT atom energies
            with open(dft_atomenergy_file, 'r') as f_read, open(result_con_file, 'w') as f_write:
                for line in f_read:
                    parts = line.strip().split()
                    if len(parts) >= 2:
                        xsf_id, dft_energy = parts
                        ga_energy = ga_atom_energies.get(xsf_id)
                        if ga_energy:
                            f_write.write(f'{xsf_id} {dft_energy} {ga_energy}\n')
                        else:
                            f_write.write(f'{xsf_id} {dft_energy}\n')

        # Run all steps
        match_ga_with_atom_counts()
        compute_atom_energy()
        combine_ga_dft_atom_energy()

def RMSE_calu2():

    R2_all = []
    MSE_all = []
    RMSE_all = []
    L1_all = []
    MAE_all = []
    MAPE_all = []


    for model_index in range(1,2):
        result_path = './predict/predict%s/'%model_index
        real = []
        predict = []
        with open(result_path + 'result_con.txt', 'r') as f_read:
            for i, line in enumerate(f_read):
                line = line.strip()
                standred = float(line.split()[1])
                GA_predict = float(line.split()[2])
                real.append(standred)
                predict.append(GA_predict)


        real = np.array(real)
        predict = np.array(predict)
        
        MSE_all.append(metrics.mean_squared_error(real, predict))
        RMSE_all.append(np.sqrt(metrics.mean_squared_error(real, predict)))
        L1_all.append(np.linalg.norm(real - predict, ord=1) / len(real))
        MAE_all.append(metrics.mean_absolute_error(real, predict))
        MAPE_all.append(mape(real, predict))
        R2_all.append(r2_score(real,predict))
        
    print('MSE',np.mean(MSE_all))
    print('RMSE',np.mean(RMSE_all))
    print('L1',np.mean(L1_all))
    print('MAE',np.mean(MAE_all))
    print('MAPE',np.mean(MAPE_all))
    print('R2',np.mean(R2_all))
    print()

def generate_plots(model_index=1):
    result_path = f'./predict/predict{model_index}/'
    real, predict = [], []
    
    try:
        with open(result_path + 'result_con.txt', 'r') as f_read:
            for line in f_read:
                parts = line.strip().split()
                real.append(float(parts[1]))
                predict.append(float(parts[2]))
    except FileNotFoundError:
        return

    real = np.array(real)
    predict = np.array(predict)

    plt.figure(figsize=(8, 8))
    plt.scatter(real, predict, alpha=0.6, edgecolors='k', s=50)
    
    lim_min = min(real.min(), predict.min())
    lim_max = max(real.max(), predict.max())
    plt.plot([lim_min, lim_max], [lim_min, lim_max], 'r--', linewidth=2, label='Predizione Perfetta')
    
    plt.title('Correlation between real and predicted energy', fontsize=16)
    plt.xlabel('Real energy (per atom)', fontsize=12)
    plt.ylabel('Predicted energy (per atom)', fontsize=12)
    plt.legend()
    plt.grid(True)
    plt.axis('equal')
    
    errors = predict - real
    rmse = np.sqrt(np.mean(errors**2))
    l1 = np.linalg.norm(errors, ord=1) / len(errors)

    plt.figure(figsize=(10, 6))
    plt.hist(errors, bins=40, edgecolor='black', alpha=0.7)
    
    plt.axvline(0, color='r', linestyle='--', linewidth=2, label='Null error')
    
    plt.title('Distribution of prediction errors', fontsize=16)
    plt.xlabel('Error (Predicted - Real)', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.legend()
    plt.grid(axis='y', alpha=0.5)
    
    plt.text(0.95, 0.95, f'L1 = {l1:.4f}', transform=plt.gca().transAxes,
             fontsize=12, verticalalignment='top', horizontalalignment='right',
             bbox=dict(boxstyle='round,pad=0.5', fc='wheat', alpha=0.5))

    plt.tight_layout()
    plt.show()

# %%
if os.path.exists('./predict/predict1'):
    shutil.rmtree('./predict/predict1')
    shutil.rmtree('./predict')
os.mkdir('./predict')
os.mkdir('./predict/predict1')
os.system('cp model/model_9999/model.pkl temp_files/')
os.system('cd temp_files; cp normal_para.txt normal_para_predict.txt')
os.system('cp temp_files/* ./predict/predict1')

predict_model('./predict/predict1/predictset_with_scaled_normalized.txt',nfeatures)

result_conn() 
RMSE_calu()

result_conn2() 
RMSE_calu2()

generate_plots()
# Out:
# MSE 0.07002946028772271
# RMSE 0.26463079996047834
# L1 0.12186153395000002
# MAE 0.12186153395000002
# MAPE 0.016947915785722023
# R2 0.8830066035244931

# %% [markdown]
# ## Paper comparison error
#
# <p align="center">
#   <img src="./img/BP_TiO2.png" alt="Neural network" width="400"/>
# </p>
#
# Error RMSE: 0.27
#
# Error L1: 0.13
#
# Error MAPE: 0.01
#
# Error R2: 0.875

# %%
import matplotlib.pyplot as plt
import numpy as np

# Metrics
metrics = ['RMSE', 'L1', 'MAPE', 'R2']

my_model = [0.26463079996047834, 0.12186153395000002, 0.016947915785722023, 0.8830066035244931]

# Paper model errors
paper_model = [0.27, 0.13, 0.01, 0.875]

x = np.arange(len(metrics))  # label locations
width = 0.35  # width of bars

fig, ax = plt.subplots(figsize=(8,5))

bars1 = ax.bar(x - width/2, my_model, width, label='My model')
bars2 = ax.bar(x + width/2, paper_model, width, label='Paper Model')

# Add text labels above bars
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.3f}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0,3),
                    textcoords='offset points',
                    ha='center', va='bottom')

autolabel(bars1)
autolabel(bars2)

ax.set_ylabel('Error')
ax.set_title('Comparison of Error Metrics')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Optimization Algorithm: PGB

# %%
# Define parameters constants for the genetic algorithm
BOUNDS = [[-1.0, 1.0]] * num_para
RESOLUTION = 0.0001
POPULATION_SIZE = 20
MAX_GENERATIONS = 10
CROSSOVER_PROB = 0.8
MUTATION_BASE_PROB = 0.1
INITIAL_PSO_RATE = 0.8
STAGNATION_THRESHOLD = 3
BAYES_UPDATE_LIMIT = 5

# %%
from IPython.display import clear_output

# Function to plot fitness over generations
def plot_fitness(fitness_over_time, generation):
    clear_output(wait=True)
    plt.figure(figsize=(8, 4))
    plt.plot(fitness_over_time, label='Fitness')
    plt.xlabel('Generation')
    plt.ylabel('Fitness')
    plt.title(f'Generation {generation}')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Here we define the PGB algorithm, which combines Genetic Algorithm (GA), Particle Swarm Optimization (PSO), and Bayesian Optimization to optimize the neural network parameters.

# %%
def pgb():
    start_time = time.time()

    # Initialize population and encoding
    encoding_lengths = getEncodeLength(BOUNDS, RESOLUTION)
    population = getinitialPopulation(sum(encoding_lengths), POPULATION_SIZE)

    # Optimization state
    best_fitness = float('-inf')
    stagnation_counter = bayes_update_count = 0
    fitness_over_time, best_solutions, best_variables = [], [], []

    # Buffers for Bayesian optimization
    bayes_pool_decoded = np.empty((0, num_para))
    bayes_pool_fitness = np.array([])

    # Initial evaluation
    _, fitness_scores, _ = evaluate_population(
        population, encoding_lengths, BOUNDS
    )

    for generation in range(MAX_GENERATIONS):
        # Variation step: crossover and mutation
        mutated_population, decoded_mutated = crossover_and_mutate(
            population, CROSSOVER_PROB, fitness_scores,
            encoding_lengths, BOUNDS,
            stagnation_counter, INITIAL_PSO_RATE, MUTATION_BASE_PROB
        )

        # Evaluate mutated individuals
        decoded_original = getDecode(population, encoding_lengths, BOUNDS)
        mutated_fitness, _, _, _ = getFitnessValue(decoded_mutated)

        print(mutated_fitness)

        # Update Bayesian pool
        bayes_pool_decoded = np.vstack((bayes_pool_decoded, decoded_mutated))
        bayes_pool_fitness = np.hstack((bayes_pool_fitness, mutated_fitness))

        # Merge populations and fitness
        combined_population = np.vstack((population, mutated_population))
        combined_decoded = np.vstack((decoded_original, decoded_mutated))
        combined_fitness = np.hstack((fitness_scores, mutated_fitness))

        # Perform Bayesian update if stagnated
        if stagnation_counter >= STAGNATION_THRESHOLD:
            bayes_pool_decoded, bayes_pool_fitness = bayesian_optimization_step(
                combined_population, combined_decoded, combined_fitness,
                encoding_lengths, BOUNDS, RESOLUTION,
                bayes_pool_decoded, bayes_pool_fitness
            )
            bayes_update_count += 1

        # Select next generation
        population, fitness_scores = select_top_individuals(combined_population, combined_fitness, POPULATION_SIZE, POPULATION_SIZE)

        # Track best fitness
        current_best_fitness = np.max(combined_fitness)
        fitness_over_time.append(current_best_fitness)

        stagnation_counter += 1
        if current_best_fitness > best_fitness:
            best_fitness = current_best_fitness
            stagnation_counter = 0

        # Store best solution
        best_index = np.argmax(combined_fitness)
        best_solutions.append(current_best_fitness)
        best_variables.append(combined_decoded[best_index].tolist())

        # Plot and log progress
        plot_fitness(fitness_over_time, generation)
        print(f'Generation {generation} time: {time.time() - start_time:.2f}s')

        print(fitness_over_time)
        
        if bayes_update_count >= BAYES_UPDATE_LIMIT:
            break

    # Return best overall result
    final_idx = np.argmax(best_solutions)
    return best_solutions[final_idx], best_variables[final_idx]

# %% [markdown]
# Here we run the PGB algorithm to optimize the neural network parameters, saving the best parameters found during the optimization process.

# %%
optval, optvar = pgb()

print("Max fitness:", optval)
# Out:
# Generation 9 time: 1014.33s
# [-0.2326129380428756, -0.15874546664999797, -0.1463675768484245, -0.1463675768484245, -0.1463675768484245, -0.1463675768484245, -0.1488408921076916, -0.14884233217977452, -0.14884233217977452, -0.14884233217977452]
# Max fitness: -0.1463675768484245

# %% [markdown]
# Here we train the final neural network for 500 epochs using the best parameters found by the PGB algorithm.

# %%
# Perform the final training and evaluation using the optimal parameters
min_vali, cum_proba, history_train, history_val = getFitnessValue(np.array(optvar), 9999)
plot_loss_history(history_train, history_val)

print("Best fitness value:", min_vali)
# Out:
# (fitnessFunction pid=84397) [000/500], time: 3.850s, train_loss: 1.170658, vali_loss: 0.146368, avg_real_loss: 2.461853, max_real_loss: 23.166615
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [001/500], time: 3.516s, train_loss: 0.190938, vali_loss: 0.126485, avg_real_loss: 2.046788, max_real_loss: 25.216978
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [002/500], time: 3.722s, train_loss: 0.176691, vali_loss: 0.117099, avg_real_loss: 1.904578, max_real_loss: 25.185520
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [003/500], time: 3.550s, train_loss: 0.169373, vali_loss: 0.122283, avg_real_loss: 1.991735, max_real_loss: 23.827070
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [004/500], time: 3.420s, train_loss: 0.161512, vali_loss: 0.100936, avg_real_loss: 1.699079, max_real_loss: 24.541044
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [005/500], time: 3.506s, train_loss: 0.158283, vali_loss: 0.098360, avg_real_loss: 1.674482, max_real_loss: 23.741194
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [006/500], time: 3.504s, train_loss: 0.154161, vali_loss: 0.094763, avg_real_loss: 1.603923, max_real_loss: 24.084522
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [007/500], time: 4.427s, train_loss: 0.150814, vali_loss: 0.106190, avg_real_loss: 1.833299, max_real_loss: 22.319651
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [008/500], time: 6.154s, train_loss: 0.149715, vali_loss: 0.095688, avg_real_loss: 1.598616, max_real_loss: 24.493839
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [009/500], time: 4.530s, train_loss: 0.145446, vali_loss: 0.090374, avg_real_loss: 1.529749, max_real_loss: 24.158855
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [010/500], time: 4.297s, train_loss: 0.141695, vali_loss: 0.099888, avg_real_loss: 1.692748, max_real_loss: 22.366297
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [011/500], time: 4.422s, train_loss: 0.141571, vali_loss: 0.090605, avg_real_loss: 1.541880, max_real_loss: 23.618454
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [012/500], time: 4.450s, train_loss: 0.141063, vali_loss: 0.090735, avg_real_loss: 1.533944, max_real_loss: 24.589458
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [013/500], time: 4.493s, train_loss: 0.140937, vali_loss: 0.088345, avg_real_loss: 1.502490, max_real_loss: 24.578737
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [014/500], time: 4.772s, train_loss: 0.139453, vali_loss: 0.088246, avg_real_loss: 1.555825, max_real_loss: 21.870201
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [015/500], time: 4.729s, train_loss: 0.140017, vali_loss: 0.086239, avg_real_loss: 1.498801, max_real_loss: 22.754711
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [016/500], time: 4.795s, train_loss: 0.133837, vali_loss: 0.086981, avg_real_loss: 1.504097, max_real_loss: 23.820507
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [017/500], time: 3.820s, train_loss: 0.133815, vali_loss: 0.086023, avg_real_loss: 1.469174, max_real_loss: 25.063345
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [018/500], time: 3.416s, train_loss: 0.133233, vali_loss: 0.096876, avg_real_loss: 1.669203, max_real_loss: 23.253563
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [019/500], time: 3.281s, train_loss: 0.131683, vali_loss: 0.091889, avg_real_loss: 1.573241, max_real_loss: 23.892756
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [020/500], time: 3.279s, train_loss: 0.133098, vali_loss: 0.082940, avg_real_loss: 1.437574, max_real_loss: 24.923183
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [021/500], time: 3.425s, train_loss: 0.132977, vali_loss: 0.084254, avg_real_loss: 1.452704, max_real_loss: 25.205280
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [022/500], time: 3.498s, train_loss: 0.132256, vali_loss: 0.085930, avg_real_loss: 1.490719, max_real_loss: 22.979767
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [023/500], time: 3.491s, train_loss: 0.128363, vali_loss: 0.081698, avg_real_loss: 1.434024, max_real_loss: 23.402784
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [024/500], time: 3.615s, train_loss: 0.132090, vali_loss: 0.082640, avg_real_loss: 1.461275, max_real_loss: 23.859646
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [025/500], time: 3.582s, train_loss: 0.128042, vali_loss: 0.081507, avg_real_loss: 1.430293, max_real_loss: 24.220150
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [026/500], time: 3.523s, train_loss: 0.128337, vali_loss: 0.087689, avg_real_loss: 1.514066, max_real_loss: 23.798382
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [027/500], time: 3.575s, train_loss: 0.130801, vali_loss: 0.081649, avg_real_loss: 1.427689, max_real_loss: 23.741791
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [028/500], time: 3.460s, train_loss: 0.128737, vali_loss: 0.084503, avg_real_loss: 1.467451, max_real_loss: 23.998249
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [029/500], time: 3.490s, train_loss: 0.125079, vali_loss: 0.087895, avg_real_loss: 1.515851, max_real_loss: 22.331953
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [030/500], time: 3.681s, train_loss: 0.130469, vali_loss: 0.085752, avg_real_loss: 1.468469, max_real_loss: 23.646404
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [031/500], time: 3.821s, train_loss: 0.130364, vali_loss: 0.087365, avg_real_loss: 1.505532, max_real_loss: 24.225889
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [032/500], time: 4.033s, train_loss: 0.129119, vali_loss: 0.083821, avg_real_loss: 1.457628, max_real_loss: 23.914778
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [033/500], time: 3.697s, train_loss: 0.127421, vali_loss: 0.080611, avg_real_loss: 1.408383, max_real_loss: 25.169945
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [034/500], time: 3.611s, train_loss: 0.124874, vali_loss: 0.089534, avg_real_loss: 1.573443, max_real_loss: 24.975872
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [035/500], time: 3.549s, train_loss: 0.126006, vali_loss: 0.082120, avg_real_loss: 1.436222, max_real_loss: 23.264246
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [036/500], time: 3.370s, train_loss: 0.125271, vali_loss: 0.083503, avg_real_loss: 1.438320, max_real_loss: 23.327490
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [037/500], time: 3.989s, train_loss: 0.126526, vali_loss: 0.087855, avg_real_loss: 1.511768, max_real_loss: 23.538973
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [038/500], time: 3.775s, train_loss: 0.122843, vali_loss: 0.087077, avg_real_loss: 1.494984, max_real_loss: 22.587507
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [039/500], time: 3.743s, train_loss: 0.123632, vali_loss: 0.075558, avg_real_loss: 1.357165, max_real_loss: 24.511454
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [040/500], time: 3.791s, train_loss: 0.125654, vali_loss: 0.088950, avg_real_loss: 1.529945, max_real_loss: 23.855236
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [041/500], time: 3.866s, train_loss: 0.124299, vali_loss: 0.084902, avg_real_loss: 1.458309, max_real_loss: 24.090704
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [042/500], time: 3.696s, train_loss: 0.123105, vali_loss: 0.081694, avg_real_loss: 1.412675, max_real_loss: 23.385870
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [043/500], time: 3.499s, train_loss: 0.120862, vali_loss: 0.080386, avg_real_loss: 1.405507, max_real_loss: 23.068995
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [044/500], time: 3.678s, train_loss: 0.122772, vali_loss: 0.083243, avg_real_loss: 1.431485, max_real_loss: 22.665293
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [045/500], time: 3.639s, train_loss: 0.123456, vali_loss: 0.082202, avg_real_loss: 1.419618, max_real_loss: 23.263281
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [046/500], time: 3.623s, train_loss: 0.121907, vali_loss: 0.082719, avg_real_loss: 1.466464, max_real_loss: 24.546841
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [047/500], time: 3.925s, train_loss: 0.123357, vali_loss: 0.081561, avg_real_loss: 1.412009, max_real_loss: 22.490700
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [048/500], time: 4.825s, train_loss: 0.123802, vali_loss: 0.084598, avg_real_loss: 1.467921, max_real_loss: 22.607155
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [049/500], time: 4.887s, train_loss: 0.123118, vali_loss: 0.080189, avg_real_loss: 1.396971, max_real_loss: 23.732819
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [050/500], time: 3.957s, train_loss: 0.122046, vali_loss: 0.081456, avg_real_loss: 1.418745, max_real_loss: 23.213272
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [051/500], time: 4.157s, train_loss: 0.121201, vali_loss: 0.074114, avg_real_loss: 1.311118, max_real_loss: 23.682829
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [052/500], time: 4.290s, train_loss: 0.119700, vali_loss: 0.080159, avg_real_loss: 1.384977, max_real_loss: 23.205557
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [053/500], time: 3.923s, train_loss: 0.117749, vali_loss: 0.080858, avg_real_loss: 1.415042, max_real_loss: 24.764011
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [054/500], time: 3.523s, train_loss: 0.120163, vali_loss: 0.082587, avg_real_loss: 1.424963, max_real_loss: 22.390585
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [055/500], time: 3.740s, train_loss: 0.118003, vali_loss: 0.082427, avg_real_loss: 1.436877, max_real_loss: 22.859406
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [056/500], time: 3.664s, train_loss: 0.118464, vali_loss: 0.080424, avg_real_loss: 1.382137, max_real_loss: 23.816545
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [057/500], time: 3.487s, train_loss: 0.115748, vali_loss: 0.080713, avg_real_loss: 1.394191, max_real_loss: 23.040850
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [058/500], time: 3.334s, train_loss: 0.117556, vali_loss: 0.082159, avg_real_loss: 1.448100, max_real_loss: 23.423779
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [059/500], time: 3.440s, train_loss: 0.117561, vali_loss: 0.076533, avg_real_loss: 1.332180, max_real_loss: 22.898870
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [060/500], time: 3.392s, train_loss: 0.115497, vali_loss: 0.074537, avg_real_loss: 1.307340, max_real_loss: 24.053360
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [061/500], time: 3.487s, train_loss: 0.115484, vali_loss: 0.086340, avg_real_loss: 1.486766, max_real_loss: 22.667292
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [062/500], time: 3.459s, train_loss: 0.117345, vali_loss: 0.079508, avg_real_loss: 1.399456, max_real_loss: 24.758150
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [063/500], time: 4.095s, train_loss: 0.120642, vali_loss: 0.078422, avg_real_loss: 1.384797, max_real_loss: 23.741344
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [064/500], time: 4.757s, train_loss: 0.116211, vali_loss: 0.084107, avg_real_loss: 1.453292, max_real_loss: 23.243000
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [065/500], time: 5.327s, train_loss: 0.114408, vali_loss: 0.082714, avg_real_loss: 1.414633, max_real_loss: 23.519484
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [066/500], time: 4.232s, train_loss: 0.114134, vali_loss: 0.075378, avg_real_loss: 1.322021, max_real_loss: 23.683617
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [067/500], time: 3.880s, train_loss: 0.114068, vali_loss: 0.078202, avg_real_loss: 1.350225, max_real_loss: 23.383350
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [068/500], time: 3.811s, train_loss: 0.113403, vali_loss: 0.085301, avg_real_loss: 1.457093, max_real_loss: 22.447802
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [069/500], time: 4.409s, train_loss: 0.114487, vali_loss: 0.074461, avg_real_loss: 1.308165, max_real_loss: 23.173214
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [070/500], time: 5.181s, train_loss: 0.112361, vali_loss: 0.085469, avg_real_loss: 1.469838, max_real_loss: 22.912369
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [071/500], time: 7.100s, train_loss: 0.115400, vali_loss: 0.073114, avg_real_loss: 1.295168, max_real_loss: 23.300718
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [072/500], time: 5.680s, train_loss: 0.112014, vali_loss: 0.071534, avg_real_loss: 1.279940, max_real_loss: 23.331083
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [073/500], time: 5.868s, train_loss: 0.113771, vali_loss: 0.074921, avg_real_loss: 1.314530, max_real_loss: 23.429834
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [074/500], time: 5.921s, train_loss: 0.114477, vali_loss: 0.076222, avg_real_loss: 1.305280, max_real_loss: 23.900993
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [075/500], time: 8.425s, train_loss: 0.114490, vali_loss: 0.082237, avg_real_loss: 1.404538, max_real_loss: 23.207209
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [076/500], time: 5.564s, train_loss: 0.111200, vali_loss: 0.080955, avg_real_loss: 1.405446, max_real_loss: 22.928371
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [077/500], time: 6.656s, train_loss: 0.111586, vali_loss: 0.086156, avg_real_loss: 1.488128, max_real_loss: 22.647141
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 12:59:17,536 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 11.3525 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [078/500], time: 10.482s, train_loss: 0.110983, vali_loss: 0.075351, avg_real_loss: 1.308258, max_real_loss: 24.481901
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 12:59:27,595 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 11.3992 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [079/500], time: 8.355s, train_loss: 0.112150, vali_loss: 0.078095, avg_real_loss: 1.345368, max_real_loss: 23.378464
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [080/500], time: 5.152s, train_loss: 0.111503, vali_loss: 0.074954, avg_real_loss: 1.321208, max_real_loss: 22.395817
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [081/500], time: 4.320s, train_loss: 0.112291, vali_loss: 0.075974, avg_real_loss: 1.314785, max_real_loss: 23.951200
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [082/500], time: 3.944s, train_loss: 0.112171, vali_loss: 0.075706, avg_real_loss: 1.308107, max_real_loss: 23.538885
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [083/500], time: 4.686s, train_loss: 0.109608, vali_loss: 0.077642, avg_real_loss: 1.353021, max_real_loss: 22.337580
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 12:59:51,894 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 11.3688 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [084/500], time: 4.366s, train_loss: 0.108097, vali_loss: 0.081175, avg_real_loss: 1.409319, max_real_loss: 23.160772
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [085/500], time: 5.076s, train_loss: 0.110448, vali_loss: 0.077802, avg_real_loss: 1.351492, max_real_loss: 24.088856
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:00:01,939 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 10.4635 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [086/500], time: 9.381s, train_loss: 0.110407, vali_loss: 0.076015, avg_real_loss: 1.316447, max_real_loss: 23.733589
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:00:11,955 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 9.57908 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [087/500], time: 6.608s, train_loss: 0.109752, vali_loss: 0.074167, avg_real_loss: 1.321183, max_real_loss: 22.910995
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [088/500], time: 4.393s, train_loss: 0.109687, vali_loss: 0.079070, avg_real_loss: 1.371935, max_real_loss: 23.300783
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:00:22,054 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 8.54069 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [089/500], time: 4.888s, train_loss: 0.107062, vali_loss: 0.083868, avg_real_loss: 1.458959, max_real_loss: 22.884958
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [090/500], time: 6.917s, train_loss: 0.109690, vali_loss: 0.075962, avg_real_loss: 1.351289, max_real_loss: 23.684431
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:00:32,107 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 7.58589 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [091/500], time: 5.134s, train_loss: 0.109641, vali_loss: 0.072966, avg_real_loss: 1.293776, max_real_loss: 24.877516
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [092/500], time: 4.270s, train_loss: 0.111646, vali_loss: 0.080003, avg_real_loss: 1.397701, max_real_loss: 24.245775
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:00:42,205 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 7.58341 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [093/500], time: 4.920s, train_loss: 0.109971, vali_loss: 0.078180, avg_real_loss: 1.366208, max_real_loss: 22.976900
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [094/500], time: 4.858s, train_loss: 0.112702, vali_loss: 0.077866, avg_real_loss: 1.352091, max_real_loss: 23.749481
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:00:52,218 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 7.5995 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [095/500], time: 4.953s, train_loss: 0.108275, vali_loss: 0.084379, avg_real_loss: 1.460488, max_real_loss: 20.821829
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [096/500], time: 5.072s, train_loss: 0.109940, vali_loss: 0.079956, avg_real_loss: 1.406314, max_real_loss: 24.442549
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:01:02,236 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 7.71358 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [097/500], time: 6.378s, train_loss: 0.108357, vali_loss: 0.077056, avg_real_loss: 1.346887, max_real_loss: 22.842928
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [098/500], time: 4.245s, train_loss: 0.106086, vali_loss: 0.080982, avg_real_loss: 1.389863, max_real_loss: 23.997612
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:01:12,283 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 8.11438 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [099/500], time: 4.064s, train_loss: 0.108317, vali_loss: 0.081669, avg_real_loss: 1.417245, max_real_loss: 24.444752
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [100/500], time: 4.059s, train_loss: 0.109640, vali_loss: 0.081278, avg_real_loss: 1.412133, max_real_loss: 22.509743
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:01:22,300 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 8.21691 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [101/500], time: 4.352s, train_loss: 0.110020, vali_loss: 0.079415, avg_real_loss: 1.389835, max_real_loss: 24.767406
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [102/500], time: 4.673s, train_loss: 0.109985, vali_loss: 0.075554, avg_real_loss: 1.320257, max_real_loss: 23.659195
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:01:32,379 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 8.33136 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [103/500], time: 5.094s, train_loss: 0.108577, vali_loss: 0.078238, avg_real_loss: 1.391349, max_real_loss: 22.848785
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [104/500], time: 5.606s, train_loss: 0.108576, vali_loss: 0.075731, avg_real_loss: 1.318094, max_real_loss: 23.820284
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:01:42,477 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 8.38105 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [105/500], time: 4.417s, train_loss: 0.106304, vali_loss: 0.081601, avg_real_loss: 1.411723, max_real_loss: 22.592472
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [106/500], time: 4.026s, train_loss: 0.110441, vali_loss: 0.075261, avg_real_loss: 1.323927, max_real_loss: 22.875910
# (fitnessFunction pid=84397)
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:01:52,501 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 7.38612 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [107/500], time: 5.441s, train_loss: 0.109207, vali_loss: 0.084642, avg_real_loss: 1.473898, max_real_loss: 24.395817
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=84397) [108/500], time: 5.400s, train_loss: 0.108813, vali_loss: 0.087709, avg_real_loss: 1.506411, max_real_loss: 21.296757
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:02:02,572 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 7.25528 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [109/500], time: 12.245s, train_loss: 0.107609, vali_loss: 0.080513, avg_real_loss: 1.410643, max_real_loss: 23.164465
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:02:12,605 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 6.25043 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [110/500], time: 8.200s, train_loss: 0.108018, vali_loss: 0.073878, avg_real_loss: 1.302232, max_real_loss: 23.402763
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:02:22,671 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 6.3764 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [111/500], time: 6.329s, train_loss: 0.107491, vali_loss: 0.080270, avg_real_loss: 1.383369, max_real_loss: 23.976107
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (raylet) [2025-06-12 13:02:32,672 E 7266 5338012] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-11_12-31-28_417173_7092 is over 95% full, available space: 6.63179 GB; capacity: 228.274 GB. Object creation will fail if spilling is required.
# (fitnessFunction pid=84397) [112/500], time: 8.174s, train_loss: 0.107237, vali_loss: 0.075870, avg_real_loss: 1.323381, max_real_loss: 23.106749
# (fitnessFunction pid=84397) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# Fitness values: [-0.07153382]
# Best fitness value: [-0.07153382]

# %%
if os.path.exists('./predict/predict1'):
    shutil.rmtree('./predict/predict1')
    shutil.rmtree('./predict')
os.mkdir('./predict')
os.mkdir('./predict/predict1')
os.system('cp model/model_9999/model.pkl temp_files/')
os.system('cd temp_files; cp normal_para.txt normal_para_predict.txt')
os.system('cp temp_files/* ./predict/predict1')

predict_model('./predict/predict1/predictset_with_scaled_normalized.txt',nfeatures)

result_conn() 
RMSE_calu()

result_conn2() 
RMSE_calu2()

generate_plots()
# Out:
# MSE 0.06529802040361471
# RMSE 0.2555347733746128
# L1 0.10933105054999999
# MAE 0.10933105054999999
# MAPE 0.01516752722829305
# R2 0.8909110942914813

# %% [markdown]
# ## Paper comparison error
#
# <p align="center">
#   <img src="./img/PGB_TiO2.png" alt="Neural network" width="400"/>
# </p>
#
# Error RMSE: 0.24
#
# Error L1: 0.07
#
# Error MAPE: 0.01
#
# Error R2: 0.91

# %%
import matplotlib.pyplot as plt
import numpy as np

# Metrics
metrics = ['RMSE', 'L1', 'MAPE', 'R2']

my_model = [0.2555347733746128, 0.10933105054999999, 0.01516752722829305, 0.8909110942914813]

# Paper model errors
paper_model = [0.24, 0.07, 0.01, 0.91]

x = np.arange(len(metrics))  # label locations
width = 0.35  # width of bars

fig, ax = plt.subplots(figsize=(8,5))

bars1 = ax.bar(x - width/2, my_model, width, label='My model')
bars2 = ax.bar(x + width/2, paper_model, width, label='Paper Model')

# Add text labels above bars
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.3f}',
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0,3),
                    textcoords='offset points',
                    ha='center', va='bottom')

autolabel(bars1)
autolabel(bars2)

ax.set_ylabel('Error')
ax.set_title('Comparison of Error Metrics')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Metrics
metrics = ['RMSE', 'MAE', 'MAPE', 'R2']

my_model_bp = [0.26463079996047834, 0.12186153395000002, 0.016947915785722023, 0.8830066035244931]
my_model_pgb = [0.2555347733746128, 0.10933105054999999, 0.01516752722829305, 0.8909110942914813]

paper_bp = [0.27, 0.13, 0.01, 0.875]
paper_pgb = [0.24, 0.07, 0.01, 0.91]


x = np.arange(len(metrics))
width = 0.2

fig, ax = plt.subplots(figsize=(12, 7))

bars1 = ax.bar(x - 1.5*width, my_model_bp, width, label='My Model (BP)', color='cornflowerblue')
bars2 = ax.bar(x - 0.5*width, paper_bp,    width, label='Paper (BP)',    color='lightcoral')
bars3 = ax.bar(x + 0.5*width, my_model_pgb,  width, label='My Model (PGB)',  color='royalblue')
bars4 = ax.bar(x + 1.5*width, paper_pgb,   width, label='Paper (PGB)',   color='firebrick')

def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.3f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom',
                    rotation=0)

autolabel(bars1)
autolabel(bars2)
autolabel(bars3)
autolabel(bars4)

ax.set_ylabel('Score / Error')
ax.set_title('Confronto delle Metriche tra Modelli')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.set_ylim(0, max(my_model_bp + my_model_pgb + paper_bp + paper_pgb) * 1.15)
ax.legend()

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Numerical Simulation with Pyscf
# Here we perform a numerical simulation using the `pyscf` library to compute the energy of a crystal structure. This is done to validate the performance of the neural network model.
# We will focus on the Si crystal structure.

# %%
import ase.io
from ase.visualize.plot import plot_atoms
import matplotlib.pyplot as plt
import nglview as nv
import random
import os

random.seed(42)

# Randomly take a .xsf from the test dataset
file_to_read = './data/TiO2/raw_data/test'
file_to_read = os.path.join(file_to_read, random.choice(os.listdir(file_to_read)))
print(f"Reading structure from: {file_to_read}")
ase_atom = ase.io.read(file_to_read)

fig, ax = plt.subplots()
plot_atoms(ase_atom, ax, radii=0.5, rotation=('45x,45y,0z'))
plt.title(f"Structure from {file_to_read}")
plt.show()


# Create an interactive view from the ase object
view = nv.show_ase(ase_atom)
view.add_unitcell()
view
# Out:
# Reading structure from: ./data/TiO2/raw_data/test/structure100000002247.xsf
# NGLWidget()

# %% [markdown]
# ## Periodic Boundary Conditions (PBC)
#
# In quantum chemistry and condensed matter physics, periodic boundary conditions are used to model infinite crystalline solids. The periodicity of the potential and electronic density in such systems reflects the translational symmetry of the crystal lattice. Each unit cell is repeated in all directions to mimic the behavior of a bulk material.
#
# ## Density Functional Theory (DFT)
#
# DFT is a widely used method for computing the electronic structure of many-body systems. It reformulates the many-electron problem in terms of the electron density, rather than the many-body wavefunction.
#
# ## Density Fitting
#
# To accelerate the calculation of two-electron integrals, especially in periodic systems, density fitting techniques are employed. These approximate the electron repulsion integrals using an auxiliary basis, such as a plane-wave basis, and reduce the computational scaling.
# DFT calculations are carried out iteratively through a self-consistent field procedure. At each step, the electron density is updated based on the solution of the Kohn-Sham equations, and the process continues until convergence is achieved. The result is a total energy that includes kinetic, Coulomb, exchange-correlation, and pseudopotential contributions.

# %%
from pyscf.pbc import gto, dft, df
import numpy as np
import time

cell = gto.Cell()
cell.a = ase_atom.cell
cell.atom = list(zip(ase_atom.get_chemical_symbols(), ase_atom.get_positions()))
cell.basis = 'gth-szv-molopt-sr'
cell.pseudo = 'gth-pbe'
cell.unit = 'A'
cell.exp_to_discard=0.1
cell.ke_cutoff = 100
cell.build()

# --- Convergence Loop ---
k_mesh_sizes = [2, 4, 6, 8]
calculated_energies = []
calculation_times = []

print("--- Starting K-Point Convergence Test ---")

for n in k_mesh_sizes:
    now = time.time()
    kmesh = [n, n, n]
    kpts = cell.make_kpts(kmesh)
    
    print(f"\nCalculating for k-mesh = {kmesh}...")

    # Set up and run the DFT calculation
    mf = dft.KRKS(cell, kpts=kpts)
    mf.with_df = df.FFTDF(cell)
    mf.xc = 'pbe'
    mf.conv_tol = 1e-8
    mf.verbose = 0
    mf.run()
    
    # Store results
    total_energy = mf.e_tot
    calculated_energies.append(total_energy)
    
    time_taken = time.time() - now
    calculation_times.append(time_taken)
    
    print(f"  -> Total Energy: {total_energy:.6f} eV")
    print(f"  -> Time: {time_taken:.2f} seconds")

print("\n--- Convergence Test Finished ---")

# --- Process and Plot Results ---
n_atoms = len(ase_atom)
energies_per_atom = np.array(calculated_energies) / n_atoms

energy_delta_meV = (energies_per_atom - energies_per_atom[-1]) * 1000

# --- Plotting ---
fig, ax1 = plt.subplots(figsize=(12, 7))

# Plot Energy vs. K-mesh size
color = 'tab:red'
ax1.set_xlabel('K-Mesh Size (N x N x N)', fontsize=14)
ax1.set_ylabel('Energy Change (meV/atom)', color=color, fontsize=14)
ax1.plot(k_mesh_sizes, energy_delta_meV, 'o-', color=color, linewidth=2, markersize=8, label='Energy Convergence')
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)
ax1.legend(loc='upper left')

# Plot calculation time on a second y-axis
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Calculation Time (seconds)', color=color, fontsize=14)
ax2.plot(k_mesh_sizes, calculation_times, 's--', color=color, linewidth=2, markersize=8, label='Calculation Time')
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(loc='upper right')

plt.title('K-Point Convergence Test for Si', fontsize=16)
fig.tight_layout()
plt.show()

# Print final results
print("\n--- Results Summary ---")
for i, n in enumerate(k_mesh_sizes):
    print(f"K-mesh {n}x{n}x{n}: Energy/atom = {energies_per_atom[i]:.6f} eV, Delta = {energy_delta_meV[i]:.2f} meV")
# Out:
# --- Starting K-Point Convergence Test ---
#
# Calculating for k-mesh = [2, 2, 2]...
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyscf/pbc/gto/cell.py:127: UserWarning: Function cell.dumps drops attribute a because it is not JSON-serializable
#   warnings.warn(msg)
#   -> Total Energy: -526.019025 eV
#   -> Time: 237.13 seconds
#
# Calculating for k-mesh = [4, 4, 4]...
#   -> Total Energy: -526.019025 eV
#   -> Time: 276.20 seconds
#
# Calculating for k-mesh = [6, 6, 6]...
#   -> Total Energy: -526.019025 eV
#   -> Time: 280.63 seconds
#
# Calculating for k-mesh = [8, 8, 8]...
#   -> Total Energy: -526.019025 eV
#   -> Time: 304.82 seconds
#
# --- Convergence Test Finished ---
# --- Results Summary ---
# K-mesh 2x2x2: Energy/atom = -43.834919 eV, Delta = 0.00 meV
# K-mesh 4x4x4: Energy/atom = -43.834919 eV, Delta = 0.00 meV
# K-mesh 6x6x6: Energy/atom = -43.834919 eV, Delta = 0.00 meV
# K-mesh 8x8x8: Energy/atom = -43.834919 eV, Delta = 0.00 meV

# %% [markdown]
# Here we compare the time taken by the neural network model to predict the energy of the crystal structure with the time taken by the `pyscf` library to compute the energy using DFT.

# %%
def plot_comparison(time_pyscf, time_nn):
    plt.figure(figsize=(8, 5))
    plt.bar(['PySCF', 'Neural Network'], [time_pyscf, time_nn], color=['blue', 'orange'])
    plt.ylabel('Time (seconds)')
    plt.title('Comparison of Calculation Times in estimating energy')
    plt.grid(axis='y')
    plt.show()

avg_time_pyscf = np.mean(calculation_times)


now = time.time()
model = NeuralNetwork(44)
model.load_state_dict(torch.load('./model/model_9999/model.pkl', map_location=torch.device('cpu')))
model.eval()
data = np.load('./predict_data/predict.npy', allow_pickle=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dataset = PredictDataset(data, device)
dataloader = DataLoader(dataset, batch_size=1)
x, flag_list, struct_name = next(iter(dataloader))
x_var = Variable(x)
output, atom_count = model(x_var, flag_list)
time_nn = time.time() - now

plot_comparison(avg_time_pyscf, time_nn)
print(f"Average time for PySCF: {avg_time_pyscf:.2f} seconds")
print(f"Time for Neural Network: {time_nn:.2f} seconds")
# Out:
# Average time for PySCF: 67.31 seconds
# Time for Neural Network: 1.68 seconds

# %%
import ase.io
from ase.visualize.plot import plot_atoms
import matplotlib.pyplot as plt
import nglview as nv
import random

file_preds = "predict/predict1/result_con.txt"
with open(file_preds, 'r') as f:
    lines = f.readlines()

# shuffle the lines randomly
random.shuffle(lines)
lines = lines[:5]


# Randomly take a .xsf from the test dataset
file_to_read1 = os.path.join(WORKPLACE, 'data/TiO2/raw_data/test')
for i in range(5):
  line = lines[i].strip()
  xsf_id = line.split()[0]
  file_to_read = os.path.join(file_to_read1, f"{xsf_id}")

  print(f"Reading structure from: {file_to_read}")
  ase_atom = ase.io.read(file_to_read)

  fig, ax = plt.subplots()
  plot_atoms(ase_atom, ax, radii=0.5, rotation=('45x,45y,0z'))
  plt.title(f"Structure from {file_to_read}")
  plt.show()

  # Create an interactive view from the ase object
  view = nv.show_ase(ase_atom)
  view.add_unitcell()
  view


  cell = gto.Cell()
  cell.a = ase_atom.cell
  cell.atom = list(zip(ase_atom.get_chemical_symbols(), ase_atom.get_positions()))
  cell.basis = 'gth-szv-molopt-sr'
  cell.pseudo = 'gth-pbe'
  cell.unit = 'A'
  cell.exp_to_discard=0.1
  cell.ke_cutoff = 100
  cell.build()

  kpts = cell.make_kpts([4, 4, 4])

  # Set up and run the DFT calculation
  mf = dft.KRKS(cell, kpts=kpts)
  mf.with_df = df.FFTDF(cell)
  mf.xc = 'pbe'
  mf.conv_tol = 1e-8
  mf.verbose = 0
  mf.run()
  
  # Store results
  total_energy = mf.e_tot
  calculated_energies.append(total_energy)
  
  time_taken = time.time() - now
  calculation_times.append(time_taken)
  
  print(f"  -> Total Energy: {total_energy:.6f} eV")
  print(f"  -> Time: {time_taken:.2f} seconds")
# Out:
# Reading structure from: /Users/matteobalice/Desktop/swarm_intelligence/data/VO2/raw_data/test/structure10001386619.xsf
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyscf/pbc/gto/cell.py:127: UserWarning: Function cell.dumps drops attribute a because it is not JSON-serializable
#   warnings.warn(msg)
#   -> Total Energy: -192.662127 eV
#   -> Time: 373.98 seconds
# Reading structure from: /Users/matteobalice/Desktop/swarm_intelligence/data/VO2/raw_data/test/structure10002351515.xsf
#   -> Total Energy: -201.224771 eV
#   -> Time: 458.19 seconds
# Reading structure from: /Users/matteobalice/Desktop/swarm_intelligence/data/VO2/raw_data/test/structure100000026411.xsf
#   -> Total Energy: -206.845335 eV
#   -> Time: 545.17 seconds
# Reading structure from: /Users/matteobalice/Desktop/swarm_intelligence/data/VO2/raw_data/test/structure100000409522.xsf
#   -> Total Energy: -412.223447 eV
#   -> Time: 760.58 seconds
# Reading structure from: /Users/matteobalice/Desktop/swarm_intelligence/data/VO2/raw_data/test/structure100000160115.xsf
#   -> Total Energy: -413.593496 eV
#   -> Time: 927.25 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np
import time
import torch
from torch.utils.data import DataLoader
from torch.autograd import Variable

def plot_comparison(time_pyscf, time_nn_train_phase1, time_nn_train_phase2, time_nn_pred, factor, ax):
    labels = ['PySCF', 'Neural Network']
    x = np.arange(len(labels))
    width = 0.4

    # Scale times by factor
    pyscf_scaled = time_pyscf * factor
    train1_scaled = time_nn_train_phase1
    train2_scaled = time_nn_train_phase2
    pred_scaled = time_nn_pred * factor

    # PySCF bar
    ax.bar(x[0], pyscf_scaled, width, label='PySCF Time', color='blue')

    # NN stacked bar (train phases + prediction)
    ax.bar(x[1], train1_scaled, width, label='NN Genetic Algorithm', color='green')
    ax.bar(x[1], train2_scaled, width, bottom=train1_scaled, label='NN Training 500 epochs', color='limegreen')
    ax.bar(x[1], pred_scaled, width, bottom=train1_scaled + train2_scaled, label='NN Prediction Time', color='orange')

    ax.set_ylabel('Time (seconds)')
    ax.set_title(f'Scaling factor = {factor}')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.grid(axis='y')

    if factor == 1:
        ax.legend()

avg_time_pyscf = np.mean(calculation_times)

# Load model and measure prediction time (run once)
now = time.time()
model = NeuralNetwork(44)
model.load_state_dict(torch.load('./model/model_9999/model.pkl', map_location=torch.device('cpu')))
model.eval()
data = np.load('./predict_data/predict.npy', allow_pickle=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dataset = PredictDataset(data, device)
dataloader = DataLoader(dataset, batch_size=1)
x, flag_list, struct_name = next(iter(dataloader))
x_var = Variable(x)
output, atom_count = model(x_var, flag_list)
time_nn_pred_original = time.time() - now

# Fixed training times (taken from previous cells)
time_nn_train_phase1 = 3460
time_nn_train_phase2 = 1000

# Plot 10 graphs with 2 per row
fig, axs = plt.subplots(5, 2, figsize=(15, 20))
axs = axs.flatten()

for factor in range(1, 11):
    plot_comparison(avg_time_pyscf, time_nn_train_phase1, time_nn_train_phase2, time_nn_pred_original, factor, axs[factor-1])

plt.tight_layout()
plt.show()
plt.close('all')

# %% [markdown]
# ## Conclusion
#
# This project successfully replicated the methodology presented in *"Swarm intelligence for new materials,"* which introduces a novel hybrid swarm intelligence algorithm designed to optimize neural networks for materials science applications. The primary goal was to develop more stable and efficient models for predicting material properties, thereby reducing dependence on computationally expensive first-principles calculations.
#
# The implementation combined the strengths of a **Genetic Algorithm (GA)**, **Particle Swarm Optimization (PSO)**, and **Bayesian Optimization**. Specifically, PSO was employed as an advanced mutation operator within the GA framework, while Bayesian optimization was incorporated to help escape local optima.
#
# To validate the replication, the optimized neural network was applied to predict the formation energies of several crystal structures, including **Si**, **$TiO_{2}$**, **$VO_{2}$**, and **$CaTiO_{3}$**. In addition, validation was performed through numerical simulations using the PySCF package to ensure consistency with quantum chemical calculations. The results obtained confirm the findings reported in the paper: the hybrid swarm intelligence approach (termed PGB in the original work) consistently outperformed traditional back-propagation neural networks and other combined optimization algorithms. The replicated models demonstrated both higher accuracy and improved training efficiency.
