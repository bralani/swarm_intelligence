# %% [markdown]
# # Swarm intelligence for new materials 🧬🔬
#
# This project implements and explores a novel hybrid swarm intelligence algorithm to optimize neural network parameters for predicting material properties, specifically focusing on crystal structure energies. The approach aims to enhance the efficiency and accuracy of traditional neural network models in the field of computational materials science, aiding in the discovery and design of new materials.
#
# The core methodology is inspired by the paper "Swarm intelligence for new materials", which proposes an improved genetic algorithm (GA) by integrating Particle Swarm Optimization (PSO) and Bayesian optimization techniques.
# The main goal of the paper is to accelerate the discovery and design of new materials. The authors achieve this by creating a novel hybrid swarm intelligence algorithm (combining Genetic Algorithm, Particle Swarm, and Bayesian optimization) to optimize the parameters of neural networks, making them more efficient and accurate.
#
# The neural network is used as a high-speed predictive model to determine the stability of materials predicting the energy of crystal structures based on their local atomic environments. This predictive capability is crucial for identifying stable new materials quickly, which is essential in various applications such as electronics, energy storage, and catalysis.  It acts as a fast and low-cost replacement for expensive first-principles calculations and complex experiments, thereby speeding up the process of identifying stable new materials.

# %% [markdown]
# # Setup phase

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import heapq
import time
import skopt
import os
import shutil
import time
import numpy as np
from sklearn.model_selection import train_test_split
import torch
from torch import nn, optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
import ray

# %%
# Set the random seed for reproducibility
def setup_seed(seed):
   torch.manual_seed(seed)
   np.random.seed(seed)
   random.seed(seed)

setup_seed(38)

# %%
# defining constants
file_scale = './temp_files/scale.txt'
file_shift = './temp_files/shift.txt' 
xsfs = 2240
least_loss = 0.0001
BATCH = 8

# %% [markdown]
# ### What is Ray & Why it's Useful Here? 🚀
# Ray is a framework for running Python applications in parallel, even across multiple machines.
#
# In this project, Ray is used to speed up the optimization process.
# The PGB algorithm needs to train and evaluate many neural networks. Ray allows these evaluations to happen simultaneously on multiple CPU cores.

# %%
WORKPLACE=os.getcwd() 
os.system('ray start --head --port=8381')
ray.init()
# Out:
# 2025-06-07 11:48:56,824	INFO usage_lib.py:472 -- Usage stats collection is enabled. To disable this, add `--disable-usage-stats` to the command that starts the cluster, or run the following command: `ray disable-usage-stats` before starting the cluster. See https://docs.ray.io/en/master/cluster/usage-stats.html for more details.
# 2025-06-07 11:48:56,824	INFO scripts.py:971 -- Local node IP: 127.0.0.1
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.9/bin/ray", line 8, in <module>
#     sys.exit(main())
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/scripts/scripts.py", line 2800, in main
#     return cli()
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/click/core.py", line 1128, in __call__
#     return self.main(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/click/core.py", line 1053, in main
#     rv = self.invoke(ctx)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/click/core.py", line 1659, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/click/core.py", line 1395, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/click/core.py", line 754, in invoke
#     return __callback(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/autoscaler/_private/cli_logger.py", line 823, in wrapper
#     return f(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/scripts/scripts.py", line 997, in start
#     node = ray._private.node.Node(
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/_private/node.py", line 362, in __init__
#     self.start_head_processes()
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/_private/node.py", line 1447, in start_head_processes
#     self._write_cluster_info_to_kv()
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/_private/node.py", line 1402, in _write_cluster_info_to_kv
#     assert curr_val == self._session_name.encode("utf-8"), (
# AssertionError: Session name session_2025-06-07_11-48-56_824762_80805 does not match persisted value b'session_2025-06-01_16-29-34_460187_74454'. Perhaps there was an error connecting to Redis.
# 2025-06-07 11:48:57,835	INFO worker.py:1888 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.9.8', ray_version='2.46.0', ray_commit='c3dd2ca0c2a24ddf327a213d2e936bd4eaa4ca0a')

# %% [markdown]
# # Data Loading

# %% [markdown]
# ### Input to the neural network: Chebyshev Polynomials
#
# **Chebyshev polynomials** are special **orthogonal polynomials** used in approximation theory and numerical methods.
#
# #### Two Main Types
#
# - **First Kind** ($T_n(x)$):
#   - Recurrence:
#     - $T_0(x) = 1$
#     - $T_1(x) = x$
#     - $T_{n+1}(x) = 2xT_n(x) - T_{n-1}(x)$
#   - Alternative definition:
#     - $T_n(x) = \cos(n \arccos(x))$
#
# - **Second Kind** ($U_n(x)$):
#   - Recurrence:
#     - $U_0(x) = 1$
#     - $U_1(x) = 2x$
#     - $U_{n+1}(x) = 2xU_n(x) - U_{n-1}(x)$
#   - Alternative definition:
#     - $U_n(x) = \dfrac{\sin((n+1)\theta)}{\sin(\theta)}$ where $x = \cos(\theta)$
#
# #### Key Properties
#
# - **Orthogonality**:
#   - $T_n(x)$ is orthogonal on $[-1, 1]$ with weight $1/\sqrt{1 - x^2}$
#   - $U_n(x)$ is orthogonal on $[-1, 1]$ with weight $\sqrt{1 - x^2}$
#
# - **Roots (Chebyshev Nodes)**:
#   - Roots of $T_n(x)$ minimize interpolation error and reduce Runge's phenomenon.
#
# - **Minimax Property**:
#   - $T_n(x)$ minimizes the maximum deviation from zero on $[-1, 1]$ among monic polynomials.
#
# - **Application in ML**:
#   - Used to describe atomic environments as inputs for neural networks in materials science.

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial import chebyshev

# Generate x values in [-1, 1]
x = np.linspace(-1, 1, 400)

# Plot first 5 Chebyshev polynomials of the first kind (T0 to T4)
plt.figure(figsize=(8, 6))
for n in range(5):
    y = chebyshev.Chebyshev.basis(n)(x)
    plt.plot(x, y, label=f'$T_{n}(x)$')

plt.title('Chebyshev Polynomials of the First Kind')
plt.xlabel('$x$')
plt.ylabel('$T_n(x)$')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def train_prepare():
    with open( './train/generate.in', 'r') as f_read:
        for i, line in enumerate(f_read):
            if i == 3:
                num_type = int(line.split()[0]) 
    if num_type == 1:
        nfeatures = 22
    else:
        nfeatures = 44
    return nfeatures,num_type

nfeatures, num_type = train_prepare()

# %%
from get_dataset import get_dataset

# Load the dataset for training
data = get_dataset('./train', '/train/trainset_with_scaled_normalized.txt', nfeatures)

print(f"Number of features: {nfeatures}, Type: {num_type}")
print("Data loaded successfully.")
# Out:
# Number of features: 44, Type: 2
# Data loaded successfully.

# %%
samples_to_plot = 3

for i in range(samples_to_plot):
  if i < len(data):
    coeff_list = data[i][0]

    coeff_values = np.array(coeff_list, dtype=float)
    coeff_values = coeff_values.reshape(-1, nfeatures).T
    
    print(f"Plotting Sample {i}, Shape of feature values: {coeff_values.shape}")

    plt.figure(figsize=(10, 4))
    plt.plot(coeff_values, marker='o', linestyle='-')
    plt.title(f"Chebyshev Features for Sample {i}")
    plt.xlabel("Feature Index")
    plt.ylabel("Feature Value")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
  else:
    print(f"Sample index {i} is out of bounds for the loaded data (size: {len(data)}).")
    break
# Out:
# Plotting Sample 0, Shape of feature values: (44, 30)
# Plotting Sample 1, Shape of feature values: (44, 30)
# Plotting Sample 2, Shape of feature values: (44, 30)

# %% [markdown]
# # Neural Network
#
# The neural network is used to **predict the energy of crystal structures**. The goal is to build a model that can learn the relationship between a material's atomic structure and its energy. This approach aims to speed up the discovery and design of new materials.
#
# ### Core Purpose
# * The network is designed to fit the atomic energy of crystal structures, working on the principle that structures will favor lower energy states.
# * It calculates the energy for each atom in a crystal; these individual atomic energies are then summed up in the output layer to determine the total energy of the entire structure.
#
# ### Neural Network Architecture
# * The network consists of four layers:
#     * One **input layer** (which takes the Chebyshev polynomial descriptors).
#     * Two **hidden layers**.
#     * One **output layer** (which outputs the fitted atomic energy).
# * Each of the two hidden layers is composed of 10 neurons.
#
# <p align="center">
#   <img src="./img/neural_network.png" alt="Neural network" width="800"/>
# </p>

# %%
file_scale = './temp_files/scale.txt'
scale = 0
    
class NeuralNetwork(nn.Module):
    def __init__(self, nfeat, w_b = None):
        super().__init__()
        self.nfeat = nfeat
        self.types = self._load_types('./train/generate.in')
        architecture = nn.Sequential(
                    nn.Linear(self.nfeat, 10),
                    nn.Tanh(),
                    nn.Linear(10, 10),
                    nn.Tanh(),
                    nn.Linear(10, 1)
                )
        for t in self.types:
            setattr(self, f"{t}_forward", architecture)

        if w_b is not None:
            self._assign_weights(w_b)

    def _load_types(self, filepath):
        with open(filepath, 'r') as f:
            lines = f.readlines()
        num_type = int(lines[3].split()[0])
        return [lines[i].split()[0] for i in range(4, 4 + num_type)]

    def _assign_weights(self, w_b):
        for idx, module in enumerate(
            filter(lambda m: isinstance(m, nn.Linear), self.modules()), start=1
        ):
            w_key, b_key = f"w_{idx}", f"b_{idx}"
            if w_key in w_b and b_key in w_b:
                module.weight = nn.Parameter(w_b[w_key])
                module.bias = nn.Parameter(w_b[b_key])

    def forward(self, x, flag_list):
        outputs = []
        tmp_all = []

        for sample_idx in range(x.size(0)):
            tmp = []
            for feature_idx, flag in enumerate(flag_list):
                forward_name = f"{flag[sample_idx]}_forward"
                if hasattr(self, forward_name):
                    forward_func = getattr(self, forward_name)
                    tmp.append(forward_func(x[sample_idx][feature_idx]))
            tmp_all.append(len(tmp))
            outputs.append(torch.stack(tmp, 0).sum())

        out_tensor = torch.stack(outputs, 0).view(x.size(0), 1)
        return out_tensor, tmp_all

# %% [markdown]
# ## Initialization parameters of the neural network
#
# Here we initialize the parameters of the neural network such that they are compatible with our architecture. These parameters will be optimized during the training process.

# %%
def _extract_and_shape_single_network_params(popunum_block, nfeatures, key_idx_prefix):
    params = {}
    current_idx = 0

    layer_configs = [
        (10, nfeatures),  # Layer 1: nfeatures -> 10
        (10, 10),         # Layer 2: 10 -> 10
        (1, 10),          # Layer 3: 10 -> 1
    ]

    for i, (out_dim, in_dim) in enumerate(layer_configs):
        # Weights
        w_len = out_dim * in_dim
        params[f'w_{key_idx_prefix + i}'] = torch.Tensor(
            popunum_block[current_idx : current_idx + w_len]
        ).view(out_dim, in_dim)
        current_idx += w_len

        # Biases
        b_len = out_dim  # Bias has 'out_dim' elements
        params[f'b_{key_idx_prefix + i}'] = torch.Tensor(
            popunum_block[current_idx : current_idx + b_len]
        )
        current_idx += b_len
    
    return params

def init_w_b(popunum, num_type, nfeatures):
    
    all_network_params = {}
    current_popunum_offset = 0

    elements_per_network_block = (10 * nfeatures) + 10 + (10 * 10) + 10 + (1 * 10) + 1

    for i in range(num_type):
        key_idx_prefix_for_current_block = (3 * i) + 1
        
        start_idx = current_popunum_offset
        end_idx = current_popunum_offset + elements_per_network_block
        popunum_block = popunum[start_idx:end_idx]
        
        block_params = _extract_and_shape_single_network_params(
            popunum_block, nfeatures, key_idx_prefix_for_current_block
        )
        all_network_params.update(block_params)
        
        current_popunum_offset = end_idx
        
    return all_network_params

# %% [markdown]
# # Loss Function: RMSE
#
# The loss is computed using the formula:
#
# $$
# \text{loss} = \frac{1}{s} \sqrt{ \frac{1}{M} \sum_{i=1}^{M} \frac{1}{2} \left( \frac{x_i - y_i}{N} \right)^2 }
# $$
#
# where M is the total number of elements in the batch, N is the number of atoms in the crystal structure, and s is a scaling factor.

# %%
class RMSE(nn.Module):
  def __init__(self):
    super(RMSE, self).__init__()
  def forward(self, inputs, targets, natoms):
    global scale
    if scale == 0 and os.path.exists(file_scale):
        with open(file_scale, 'r') as f:
            for line in f:
                scale = float(line.strip().split()[0])
    loss = torch.pow((inputs - targets) / torch.tensor(natoms), 2) * 0.5
    loss = loss.mean().sqrt() / scale
    return loss

# %% [markdown]
# ## Early Stopping
# Early stopping is a technique used to prevent overfitting during training. It monitors the validation loss and stops training when the loss does not improve for a specified number of epochs (patience). This helps in finding the optimal model without unnecessary training.

# %%
class EarlyStopping:
    def __init__(self, patience=10, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss)
            self.counter = 0

    def save_checkpoint(self, val_loss):
        self.val_loss_min = val_loss

# %% [markdown]
# ## Training process
#
# The training process involves the following steps:
# 1. **Data Preparation**: Load the crystal structures and their corresponding energies, shuffle the data and splitting it into batches.
# 2. **Model Initialization**: Create the neural network model with the specified architecture.
# 3. **Training Loop**:
#    - For each epoch:
#      - For each batch:
#        - Forward pass: Compute the predicted energies using the neural network.
#        - Compute the loss using the RMSE function.
#        - Backward pass: Update the model parameters using the optimizer.
#         - Check for early stopping conditions.
# 4. **Validation**: After each epoch, evaluate the model on the validation set to monitor performance.
#
# All this is done in parallel using Ray to speed up the training process among multiple CPU cores (and many neural networks). Moreover the optimization process is done using the PGB algorithm (explained later).

# %%
from get_dataset import TrainDataset

def train_process(nfeat, popunum, f_main, thread_index):
    setup_seed(100)
    
    with open('./train/generate.in', 'r') as f_read:
        for i, line in enumerate(f_read):
            if i == 3:
                num_type = int(line.split()[0])

    w_b = init_w_b(popunum, num_type, nfeat)
    
    train_data, vali_data = train_test_split(data, test_size=0.1, random_state=42)

    device = torch.device("cuda" if thread_index == 9999 and torch.cuda.is_available() else "cpu")
    
    train_dataset = TrainDataset(train_data, device)
    vali_dataset = TrainDataset(vali_data, device)
    train_loader = DataLoader(train_dataset, batch_size=BATCH, shuffle=True)
    vali_loader = DataLoader(vali_dataset, batch_size=1, shuffle=False)

    model = NeuralNetwork(nfeat, w_b).to(device)
    min_vali, history_train, history_val = train_model(model, train_loader, vali_loader, f_main, thread_index, device)
    
    return min_vali, history_train, history_val


def train_model(model, train_loader, vali_loader, f_main, thread_index, device):
    EPOCHS = 10 if thread_index == 9999 else 1
    min_vali = float('inf')

    criterion = RMSE()
    optimizer = optim.Adamax(model.parameters(), lr=1e-3, betas=(0.9, 0.999), eps=1e-8, weight_decay=0)
    early_stopping = EarlyStopping(patience=40, verbose=True)

    history_train_loss = []
    history_vali_loss = []

    for epoch in range(EPOCHS):
        st = time.time()
        loss_train, loss_vali, real_loss = {}, {}, {}

        # === Training ===
        model.train()
        for i, (x, flag_list, y, struct_name) in enumerate(train_loader, start=1):
            x = x
            y = y
            flag_list = flag_list

            out, num_nopad = model(x, flag_list)
            loss = criterion(out, y, num_nopad)

            loss_train[struct_name] = loss.item()

            optimizer.zero_grad()
            if loss.item() != 0.0:
                loss.backward()
            optimizer.step()

        train_loss = sum(loss_train.values()) / len(loss_train)
        history_train_loss.append(train_loss)

        # === Validation ===
        model.eval()
        with torch.no_grad():
            for i, (x, flag_list, y, struct_name) in enumerate(vali_loader, start=1):
                x = x
                y = y
                flag_list = flag_list

                out, num_nopad = model(x, flag_list)
                loss = criterion(out, y, num_nopad)
                loss_vali[struct_name] = loss.item()

                real_diff = (out.data[0] - y.data[0]) / scale
                real_loss[struct_name] = abs(real_diff)

        avg_real_loss = sum(real_loss.values()).numpy()[0] / len(real_loss)
        max_real_loss = max(real_loss.values()).numpy()[0]
        vali_loss = sum(loss_vali.values()) / len(loss_vali)
        history_vali_loss.append(vali_loss)

        print(f"[{epoch:03d}/{EPOCHS}], time: {time.time() - st:.3f}s, "
              f"train_loss: {train_loss:.6f}, vali_loss: {vali_loss:.6f}, "
              f"avg_real_loss: {avg_real_loss:.6f}, max_real_loss: {max_real_loss:.6f}")

        early_stopping(vali_loss)
        model_dir = os.path.join(WORKPLACE, 'model', 'model_' + str(thread_index) + '/model.pkl')
        print(f"Model directory: {model_dir}")

        if vali_loss < min_vali:
            min_vali = vali_loss
            print(f"Saving model to {model_dir}")
            torch.save(model.state_dict(), model_dir)

        if early_stopping.early_stop:
            break

    return min_vali, history_train_loss, history_vali_loss

# %% [markdown]
# ## Fitness Evaluation
# The fitness evaluation is a crucial step in the genetic algorithm where each individual in the population is assessed based on how well it performs the task at hand. In our case, the task is to train a neural network to predict the energy of crystal structures.

# %%
@ray.remote
def fitnessFunction(population_vector, thread_index):
    log_path = f'output_all/log{thread_index}.txt'
    with open(log_path, 'a+') as log_file:

        temp_file = os.path.join(WORKPLACE, 'train', 'file.temp')
        if os.path.exists(temp_file):
            os.remove(temp_file)

        os.system(f'cp {WORKPLACE}/train/generate.in ./temp_files/')

        model_path = os.path.join(WORKPLACE, 'train', 'model.pkl')
        if os.path.exists(model_path):
            os.remove(model_path)

        n_features = 44
        min_val, history_train, history_val = train_process(n_features, population_vector, log_file, thread_index)

    return -min_val, history_train, history_val

# Calculates the fitness value of a population of chromosomes by evaluating each 
# chromosome's performance.
def getFitnessValue(decode, thread_index=0):

    history_train = []
    history_val = []
    
    if thread_index == 9999:
        fitness_value, history_train, history_val = ray.get(fitnessFunction.remote(decode, thread_index))
        fitness_values = np.array([fitness_value])
    else:
        pop_size, _ = decode.shape
        results = [fitnessFunction.remote(decode[i], i) for i in range(pop_size)]
        fitness_values = np.array([res[0] for res in ray.get(results)])

    total_fitness = np.sum(fitness_values)
    probability = fitness_values / total_fitness if total_fitness != 0 else np.ones_like(fitness_values) / len(fitness_values)
    cum_probability = np.cumsum(probability)

    return fitness_values, cum_probability, history_train, history_val

# %% [markdown]
# # PGB (Particle swarm Genetic Bayesian) Algorithm
# The PGB algorithm is a hybrid method that mixes Genetic Algorithm (GA), Particle Swarm Optimization (PSO), and Bayesian Optimization to fine-tune neural network parameters, especially for materials science. The main goal is to boost model's accuracy (at the cost of some computational resources).
#
# ## How PGB Works
#
# 1.  **Start**: It begins by setting up the neural network and creating an initial "population" of possible parameter sets.
# 2.  **Check Fitness**: Each parameter set is tested by training a neural network and seeing how well it performs.
# 3.  **Bayes optimization**: If the algorithm isn't finding better solutions after a while, Bayesian optimization steps in to suggest new, diverse parameter sets to try.
# 4.  **Evolve**: The algorithm then uses GA techniques:
#     * **Selection**: Good-performing parameter sets are chosen.
#     * **Crossover**: These sets are combined, notably by mixing them with the current best-performing set.
#     * **Mutation**: Parameters are slightly changed using a mix of PSO-like adjustments and standard random changes. The balance between these mutation types adapts as the search progresses.
# 5.  **Repeat**: These steps are repeated until a stopping condition is met. The best parameters found are then used for the final neural network training.
#
# ## Why PGB?
#
# By blending these techniques, PGB aims to:
# * Explore a wide range of possible solutions (thanks to GA).
# * Quickly find promising areas (thanks to PSO).
# * Avoid getting stuck on solutions that aren't truly the best (thanks to Bayesian Optimization).
#
# The overall aim is to get more stable, efficient, and precise neural network models for tasks like predicting material energies.
#
#
# <p align="center">
#   <img src="./img/full_algorithm.png" alt="Alt text" width="800"/>
# </p>

# %% [markdown]
# # Genetic Algorithm (GA) Overview
#
# The genetic algorithm (GA) is an optimization method inspired by the process of biological evolution, specifically the concept of "natural selection, survival of the fittest".
#
# 1.  **Initialization**: The process begins by creating an initial population of individuals. Each individual represents a potential solution and is typically encoded in some form (e.g., as a string of parameters).
# 2.  **Fitness Evaluation**: Each individual in the population is evaluated based on a "fitness value". This value quantifies how good the solution represented by the individual is. For instance, the root mean square error (RMSE) can be used as a fitness value, where a lower RMSE indicates a better fitness.
# 3.  **Selection**: Individuals are selected from the current population to create a basis for the next generation. This selection is typically based on their fitness values, with fitter individuals having a higher chance of being chosen.
# 4.  **Genetic Operators**:
#     * **Crossover**: New individuals (offspring) are generated by combining genetic material from selected parent individuals. This involves exchanging parts of their encoded representations (chromosomes). In a specific application mentioned, each individual might be crossed with the current global best individual in the population.
#     * **Mutation**: Random alterations are introduced into the new individuals at a certain probability. This helps maintain diversity in the population and explore new areas of the solution space. One form of mutation is real number mutation, where a gene of an individual is randomly changed within a defined range.
# 5.  **New Generation and Iteration**: The new individuals generated through crossover and mutation form the next generation of the population. This entire process (fitness evaluation, selection, crossover, and mutation) is repeated for a number of generations or until certain convergence conditions are met, such as reaching a maximum number of iterations or when the improvement in fitness stagnates.
#
# The goal is that over generations, the population will evolve towards better solutions to the problem being optimized.
#
# <p align="center">
#   <img src="./img/genetic_flowchart.jpg" alt="Alt text" width="300"/>
# </p>

# %% [markdown]
# ## Initialization
#
# The initialization of the genetic algorithm involves setting up the initial population of individuals, each representing a potential solution to the optimization problem. The parameters for each individual are randomly generated within specified ranges.

# %%
from scipy.optimize import fsolve

# Generates an initial binary population (chromosomes) for a genetic algorithm.
def getinitialPopulation(length, populationSize):
  chromsomes = np.zeros((populationSize, length), dtype=int)
  for popusize in range(populationSize):
      chromsomes[popusize, :] = np.random.randint(0, 2, length)
  return chromsomes

# %% [markdown]
# ## Encoding and Decoding
#
# In the context of the genetic algorithm, encoding refers to how the parameters of each individual are represented. In this case, each individual is encoded as a list of binary numbers, where each number corresponds to a specific parameter of the neural network. On the other hand, decoding is the process of converting these encoded parameters back into a format that can be used by the neural network. This typically involves mapping the binary numbers to the actual weights and biases of the neural network.

# %%
# Calculates the number of bits needed to encode each decision variable based on its range 
# and a desired precision (delta).
def getEncodeLength(decisionvariables, delta):
  lengths = []
  for decisionvar in decisionvariables:
      uper = decisionvar[1]
      low = decisionvar[0]
      res = fsolve(lambda x: ((uper - low) / delta - 2 ** x + 1), 30)
      length = int(np.ceil(res[0]))
      lengths.append(length)
  return lengths

# Converts a binary chromosome to a binary representation of real values based on the encoding length and decision range.
def getEncodeBinary(real_values, encode_length, decision_range):
  lower, upper = decision_range[0]
  num_bits = encode_length[0]

  # Scale and quantize
  normalized = ((real_values - lower) / (upper - lower)) * (2 ** num_bits - 1)
  quantized = np.round(normalized).astype(int)

  # Convert to binary strings and pad
  def to_binary(x):
    return list(map(int, format(x, f'0{num_bits}b')))

  binary_encoded = np.array([to_binary(val) for val in quantized.flatten()])
  binary_encoded = binary_encoded.reshape(real_values.shape[0], -1)

  return binary_encoded

# Converts a binary population (chromosomes) back to real values based on the encoding length and decision range.
def getDecode(binary_population, encode_length, decision_range):
  lower, upper = decision_range[0]
  num_bits = encode_length[0]
  n_samples = binary_population.shape[0]
  n_vars = binary_population.shape[1] // num_bits

  # Reshape and interpret as binary integers
  reshaped = binary_population.reshape(n_samples, n_vars, num_bits)
  powers = 2 ** np.arange(num_bits - 1, -1, -1)
  integer_values = np.sum(reshaped * powers, axis=2)

  # Scale back to real values
  real_values = lower + integer_values * (upper - lower) / (2 ** num_bits - 1)
  return real_values

# %% [markdown]
# ## Selection population
# The selection process in a genetic algorithm is designed to choose individuals from the current population to create the next generation. The goal is to favor individuals with higher fitness values, ensuring that better solutions have a higher chance of being passed on.
#
#
# <p align="center">
#   <img src="./img/selection.png" alt="Selection" width="700"/>
# </p>

# %%
def selectNewPopulation(decoded_population, cumulative_probabilities):
    num_individuals, _ = decoded_population.shape
    new_population = np.zeros_like(decoded_population)

    for i in range(num_individuals):
        r = np.random.rand()
        for j in range(num_individuals):
            if r < cumulative_probabilities[j]:
                new_population[i] = decoded_population[j]
                break

    return new_population


def evaluate_population(binary_population, encoding_lengths, variable_bounds):
    decoded_population = getDecode(binary_population, encoding_lengths, variable_bounds)
    fitness_values, cumulative_probabilities, _, _ = getFitnessValue(decoded_population)
    return decoded_population, fitness_values, cumulative_probabilities

# %% [markdown]
# ## Crossover
# Crossover is a genetic operator used to combine the genetic information of two parent individuals to create one or more offspring. This process mimics biological reproduction and is essential for introducing diversity into the population.
#
# <p align="center">
#   <img src="./img/crossover.png" alt="Selection" width="1000"/>
# </p>

# %%
# performs crossover on a population based on the best individual.
def crossover_population(population, crossover_prob, fitness_scores):
    num_individuals, num_genes = population.shape
    best_idx = np.argmax(fitness_scores)
    num_to_cross = int(np.round(num_individuals * crossover_prob))

    # Ensure an even number for pairing
    if num_to_cross % 2 != 0:
        num_to_cross += 1

    # Prepare new population
    new_population = np.copy(population)

    # Select individuals for crossover
    selected_indices = random.sample(range(num_individuals), num_to_cross)
    
    for idx in selected_indices:
        crossover_point = np.random.randint(1, num_genes)  # avoid 0 to prevent no crossover
        if np.random.rand() < 0.5:
            new_population[idx, crossover_point:] = population[best_idx, crossover_point:]
        else:
            new_population[idx, :crossover_point] = population[best_idx, :crossover_point]

    return new_population

# Selects the top individuals from a population based on their fitness scores.
def select_top_individuals(population, fitness_scores, num_selected, top_k):
    flat_scores = fitness_scores.flatten()
    top_indices = heapq.nlargest(top_k, range(len(flat_scores)), key=flat_scores.__getitem__)
    
    top_population = np.zeros((num_selected, population.shape[1]))
    top_fitness = np.zeros(num_selected)

    for i, idx in enumerate(top_indices[:num_selected]):
        top_population[i] = population[idx]
        top_fitness[i] = fitness_scores[idx]

    return top_population, top_fitness

# %% [markdown]
# ## Mutation
# Mutation is a genetic operator used in genetic algorithms to introduce random changes to individuals in the population. This process helps maintain genetic diversity and allows the algorithm to explore new areas of the solution space. In
#
# * Randomly alters genes in individuals.
# * Helps explore **new areas** of the search space.
# * Reduces risk of **premature convergence**.
#
# <p align="center">
#   <img src="./img/mutation.png" alt="Selection" width="1000"/>
# </p>
#
# ### PSO (Particle Swarm Optimization)
# PSO improves individuals by learning from their own best past performance, called the personal best, and from the best solution found by the entire population, called the global best. It balances exploration, which is trying new solutions, and exploitation, which is refining good ones. PSO uses a velocity-based update to guide the movement of individuals through the solution space.
#
# <p align="center">
#   <img src="./img/particle_swarm.png" alt="Selection" width="400"/>
# </p>

# %%
def apply_mutation_and_pso(population, fitness_values, pso_idx, mutation_idx, mutation_prob):

    # --- PSO hyperparameters ---
    w_inertia = 0.5
    c_personal = 2.0
    c_social = 3.0
    value_bounds = (-1.0, 1.0)

    # Find global and personal bests
    global_best = population[np.argmax(fitness_values)].copy()
    personal_best = population[pso_idx].copy()

    # Apply mutation to the selected individual
    population[mutation_idx] = mutate_individual(population[mutation_idx], mutation_prob)

    # PSO-style update to the selected individual
    r1, r2 = np.random.rand(2)
    current = population[pso_idx]
    velocity_update = (
        w_inertia * current +
        c_personal * r1 * (personal_best - current) +
        c_social * r2 * (global_best - current)
    )
    # Clamp to bounds
    population[pso_idx] = np.clip(velocity_update, *value_bounds)

    return population

# Mutates an individual by randomly changing a certain number of genes based on the mutation probability.
def mutate_individual(individual, mutation_prob):
    mutated = np.copy(individual)
    num_genes = mutated.shape[-1]

    # Flatten if needed
    if mutated.ndim == 2:
        mutated = mutated.reshape(-1, num_genes)

    total_genes = mutated.size
    num_mutations = int(total_genes * mutation_prob)
    indices_to_mutate = random.sample(range(total_genes), num_mutations)

    for idx in indices_to_mutate:
        row = idx // num_genes
        col = idx % num_genes
        mutated[row, col] = np.random.uniform(-1.0, 1.0)

    return mutated

# %% [markdown]
# Function to perform crossover and mutation.

# %%
def crossover_and_mutate(population, crossover_probability, fitness, encoding_lengths, bounds, stagnation_counter, initial_pso_rate, mutation_base_prob):
    crossed_population = crossover_population(population, crossover_probability, fitness)
    decoded_crossed = getDecode(crossed_population, encoding_lengths, bounds)

    pso_rate = max(0, initial_pso_rate - 0.1 * stagnation_counter)
    mutation_prob = min(0.5, mutation_base_prob * stagnation_counter)

    population_size = decoded_crossed.shape[0]
    pso_indices = random.sample(range(population_size), int(population_size * pso_rate))
    other_indices = list(set(range(population_size)) - set(pso_indices))

    mutated_decoded = apply_mutation_and_pso(decoded_crossed, fitness, pso_indices, other_indices, mutation_prob)
    mutated_population = getEncodeBinary(mutated_decoded, encoding_lengths, bounds)

    return mutated_population, mutated_decoded

# %% [markdown]
# ## Bayesian Optimization
#
# Bayesian Optimization is a strategy for global optimization of expensive-to-evaluate functions. It builds a probabilistic model (e.g., Random Forest, Gaussian Process) of the objective function and uses it to select the most promising points to evaluate next, balancing exploration and exploitation.
# In our case we use the random forest in a search space of `[-1.0, 1.0]` for each parameter with the Expected Improvement (EI) acquisition function.
#
# **Expected Improvement (EI)** quantifies how much improvement over the current best solution is expected by sampling a candidate point. It guides the optimizer to choose points that either have high predicted performance or high uncertainty, effectively balancing exploration of unknown areas and exploitation of known good areas.
#
# The optimizer:
# 1. Receives past samples (`tell`) with their fitness.
# 2. Suggests new candidates (`ask`) to improve the current solution.

# %%
def get_num_para_from_input(file_path='./train/generate.in', target_line=3):
    with open(file_path, 'r') as f:
        for i, line in enumerate(f):
            if i == target_line:
                num_type = int(line.split()[0])
                break
    return {1: 351, 2: 1142, 3: 1713}.get(num_type, None)

num_para = get_num_para_from_input()

# Initialize the Bayesian optimizer
opt_bayes = skopt.Optimizer(
    [skopt.space.Real(-1.0, 1.0, name=f'x{i}') for i in range(num_para)],
    n_initial_points=0,
    base_estimator='RF',
    acq_func='EI',
    acq_optimizer='auto',
    random_state=0,
    n_jobs=10,
)

def bayesian_optimization_step(
    combined_population, combined_decoded, combined_fitness,
    encoding_lengths, bounds, resolution,
    bayes_pool_decoded, bayes_pool_fitness,
    n_replace=10
):
    # Inform the Bayesian optimizer about the current sampled points and their (negated) fitness
    opt_bayes.tell(bayes_pool_decoded.tolist(), (-1 * bayes_pool_fitness).tolist())

    # Request new candidate points from the Bayesian optimizer
    new_candidates = np.array(opt_bayes.ask(n_replace))

    # Evaluate the fitness of the new candidates
    new_fitness_values, _, _, _ = getFitnessValue(new_candidates)

    # Encode the new candidates into the binary representation used by the population
    new_encoded_candidates = getEncodeBinary(new_candidates, encoding_lengths, bounds)

    # Find indices of the worst performing individuals to replace
    flat_values = combined_fitness.flatten().tolist()
    worst_indices = list(map(flat_values.index, heapq.nlargest(n_replace, flat_values)))

    # Replace the worst individuals with the new candidates
    combined_population[worst_indices] = new_encoded_candidates
    combined_decoded[worst_indices] = new_candidates
    combined_fitness[worst_indices] = new_fitness_values

    return new_candidates, new_fitness_values

# %% [markdown]
# ## Training without PGB
# First, we train the neural network without the PGB algorithm to establish a baseline performance.

# %%
# Plot the training and validation loss history
def plot_loss_history(history_train, history_val):
  plt.figure(figsize=(12, 6))
  plt.plot(history_train, label='Training Loss', color='blue')
  plt.plot(history_val, label='Validation Loss', color='orange')
  plt.title('Training and Validation Loss History')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)

# %%
BOUNDS = [[-1.0, 1.0]] * num_para
RESOLUTION = 0.0001

# Initialize population and encoding
encoding_lengths = getEncodeLength(BOUNDS, RESOLUTION)
population = getinitialPopulation(sum(encoding_lengths), 1)
parameters = getDecode(population, encoding_lengths, BOUNDS)

min_vali, cum_proba, history_train, history_val = getFitnessValue(np.array(parameters[0]), 9999)
plot_loss_history(history_train, history_val)

print("Best fitness value:", min_vali)
# Out:
# (raylet) Warning: The remote function __main__.fitnessFunction is very large (55 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# (fitnessFunction pid=80830) /var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/3075854479.py:14: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:212.)
# (fitnessFunction pid=80830) [000/10], time: 3.265s, train_loss: 2.139261, vali_loss: 1.145608, avg_real_loss: 19.198627, max_real_loss: 69.779732
# (fitnessFunction pid=80830) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) [001/10], time: 3.083s, train_loss: 1.317003, vali_loss: 0.782396, avg_real_loss: 13.146425, max_real_loss: 57.032284
# (fitnessFunction pid=80830) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) [002/10], time: 3.004s, train_loss: 0.917324, vali_loss: 0.568461, avg_real_loss: 9.606281, max_real_loss: 46.253864
# (fitnessFunction pid=80830) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) [003/10], time: 2.985s, train_loss: 0.686924, vali_loss: 0.436177, avg_real_loss: 7.379189, max_real_loss: 38.183994
# (fitnessFunction pid=80830) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) [004/10], time: 2.994s, train_loss: 0.548603, vali_loss: 0.368882, avg_real_loss: 6.244559, max_real_loss: 31.975151
# (fitnessFunction pid=80830) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) [005/10], time: 3.275s, train_loss: 0.479738, vali_loss: 0.338738, avg_real_loss: 5.648521, max_real_loss: 26.307373
# (fitnessFunction pid=80830) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) [006/10], time: 3.708s, train_loss: 0.436573, vali_loss: 0.315928, avg_real_loss: 5.224452, max_real_loss: 21.969522
# (fitnessFunction pid=80830) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) [007/10], time: 3.168s, train_loss: 0.405700, vali_loss: 0.306851, avg_real_loss: 5.024778, max_real_loss: 21.074308
# (fitnessFunction pid=80830) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) [008/10], time: 3.019s, train_loss: 0.382749, vali_loss: 0.290894, avg_real_loss: 4.726568, max_real_loss: 19.680794
# (fitnessFunction pid=80830) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# Best fitness value: [-0.28583653]
# (fitnessFunction pid=80830) [009/10], time: 3.019s, train_loss: 0.365007, vali_loss: 0.285837, avg_real_loss: 4.652790, max_real_loss: 17.706238
# (fitnessFunction pid=80830) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl
# (fitnessFunction pid=80830) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_9999/model.pkl

# %% [markdown]
# # Evaluation on the test set

# %%
from get_dataset import PredictDataset

def predict_model(f_format, nfeat):
    
    model = NeuralNetwork(nfeat)
    model.load_state_dict(torch.load('./model/model_9999/model.pkl', map_location=torch.device('cpu')))
    model.eval()

    # Load prediction data
    data = np.load('./predict_data/predict.npy', allow_pickle=True)

    # Set device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Prepare dataset and dataloader
    dataset = PredictDataset(data, device)
    dataloader = DataLoader(dataset, batch_size=1)

    # Load normalization parameters
    with open(file_scale, 'r') as f:
        scale = float(f.readline().strip().split()[0])
    with open(file_shift, 'r') as f:
        shift = float(f.readline().strip().split()[0])

    predictions_scaled = {}
    predictions_unscaled = {}
    structure_ids = []
    prediction_values = []

    # Run inference
    for x, flag_list, struct_name in dataloader:
        x_var = Variable(x)
        output, atom_count = model(x_var, flag_list)
        
        struct = struct_name[0]
        raw_prediction = output.data[0].item()

        structure_ids.append(struct)
        prediction_values.append(raw_prediction)

        predictions_scaled[struct] = raw_prediction
        predictions_unscaled[struct] = (raw_prediction / scale) + (float(atom_count[0]) * shift)

    # Save predictions to file
    output_path = os.path.join(os.path.abspath(os.path.dirname(f_format)), 'vasp_candidate.txt')
    with open(output_path, 'w') as f:
        for struct in structure_ids:
            f.write(f"{struct},{predictions_unscaled[struct]}\n")

# %% [markdown]
# ## Metrics for Evaluation

# %%
from sklearn.metrics import r2_score
from sklearn import metrics


def result_conn():
    for model_index in range(1, 2):
        result_path = f'./predict/predict{model_index}/'
        ga_predict_file = os.path.join(result_path, 'GA_predict.txt')
        vasp_candidate_file = os.path.join(result_path, 'vasp_candidate.txt')
        result_con_file = os.path.join(result_path, 'result_con.txt')
        dft_result_file = './predict_data/result_DFT.txt'

        def generate_ga_predictions():
            if os.path.exists(ga_predict_file):
                os.remove(ga_predict_file)

            with open(vasp_candidate_file, 'r') as f_read, open(ga_predict_file, 'a') as f_write:
                for line in f_read:
                    parts = line.strip().split(',')
                    if len(parts) >= 2:
                        id_ga = parts[0][8:]
                        energy = parts[1]
                        f_write.write(f'{id_ga} {energy}\n')

        def combine_ga_dft_results():
            if os.path.exists(result_con_file):
                os.remove(result_con_file)

            # Read GA predictions into a dictionary for fast lookup
            ga_predictions = {}
            with open(ga_predict_file, 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) == 2:
                        ga_predictions[parts[0]] = parts[1]

            with open(dft_result_file, 'r') as f_dft, open(result_con_file, 'a') as f_out:
                for line in f_dft:
                    parts = line.strip().split()
                    if len(parts) == 2:
                        id_ga, energy_ga = parts
                        energy_dft = ga_predictions.get(id_ga)
                        if energy_dft is not None:
                            f_out.write(f'{id_ga} {energy_ga} {energy_dft}\n')
                        else:
                            f_out.write(f'{id_ga} {energy_ga}\n')

        generate_ga_predictions()
        combine_ga_dft_results()


def mape(y_true, y_pred):
    return np.mean(np.abs((y_pred - y_true) / y_true)) 

def smape(y_true, y_pred):
    return 2.0 * np.mean(np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true))) 

def RMSE_calu():

    R2_all = []
    MSE_all = []
    RMSE_all = []
    MAE_all = []
    MAPE_all = []

    for model_index in range(1,2):
        result_path = './predict/predict%s/'%model_index
        real = []
        predict = []
        with open(result_path + 'result_con.txt', 'r') as f_read:
            for i, line in enumerate(f_read):
                line = line.strip()
                standred = float(line.split()[1])
                GA_predict = float(line.split()[2])
                real.append(standred)
                predict.append(GA_predict)

        real = np.array(real)
        predict = np.array(predict)
        
        MSE_all.append(metrics.mean_squared_error(real, predict))
        RMSE_all.append(np.sqrt(metrics.mean_squared_error(real, predict)))
        MAE_all.append(metrics.mean_absolute_error(real, predict))
        MAPE_all.append(mape(real, predict))
        R2_all.append(r2_score(real,predict))

def result_conn2():
    for model_index in range(1, 2):
        result_path = f'./predict/predict{model_index}/'
        ga_predict_file = os.path.join(result_path, 'GA_predict.txt')
        ga_predict_num_file = os.path.join(result_path, 'GA_predict_atomenergy_num.txt')
        ga_atomenergy_file = os.path.join(result_path, 'GA_predict_atomenergy.txt')
        dft_numbers_file = './predict_data/numbers.txt'
        dft_atomenergy_file = './predict_data/result_DFT_atomenergy.txt'
        result_con_file = os.path.join(result_path, 'result_con.txt')

        def match_ga_with_atom_counts():
            # Load a mapping from ID → atom count
            id_to_atom_count = {}
            with open(dft_numbers_file, 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) >= 2:
                        id_to_atom_count[parts[0]] = parts[1]

            # Write GA predictions + atom count to a file
            with open(ga_predict_file, 'r') as f_read, open(ga_predict_num_file, 'w') as f_write:
                for line in f_read:
                    parts = line.strip().split()
                    if len(parts) >= 2:
                        xsf_id, energy = parts
                        atom_count = id_to_atom_count.get(xsf_id)
                        if atom_count:
                            f_write.write(f'{xsf_id} {energy} {atom_count}\n')

        def compute_atom_energy():
            # Divide total energy by atom count
            with open(ga_predict_num_file, 'r') as f_read, open(ga_atomenergy_file, 'w') as f_write:
                for line in f_read:
                    parts = line.strip().split()
                    if len(parts) == 3:
                        xsf_id, total_energy, atom_count = parts
                        try:
                            atom_energy = float(total_energy) / float(atom_count)
                            f_write.write(f'{xsf_id} {atom_energy:.6f}\n')
                        except ZeroDivisionError:
                            continue

        def combine_ga_dft_atom_energy():
            if os.path.exists(result_con_file):
                os.remove(result_con_file)

            # Load GA atom energies into a dictionary
            ga_atom_energies = {}
            with open(ga_atomenergy_file, 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) == 2:
                        ga_atom_energies[parts[0]] = parts[1]

            # Combine with DFT atom energies
            with open(dft_atomenergy_file, 'r') as f_read, open(result_con_file, 'w') as f_write:
                for line in f_read:
                    parts = line.strip().split()
                    if len(parts) >= 2:
                        xsf_id, dft_energy = parts
                        ga_energy = ga_atom_energies.get(xsf_id)
                        if ga_energy:
                            f_write.write(f'{xsf_id} {dft_energy} {ga_energy}\n')
                        else:
                            f_write.write(f'{xsf_id} {dft_energy}\n')

        # Run all steps
        match_ga_with_atom_counts()
        compute_atom_energy()
        combine_ga_dft_atom_energy()

def RMSE_calu2():

    R2_all = []
    MSE_all = []
    RMSE_all = []
    L1_all = []
    MAE_all = []
    MAPE_all = []


    for model_index in range(1,2):
        result_path = './predict/predict%s/'%model_index
        real = []
        predict = []
        with open(result_path + 'result_con.txt', 'r') as f_read:
            for i, line in enumerate(f_read):
                line = line.strip()
                standred = float(line.split()[1])
                GA_predict = float(line.split()[2])
                real.append(standred)
                predict.append(GA_predict)


        real = np.array(real)
        predict = np.array(predict)
        
        MSE_all.append(metrics.mean_squared_error(real, predict))
        RMSE_all.append(np.sqrt(metrics.mean_squared_error(real, predict)))
        L1_all.append(np.linalg.norm(real - predict, ord=1) / len(real))
        MAE_all.append(metrics.mean_absolute_error(real, predict))
        MAPE_all.append(mape(real, predict))
        R2_all.append(r2_score(real,predict))
        
    print('MSE',np.mean(MSE_all))
    print('RMSE',np.mean(RMSE_all))
    print('L1',np.mean(L1_all))
    print('MAE',np.mean(MAE_all))
    print('MAPE',np.mean(MAPE_all))
    print('R2',np.mean(R2_all))
    print()

def generate_plots(model_index=1):
    result_path = f'./predict/predict{model_index}/'
    real, predict = [], []
    
    try:
        with open(result_path + 'result_con.txt', 'r') as f_read:
            for line in f_read:
                parts = line.strip().split()
                real.append(float(parts[1]))
                predict.append(float(parts[2]))
    except FileNotFoundError:
        return

    real = np.array(real)
    predict = np.array(predict)

    plt.figure(figsize=(8, 8))
    plt.scatter(real, predict, alpha=0.6, edgecolors='k', s=50)
    
    lim_min = min(real.min(), predict.min())
    lim_max = max(real.max(), predict.max())
    plt.plot([lim_min, lim_max], [lim_min, lim_max], 'r--', linewidth=2, label='Predizione Perfetta')
    
    plt.title('Correlation between real and predicted energy', fontsize=16)
    plt.xlabel('Real energy (per atom)', fontsize=12)
    plt.ylabel('Predicted energy (per atom)', fontsize=12)
    plt.legend()
    plt.grid(True)
    plt.axis('equal')
    
    errors = predict - real
    rmse = np.sqrt(np.mean(errors**2))
    l1 = np.linalg.norm(errors, ord=1) / len(errors)

    plt.figure(figsize=(10, 6))
    plt.hist(errors, bins=40, edgecolor='black', alpha=0.7)
    
    plt.axvline(0, color='r', linestyle='--', linewidth=2, label='Null error')
    
    plt.title('Distribution of prediction errors', fontsize=16)
    plt.xlabel('Error (Predicted - Real)', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.legend()
    plt.grid(axis='y', alpha=0.5)
    
    plt.text(0.95, 0.95, f'L1 = {l1:.4f}', transform=plt.gca().transAxes,
             fontsize=12, verticalalignment='top', horizontalalignment='right',
             bbox=dict(boxstyle='round,pad=0.5', fc='wheat', alpha=0.5))

    plt.tight_layout()
    plt.show()

# %%
if os.path.exists('./predict/predict1'):
    shutil.rmtree('./predict/predict1')
    shutil.rmtree('./predict')
os.mkdir('./predict')
os.mkdir('./predict/predict1')
os.system('cp model/model_9999/model.pkl temp_files/')
os.system('cd temp_files; cp normal_para.txt normal_para_predict.txt')
os.system('cp temp_files/* ./predict/predict1')

predict_model('./predict/predict1/predictset_with_scaled_normalized.txt',nfeatures)

result_conn() 
RMSE_calu()

result_conn2() 
RMSE_calu2()

generate_plots()
# Out:
# MSE 0.28834379201440274
# RMSE 0.5369765283645113
# MAE 0.38237456670000003
# MAPE 0.05324425990544987
# R2 0.5182838844995884

# %% [markdown]
# # Optimization Algorithm: PGB

# %%
# Define parameters constants for the genetic algorithm
BOUNDS = [[-1.0, 1.0]] * num_para
RESOLUTION = 0.0001
POPULATION_SIZE = 20
MAX_GENERATIONS = 10
CROSSOVER_PROB = 0.8
MUTATION_BASE_PROB = 0.1
INITIAL_PSO_RATE = 0.8
STAGNATION_THRESHOLD = 3
BAYES_UPDATE_LIMIT = 5

# %%
from IPython.display import clear_output

# Function to plot fitness over generations
def plot_fitness(fitness_over_time, generation):
    clear_output(wait=True)
    plt.figure(figsize=(8, 4))
    plt.plot(fitness_over_time, label='Fitness')
    plt.xlabel('Generation')
    plt.ylabel('Fitness')
    plt.title(f'Generation {generation}')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Here we define the PGB algorithm, which combines Genetic Algorithm (GA), Particle Swarm Optimization (PSO), and Bayesian Optimization to optimize the neural network parameters.

# %%
def pgb():
    start_time = time.time()

    # Initialize population and encoding
    encoding_lengths = getEncodeLength(BOUNDS, RESOLUTION)
    population = getinitialPopulation(sum(encoding_lengths), POPULATION_SIZE)

    # Optimization state
    best_fitness = float('-inf')
    stagnation_counter = bayes_update_count = 0
    fitness_over_time, best_solutions, best_variables = [], [], []

    # Buffers for Bayesian optimization
    bayes_pool_decoded = np.empty((0, num_para))
    bayes_pool_fitness = np.array([])

    # Initial evaluation
    _, fitness_scores, _ = evaluate_population(
        population, encoding_lengths, BOUNDS
    )

    for generation in range(MAX_GENERATIONS):
        # Variation step: crossover and mutation
        mutated_population, decoded_mutated = crossover_and_mutate(
            population, CROSSOVER_PROB, fitness_scores,
            encoding_lengths, BOUNDS,
            stagnation_counter, INITIAL_PSO_RATE, MUTATION_BASE_PROB
        )

        # Evaluate mutated individuals
        decoded_original = getDecode(population, encoding_lengths, BOUNDS)
        mutated_fitness, _, _, _ = getFitnessValue(decoded_mutated)

        # Update Bayesian pool
        bayes_pool_decoded = np.vstack((bayes_pool_decoded, decoded_mutated))
        bayes_pool_fitness = np.hstack((bayes_pool_fitness, mutated_fitness))

        # Merge populations and fitness
        combined_population = np.vstack((population, mutated_population))
        combined_decoded = np.vstack((decoded_original, decoded_mutated))
        combined_fitness = np.hstack((fitness_scores, mutated_fitness))

        # Perform Bayesian update if stagnated
        if stagnation_counter >= STAGNATION_THRESHOLD:
            bayes_pool_decoded, bayes_pool_fitness = bayesian_optimization_step(
                combined_population, combined_decoded, combined_fitness,
                encoding_lengths, BOUNDS, RESOLUTION,
                bayes_pool_decoded, bayes_pool_fitness
            )
            bayes_update_count += 1

        # Select next generation
        population, fitness_scores = select_top_individuals(combined_population, combined_fitness, POPULATION_SIZE, POPULATION_SIZE)

        # Track best fitness
        current_best_fitness = np.max(combined_fitness)
        fitness_over_time.append(current_best_fitness)

        stagnation_counter += 1
        if current_best_fitness > best_fitness:
            best_fitness = current_best_fitness
            stagnation_counter = 0

        # Store best solution
        best_index = np.argmax(combined_fitness)
        best_solutions.append(current_best_fitness)
        best_variables.append(combined_decoded[best_index].tolist())

        # Plot and log progress
        plot_fitness(fitness_over_time, generation)
        print(f'Generation {generation} time: {time.time() - start_time:.2f}s')

        if bayes_update_count >= BAYES_UPDATE_LIMIT:
            break

    # Return best overall result
    final_idx = np.argmax(best_solutions)
    return best_solutions[final_idx], best_variables[final_idx]

# %% [markdown]
# Here we run the PGB algorithm to optimize the neural network parameters, saving the best parameters found during the optimization process.

# %%
optval, optvar = pgb()

print("Max fitness:", optval)
# Out:
# (fitnessFunction pid=80830) [000/1], time: 11.612s, train_loss: 3.999980, vali_loss: 1.281005, avg_real_loss: 23.412712, max_real_loss: 86.524231
# (fitnessFunction pid=80830) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_2/model.pkl
# (fitnessFunction pid=80830) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_2/model.pkl
# ---------------------------------------------------------------------------
# RayTaskError(RuntimeError)                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 optval, optvar = pgb()
#       3 print("Max fitness:", optval)
#
# Cell In[29], line 18, in pgb()
#      15 bayes_pool_fitness = np.array([])
#      17 # Initial evaluation
# ---> 18 _, fitness_scores, _ = evaluate_population(
#      19     population, encoding_lengths, BOUNDS
#      20 )
#      22 for generation in range(MAX_GENERATIONS):
#      23     # Variation step: crossover and mutation
#      24     mutated_population, decoded_mutated = crossover_and_mutate(
#      25         population, CROSSOVER_PROB, fitness_scores,
#      26         encoding_lengths, BOUNDS,
#      27         stagnation_counter, INITIAL_PSO_RATE, MUTATION_BASE_PROB
#      28     )
#
# Cell In[17], line 17, in evaluate_population(binary_population, encoding_lengths, variable_bounds)
#      15 def evaluate_population(binary_population, encoding_lengths, variable_bounds):
#      16     decoded_population = getDecode(binary_population, encoding_lengths, variable_bounds)
# ---> 17     fitness_values, cumulative_probabilities, _, _ = getFitnessValue(decoded_population)
#      18     return decoded_population, fitness_values, cumulative_probabilities
#
# Cell In[14], line 34, in getFitnessValue(decode, thread_index)
#      32     pop_size, _ = decode.shape
#      33     results = [fitnessFunction.remote(decode[i], i) for i in range(pop_size)]
# ---> 34     fitness_values = np.array([res[0] for res in ray.get(results)])
#      36 total_fitness = np.sum(fitness_values)
#      37 probability = fitness_values / total_fitness if total_fitness != 0 else np.ones_like(fitness_values) / len(fitness_values)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/_private/worker.py:2822, in get(object_refs, timeout)
#    2816     raise ValueError(
#    2817         f"Invalid type of object refs, {type(object_refs)}, is given. "
#    2818         "'object_refs' must either be an ObjectRef or a list of ObjectRefs. "
#    2819     )
#    2821 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2822 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2823 for i, value in enumerate(values):
#    2824     if isinstance(value, RayError):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/_private/worker.py:930, in Worker.get_objects(self, object_refs, timeout, return_exceptions, skip_deserialization)
#     928     global_worker.core_worker.dump_object_store_memory_usage()
#     929 if isinstance(value, RayTaskError):
# --> 930     raise value.as_instanceof_cause()
#     931 else:
#     932     raise value
#
# RayTaskError(RuntimeError): ray::fitnessFunction() (pid=80830, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_2 does not exist.
# (fitnessFunction pid=80829) /var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/3075854479.py:14: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:212.)
# (fitnessFunction pid=80830) [000/1], time: 12.193s, train_loss: 2.012723, vali_loss: 1.130684, avg_real_loss: 18.267869, max_real_loss: 68.997887
# (fitnessFunction pid=80830) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_8/model.pkl
# (fitnessFunction pid=80830) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_8/model.pkl
# 2025-06-07 11:50:19,635	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80830, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_8 does not exist.
# (fitnessFunction pid=80831) [000/1], time: 7.648s, train_loss: 1.158421, vali_loss: 0.561126, avg_real_loss: 9.515057, max_real_loss: 48.662300
# (fitnessFunction pid=80831) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_6/model.pkl
# (fitnessFunction pid=80831) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_6/model.pkl
# (fitnessFunction pid=80827) [000/1], time: 7.584s, train_loss: 2.497071, vali_loss: 0.688207, avg_real_loss: 11.388706, max_real_loss: 63.247963
# (fitnessFunction pid=80827) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_7/model.pkl
# (fitnessFunction pid=80827) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_7/model.pkl
# 2025-06-07 11:50:27,649	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80830, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_9 does not exist.
# 2025-06-07 11:50:27,661	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80827, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_7 does not exist.
# 2025-06-07 11:50:27,663	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80833, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_5 does not exist.
# 2025-06-07 11:50:27,666	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80832, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_3 does not exist.
# 2025-06-07 11:50:27,668	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80829, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_4 does not exist.
# 2025-06-07 11:50:27,671	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80826, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_1 does not exist.
# 2025-06-07 11:50:27,673	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80831, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_6 does not exist.
# 2025-06-07 11:50:27,676	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80828, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_0 does not exist.
# (fitnessFunction pid=80830) [000/1], time: 7.328s, train_loss: 1.370373, vali_loss: 0.782607, avg_real_loss: 12.749296, max_real_loss: 49.640705 [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (fitnessFunction pid=80830) Model directory: /Users/matteobalice/Desktop/swarm_intelligence/model/model_12/model.pkl [repeated 7x across cluster]
# (fitnessFunction pid=80830) Saving model to /Users/matteobalice/Desktop/swarm_intelligence/model/model_12/model.pkl [repeated 7x across cluster]
# 2025-06-07 11:50:34,664	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80831, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_10 does not exist.
# 2025-06-07 11:50:34,672	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80830, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_12 does not exist.
# 2025-06-07 11:50:34,673	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80827, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_11 does not exist.
# 2025-06-07 11:50:35,661	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80828, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_17 does not exist.
# 2025-06-07 11:50:35,663	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80826, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_16 does not exist.
# 2025-06-07 11:50:35,664	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80832, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_14 does not exist.
# 2025-06-07 11:50:35,665	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80829, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_15 does not exist.
# 2025-06-07 11:50:35,666	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80833, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_13 does not exist.
# 2025-06-07 11:50:38,665	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80830, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_19 does not exist.
# 2025-06-07 11:50:38,669	ERROR worker.py:421 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::fitnessFunction() (pid=80827, ip=127.0.0.1)
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/2108335988.py", line 17, in fitnessFunction
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 23, in train_process
#   File "/var/folders/tb/hddnh_pd115f4lqqcsjvkv740000gn/T/ipykernel_80783/1859309.py", line 94, in train_model
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 628, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 502, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/serialization.py", line 473, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(self.name))
# RuntimeError: Parent directory /Users/matteobalice/Desktop/swarm_intelligence/model/model_18 does not exist.

# %% [markdown]
# Here we train the final neural network for 500 epochs using the best parameters found by the PGB algorithm.

# %%
# Perform the final training and evaluation using the optimal parameters
min_vali, cum_proba, history_train, history_val = getFitnessValue(np.array(optvar), 9999)
plot_loss_history(history_train, history_val)

print("Best fitness value:", min_vali)
# Out:
# (fitnessFunction pid=15031) [000/500], time: 4.619s, train_loss: 1.017542, vali_loss: 0.231044, avg_real_loss: 3.952070, max_real_loss: 26.231871
# (fitnessFunction pid=15031) [001/500], time: 4.329s, train_loss: 0.291270, vali_loss: 0.170846, avg_real_loss: 2.909305, max_real_loss: 26.300770
# (fitnessFunction pid=15031) [002/500], time: 5.035s, train_loss: 0.252466, vali_loss: 0.156847, avg_real_loss: 2.658356, max_real_loss: 26.137390
# (fitnessFunction pid=15031) [003/500], time: 4.971s, train_loss: 0.232872, vali_loss: 0.141999, avg_real_loss: 2.451542, max_real_loss: 23.835690
# (fitnessFunction pid=15031) [004/500], time: 4.014s, train_loss: 0.216681, vali_loss: 0.133931, avg_real_loss: 2.294143, max_real_loss: 24.137793
# (fitnessFunction pid=15031) [005/500], time: 3.465s, train_loss: 0.208310, vali_loss: 0.135974, avg_real_loss: 2.316611, max_real_loss: 22.596165
# (fitnessFunction pid=15031) [006/500], time: 3.675s, train_loss: 0.200235, vali_loss: 0.124409, avg_real_loss: 2.115023, max_real_loss: 23.111183
# (fitnessFunction pid=15031) [007/500], time: 4.892s, train_loss: 0.191232, vali_loss: 0.130971, avg_real_loss: 2.197975, max_real_loss: 22.240580
# (fitnessFunction pid=15031) [008/500], time: 4.705s, train_loss: 0.186898, vali_loss: 0.122680, avg_real_loss: 2.058408, max_real_loss: 22.525311
# (fitnessFunction pid=15031) [009/500], time: 4.304s, train_loss: 0.180236, vali_loss: 0.119726, avg_real_loss: 1.975118, max_real_loss: 23.412766
# (fitnessFunction pid=15031) [010/500], time: 4.700s, train_loss: 0.174695, vali_loss: 0.122746, avg_real_loss: 2.050344, max_real_loss: 21.430799
# (fitnessFunction pid=15031) [011/500], time: 4.385s, train_loss: 0.171815, vali_loss: 0.115440, avg_real_loss: 1.951635, max_real_loss: 21.296732
# (fitnessFunction pid=15031) [012/500], time: 3.529s, train_loss: 0.169160, vali_loss: 0.116608, avg_real_loss: 1.938535, max_real_loss: 22.954294
# (fitnessFunction pid=15031) [013/500], time: 3.241s, train_loss: 0.167881, vali_loss: 0.108016, avg_real_loss: 1.842505, max_real_loss: 21.431051
# (fitnessFunction pid=15031) [014/500], time: 3.419s, train_loss: 0.162779, vali_loss: 0.105153, avg_real_loss: 1.824090, max_real_loss: 20.573385
# (fitnessFunction pid=15031) [015/500], time: 3.209s, train_loss: 0.161635, vali_loss: 0.106640, avg_real_loss: 1.800565, max_real_loss: 21.509592
# (fitnessFunction pid=15031) [016/500], time: 3.298s, train_loss: 0.153355, vali_loss: 0.102661, avg_real_loss: 1.752713, max_real_loss: 21.910000
# (fitnessFunction pid=15031) [017/500], time: 3.277s, train_loss: 0.149423, vali_loss: 0.106479, avg_real_loss: 1.775322, max_real_loss: 22.482019
# (fitnessFunction pid=15031) [018/500], time: 3.472s, train_loss: 0.149016, vali_loss: 0.099121, avg_real_loss: 1.694673, max_real_loss: 21.243876
# (fitnessFunction pid=15031) [019/500], time: 3.255s, train_loss: 0.145225, vali_loss: 0.101622, avg_real_loss: 1.710087, max_real_loss: 22.311361
# (fitnessFunction pid=15031) [020/500], time: 3.599s, train_loss: 0.145381, vali_loss: 0.098979, avg_real_loss: 1.682599, max_real_loss: 21.870911
# (fitnessFunction pid=15031) [021/500], time: 3.214s, train_loss: 0.142312, vali_loss: 0.105167, avg_real_loss: 1.773862, max_real_loss: 23.408113
# (fitnessFunction pid=15031) [022/500], time: 3.262s, train_loss: 0.142675, vali_loss: 0.095584, avg_real_loss: 1.645323, max_real_loss: 20.761358
# (fitnessFunction pid=15031) [023/500], time: 3.191s, train_loss: 0.136506, vali_loss: 0.094463, avg_real_loss: 1.629790, max_real_loss: 21.813965
# (fitnessFunction pid=15031) [024/500], time: 3.254s, train_loss: 0.137980, vali_loss: 0.093309, avg_real_loss: 1.614716, max_real_loss: 21.896841
# (fitnessFunction pid=15031) [025/500], time: 3.172s, train_loss: 0.134070, vali_loss: 0.091097, avg_real_loss: 1.595207, max_real_loss: 22.000727
# (fitnessFunction pid=15031) [026/500], time: 3.406s, train_loss: 0.131566, vali_loss: 0.095374, avg_real_loss: 1.624947, max_real_loss: 21.627378
# (fitnessFunction pid=15031) [027/500], time: 3.156s, train_loss: 0.131136, vali_loss: 0.092287, avg_real_loss: 1.594103, max_real_loss: 22.539135
# (fitnessFunction pid=15031) [028/500], time: 3.270s, train_loss: 0.129165, vali_loss: 0.094577, avg_real_loss: 1.629544, max_real_loss: 23.086245
# (fitnessFunction pid=15031) [029/500], time: 3.268s, train_loss: 0.126891, vali_loss: 0.091356, avg_real_loss: 1.594843, max_real_loss: 20.903662
# (fitnessFunction pid=15031) [030/500], time: 3.323s, train_loss: 0.129036, vali_loss: 0.088503, avg_real_loss: 1.550578, max_real_loss: 21.134550
# (fitnessFunction pid=15031) [031/500], time: 3.117s, train_loss: 0.127057, vali_loss: 0.097920, avg_real_loss: 1.675214, max_real_loss: 22.532436
# (fitnessFunction pid=15031) [032/500], time: 3.585s, train_loss: 0.126858, vali_loss: 0.089019, avg_real_loss: 1.549796, max_real_loss: 21.974188
# (fitnessFunction pid=15031) [033/500], time: 3.212s, train_loss: 0.125162, vali_loss: 0.085241, avg_real_loss: 1.508087, max_real_loss: 21.635826
# (fitnessFunction pid=15031) [034/500], time: 3.341s, train_loss: 0.121290, vali_loss: 0.089099, avg_real_loss: 1.560517, max_real_loss: 22.068705
# (fitnessFunction pid=15031) [035/500], time: 3.208s, train_loss: 0.124158, vali_loss: 0.084857, avg_real_loss: 1.493192, max_real_loss: 21.664099
# (fitnessFunction pid=15031) [036/500], time: 3.296s, train_loss: 0.120922, vali_loss: 0.086539, avg_real_loss: 1.515396, max_real_loss: 21.385416
# (fitnessFunction pid=15031) [037/500], time: 3.235s, train_loss: 0.122317, vali_loss: 0.087847, avg_real_loss: 1.530758, max_real_loss: 21.845884
# (fitnessFunction pid=15031) [038/500], time: 3.246s, train_loss: 0.119185, vali_loss: 0.088592, avg_real_loss: 1.546088, max_real_loss: 22.383186
# (fitnessFunction pid=15031) [039/500], time: 3.166s, train_loss: 0.117525, vali_loss: 0.083841, avg_real_loss: 1.485470, max_real_loss: 22.421066
# (fitnessFunction pid=15031) [040/500], time: 3.211s, train_loss: 0.119092, vali_loss: 0.088821, avg_real_loss: 1.528061, max_real_loss: 21.767368
# (fitnessFunction pid=15031) [041/500], time: 3.109s, train_loss: 0.116705, vali_loss: 0.087465, avg_real_loss: 1.526303, max_real_loss: 22.827065
# (fitnessFunction pid=15031) [042/500], time: 3.264s, train_loss: 0.117740, vali_loss: 0.085699, avg_real_loss: 1.505310, max_real_loss: 22.719049
# (fitnessFunction pid=15031) [043/500], time: 3.596s, train_loss: 0.114821, vali_loss: 0.087565, avg_real_loss: 1.546903, max_real_loss: 20.188841
# (fitnessFunction pid=15031) [044/500], time: 3.683s, train_loss: 0.115926, vali_loss: 0.081702, avg_real_loss: 1.432835, max_real_loss: 20.704649
# (fitnessFunction pid=15031) [045/500], time: 3.444s, train_loss: 0.115880, vali_loss: 0.086810, avg_real_loss: 1.505735, max_real_loss: 21.105886
# (fitnessFunction pid=15031) [046/500], time: 3.674s, train_loss: 0.114278, vali_loss: 0.079875, avg_real_loss: 1.405936, max_real_loss: 20.813461
# (fitnessFunction pid=15031) [047/500], time: 3.478s, train_loss: 0.116308, vali_loss: 0.082578, avg_real_loss: 1.451411, max_real_loss: 20.568010
# (fitnessFunction pid=15031) [048/500], time: 3.190s, train_loss: 0.113886, vali_loss: 0.085860, avg_real_loss: 1.504897, max_real_loss: 20.796766
# (fitnessFunction pid=15031) [049/500], time: 3.241s, train_loss: 0.115833, vali_loss: 0.081973, avg_real_loss: 1.441500, max_real_loss: 22.123447
# (fitnessFunction pid=15031) [050/500], time: 3.098s, train_loss: 0.113878, vali_loss: 0.082244, avg_real_loss: 1.442134, max_real_loss: 20.811533
# (fitnessFunction pid=15031) [051/500], time: 3.217s, train_loss: 0.112072, vali_loss: 0.081791, avg_real_loss: 1.459059, max_real_loss: 20.853767
# (fitnessFunction pid=15031) [052/500], time: 3.065s, train_loss: 0.112497, vali_loss: 0.082973, avg_real_loss: 1.459924, max_real_loss: 20.694075
# (fitnessFunction pid=15031) [053/500], time: 3.247s, train_loss: 0.108523, vali_loss: 0.079414, avg_real_loss: 1.390662, max_real_loss: 21.752459
# (fitnessFunction pid=15031) [054/500], time: 3.609s, train_loss: 0.111959, vali_loss: 0.082785, avg_real_loss: 1.434159, max_real_loss: 21.150143
# (fitnessFunction pid=15031) [055/500], time: 3.388s, train_loss: 0.111202, vali_loss: 0.079849, avg_real_loss: 1.398040, max_real_loss: 20.875216
# (fitnessFunction pid=15031) [056/500], time: 3.138s, train_loss: 0.109863, vali_loss: 0.081360, avg_real_loss: 1.402640, max_real_loss: 21.007824
# (fitnessFunction pid=15031) [057/500], time: 3.246s, train_loss: 0.108359, vali_loss: 0.078097, avg_real_loss: 1.380339, max_real_loss: 21.880474
# (fitnessFunction pid=15031) [058/500], time: 3.170s, train_loss: 0.108932, vali_loss: 0.081425, avg_real_loss: 1.422538, max_real_loss: 21.413496
# (fitnessFunction pid=15031) [059/500], time: 3.353s, train_loss: 0.109192, vali_loss: 0.077254, avg_real_loss: 1.350943, max_real_loss: 21.502165
# (fitnessFunction pid=15031) [060/500], time: 3.186s, train_loss: 0.106855, vali_loss: 0.079808, avg_real_loss: 1.400443, max_real_loss: 21.888449
# (fitnessFunction pid=15031) [061/500], time: 3.162s, train_loss: 0.108502, vali_loss: 0.077790, avg_real_loss: 1.364555, max_real_loss: 21.515238
# (fitnessFunction pid=15031) [062/500], time: 3.091s, train_loss: 0.107717, vali_loss: 0.080612, avg_real_loss: 1.411023, max_real_loss: 21.940550
# (fitnessFunction pid=15031) [063/500], time: 3.163s, train_loss: 0.109882, vali_loss: 0.079969, avg_real_loss: 1.403979, max_real_loss: 21.577618
# (fitnessFunction pid=15031) [064/500], time: 3.081s, train_loss: 0.107939, vali_loss: 0.080645, avg_real_loss: 1.418895, max_real_loss: 21.369438
# (fitnessFunction pid=15031) [065/500], time: 3.157s, train_loss: 0.106646, vali_loss: 0.078977, avg_real_loss: 1.380955, max_real_loss: 20.938211
# (fitnessFunction pid=15031) [066/500], time: 3.029s, train_loss: 0.105405, vali_loss: 0.076794, avg_real_loss: 1.351028, max_real_loss: 20.540018
# (fitnessFunction pid=15031) [067/500], time: 3.159s, train_loss: 0.107348, vali_loss: 0.075345, avg_real_loss: 1.323202, max_real_loss: 21.376347
# (fitnessFunction pid=15031) [068/500], time: 3.028s, train_loss: 0.105638, vali_loss: 0.076081, avg_real_loss: 1.330179, max_real_loss: 21.355770
# (fitnessFunction pid=15031) [069/500], time: 3.122s, train_loss: 0.106851, vali_loss: 0.074342, avg_real_loss: 1.312763, max_real_loss: 21.445171
# (fitnessFunction pid=15031) [070/500], time: 3.063s, train_loss: 0.105229, vali_loss: 0.076768, avg_real_loss: 1.348664, max_real_loss: 21.901608
# (fitnessFunction pid=15031) [071/500], time: 3.103s, train_loss: 0.106100, vali_loss: 0.073195, avg_real_loss: 1.289400, max_real_loss: 21.499569
# (fitnessFunction pid=15031) [072/500], time: 3.069s, train_loss: 0.104327, vali_loss: 0.072791, avg_real_loss: 1.292831, max_real_loss: 21.098722
# (fitnessFunction pid=15031) [073/500], time: 3.260s, train_loss: 0.104173, vali_loss: 0.072802, avg_real_loss: 1.287077, max_real_loss: 21.543505
# (fitnessFunction pid=15031) [074/500], time: 3.155s, train_loss: 0.104324, vali_loss: 0.074113, avg_real_loss: 1.299799, max_real_loss: 21.796535
# (fitnessFunction pid=15031) [075/500], time: 3.400s, train_loss: 0.105744, vali_loss: 0.074994, avg_real_loss: 1.313057, max_real_loss: 21.264818
# (fitnessFunction pid=15031) [076/500], time: 3.764s, train_loss: 0.103030, vali_loss: 0.073227, avg_real_loss: 1.279290, max_real_loss: 21.200508
# (fitnessFunction pid=15031) [077/500], time: 4.231s, train_loss: 0.104355, vali_loss: 0.073745, avg_real_loss: 1.294130, max_real_loss: 21.889532
# (fitnessFunction pid=15031) [078/500], time: 3.575s, train_loss: 0.102242, vali_loss: 0.072575, avg_real_loss: 1.271094, max_real_loss: 22.383852
# (fitnessFunction pid=15031) [079/500], time: 3.237s, train_loss: 0.102956, vali_loss: 0.079059, avg_real_loss: 1.409090, max_real_loss: 21.251644
# (fitnessFunction pid=15031) [080/500], time: 3.328s, train_loss: 0.102988, vali_loss: 0.070682, avg_real_loss: 1.248232, max_real_loss: 21.389338
# (fitnessFunction pid=15031) [081/500], time: 3.146s, train_loss: 0.103326, vali_loss: 0.072605, avg_real_loss: 1.281115, max_real_loss: 21.266867
# (fitnessFunction pid=15031) [082/500], time: 3.258s, train_loss: 0.103257, vali_loss: 0.072246, avg_real_loss: 1.272941, max_real_loss: 22.272100
# (fitnessFunction pid=15031) [083/500], time: 3.542s, train_loss: 0.101105, vali_loss: 0.072158, avg_real_loss: 1.268666, max_real_loss: 21.229145
# (fitnessFunction pid=15031) [084/500], time: 3.302s, train_loss: 0.100345, vali_loss: 0.073095, avg_real_loss: 1.276567, max_real_loss: 22.032082
# (fitnessFunction pid=15031) [085/500], time: 3.130s, train_loss: 0.103079, vali_loss: 0.074239, avg_real_loss: 1.295421, max_real_loss: 22.475975
# (fitnessFunction pid=15031) [086/500], time: 3.302s, train_loss: 0.102554, vali_loss: 0.073753, avg_real_loss: 1.299715, max_real_loss: 21.371113
# (fitnessFunction pid=15031) [087/500], time: 3.102s, train_loss: 0.100620, vali_loss: 0.070064, avg_real_loss: 1.248407, max_real_loss: 21.646997
# (fitnessFunction pid=15031) [088/500], time: 3.188s, train_loss: 0.102530, vali_loss: 0.072212, avg_real_loss: 1.269733, max_real_loss: 21.289934
# (fitnessFunction pid=15031) [089/500], time: 3.145s, train_loss: 0.097632, vali_loss: 0.071146, avg_real_loss: 1.257000, max_real_loss: 21.513445
# (fitnessFunction pid=15031) [090/500], time: 3.289s, train_loss: 0.101791, vali_loss: 0.069996, avg_real_loss: 1.239435, max_real_loss: 22.192694
# (fitnessFunction pid=15031) [091/500], time: 3.209s, train_loss: 0.100550, vali_loss: 0.069506, avg_real_loss: 1.237983, max_real_loss: 22.686300
# (fitnessFunction pid=15031) [092/500], time: 3.471s, train_loss: 0.101947, vali_loss: 0.073191, avg_real_loss: 1.293342, max_real_loss: 22.701160
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 5
#       2 start_time = time.time()
#       4 # Perform the final training and evaluation using the optimal parameters
# ----> 5 min_vali, cum_proba = getFitnessValue(np.array(optvar), 9999)
#       7 # Print the time taken for the final training/evaluation
#       8 end_time = time.time()
#
# Cell In[16], line 31, in getFitnessValue(decode, thread_index)
#      28     pop_size, _ = decode.shape
#      29     results = [fitnessFunction.remote(decode[i], i) for i in range(pop_size)]
# ---> 31 fitness_values = np.array(ray.get(results))
#      32 total_fitness = np.sum(fitness_values)
#      33 probability = fitness_values / total_fitness if total_fitness != 0 else np.ones_like(fitness_values) / len(fitness_values)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/_private/worker.py:2822, in get(object_refs, timeout)
#    2816     raise ValueError(
#    2817         f"Invalid type of object refs, {type(object_refs)}, is given. "
#    2818         "'object_refs' must either be an ObjectRef or a list of ObjectRefs. "
#    2819     )
#    2821 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2822 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2823 for i, value in enumerate(values):
#    2824     if isinstance(value, RayError):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ray/_private/worker.py:904, in Worker.get_objects(self, object_refs, timeout, return_exceptions, skip_deserialization)
#     894         raise TypeError(
#     895             f"Attempting to call `get` on the value {object_ref}, "
#     896             "which is not an ray.ObjectRef."
#     897         )
#     899 timeout_ms = (
#     900     int(timeout * 1000) if timeout is not None and timeout != -1 else -1
#     901 )
#     902 data_metadata_pairs: List[
#     903     Tuple[ray._raylet.Buffer, bytes]
# --> 904 ] = self.core_worker.get_objects(
#     905     object_refs,
#     906     timeout_ms,
#     907 )
#     909 debugger_breakpoint = b""
#     910 for data, metadata in data_metadata_pairs:
#
# File python/ray/_raylet.pyx:3196, in ray._raylet.CoreWorker.get_objects()
#
# File python/ray/includes/common.pxi:83, in ray._raylet.check_status()
#
# KeyboardInterrupt:
# (fitnessFunction pid=15031) [093/500], time: 3.515s, train_loss: 0.099327, vali_loss: 0.068483, avg_real_loss: 1.216618, max_real_loss: 21.455252
# (fitnessFunction pid=15031) [094/500], time: 3.331s, train_loss: 0.103533, vali_loss: 0.072382, avg_real_loss: 1.271157, max_real_loss: 21.547058
# (fitnessFunction pid=15031) [095/500], time: 3.329s, train_loss: 0.098065, vali_loss: 0.071987, avg_real_loss: 1.278120, max_real_loss: 19.763763
# (fitnessFunction pid=15031) [096/500], time: 3.138s, train_loss: 0.099202, vali_loss: 0.069156, avg_real_loss: 1.218082, max_real_loss: 22.342499
# (fitnessFunction pid=15031) [097/500], time: 3.221s, train_loss: 0.097830, vali_loss: 0.070392, avg_real_loss: 1.239905, max_real_loss: 21.709669
# (fitnessFunction pid=15031) [098/500], time: 3.160s, train_loss: 0.098661, vali_loss: 0.071690, avg_real_loss: 1.275501, max_real_loss: 22.445839
# (fitnessFunction pid=15031) [099/500], time: 3.277s, train_loss: 0.097963, vali_loss: 0.074688, avg_real_loss: 1.315673, max_real_loss: 21.365747
# (fitnessFunction pid=15031) [100/500], time: 3.135s, train_loss: 0.100004, vali_loss: 0.071958, avg_real_loss: 1.267630, max_real_loss: 21.593493
# (fitnessFunction pid=15031) [101/500], time: 3.276s, train_loss: 0.098688, vali_loss: 0.071315, avg_real_loss: 1.251171, max_real_loss: 22.522743
# (fitnessFunction pid=15031) [102/500], time: 3.283s, train_loss: 0.099011, vali_loss: 0.068713, avg_real_loss: 1.213943, max_real_loss: 21.847044
# (fitnessFunction pid=15031) [103/500], time: 3.127s, train_loss: 0.098283, vali_loss: 0.065967, avg_real_loss: 1.166208, max_real_loss: 21.345081
# (fitnessFunction pid=15031) [104/500], time: 3.762s, train_loss: 0.098409, vali_loss: 0.067594, avg_real_loss: 1.191138, max_real_loss: 21.629654
# (fitnessFunction pid=15031) [105/500], time: 3.542s, train_loss: 0.096578, vali_loss: 0.065668, avg_real_loss: 1.170733, max_real_loss: 21.167145
# (fitnessFunction pid=15031) [106/500], time: 3.761s, train_loss: 0.100019, vali_loss: 0.072488, avg_real_loss: 1.262366, max_real_loss: 21.684942
# (fitnessFunction pid=15031) [107/500], time: 3.611s, train_loss: 0.098635, vali_loss: 0.069411, avg_real_loss: 1.220646, max_real_loss: 22.057871
# (fitnessFunction pid=15031) [108/500], time: 3.291s, train_loss: 0.098322, vali_loss: 0.069970, avg_real_loss: 1.253941, max_real_loss: 20.926153
# (fitnessFunction pid=15031) [109/500], time: 3.377s, train_loss: 0.098914, vali_loss: 0.070475, avg_real_loss: 1.247531, max_real_loss: 21.516523
# (fitnessFunction pid=15031) [110/500], time: 3.282s, train_loss: 0.098504, vali_loss: 0.067212, avg_real_loss: 1.197663, max_real_loss: 21.572876
# (fitnessFunction pid=15031) [111/500], time: 3.122s, train_loss: 0.097232, vali_loss: 0.070392, avg_real_loss: 1.233997, max_real_loss: 22.865070
# (fitnessFunction pid=15031) [112/500], time: 3.255s, train_loss: 0.097881, vali_loss: 0.065103, avg_real_loss: 1.161955, max_real_loss: 21.997778
# (fitnessFunction pid=15031) [113/500], time: 3.130s, train_loss: 0.096090, vali_loss: 0.068213, avg_real_loss: 1.204799, max_real_loss: 21.498421
# (fitnessFunction pid=15031) [114/500], time: 3.274s, train_loss: 0.096199, vali_loss: 0.068361, avg_real_loss: 1.211294, max_real_loss: 22.256647
# (fitnessFunction pid=15031) [115/500], time: 3.081s, train_loss: 0.096180, vali_loss: 0.065878, avg_real_loss: 1.164333, max_real_loss: 22.542786
# (fitnessFunction pid=15031) [116/500], time: 3.222s, train_loss: 0.095644, vali_loss: 0.066196, avg_real_loss: 1.180033, max_real_loss: 21.085350
# (fitnessFunction pid=15031) [117/500], time: 3.149s, train_loss: 0.095172, vali_loss: 0.068835, avg_real_loss: 1.203754, max_real_loss: 22.431126
# (fitnessFunction pid=15031) [118/500], time: 3.244s, train_loss: 0.098185, vali_loss: 0.066215, avg_real_loss: 1.210516, max_real_loss: 20.807304
# (fitnessFunction pid=15031) [119/500], time: 3.110s, train_loss: 0.097160, vali_loss: 0.065734, avg_real_loss: 1.171295, max_real_loss: 21.448103
# (fitnessFunction pid=15031) [120/500], time: 3.582s, train_loss: 0.096583, vali_loss: 0.065578, avg_real_loss: 1.192992, max_real_loss: 21.329624
# (fitnessFunction pid=15031) [121/500], time: 3.333s, train_loss: 0.094730, vali_loss: 0.071177, avg_real_loss: 1.243692, max_real_loss: 22.046038
# (fitnessFunction pid=15031) [122/500], time: 3.217s, train_loss: 0.096287, vali_loss: 0.071932, avg_real_loss: 1.294754, max_real_loss: 22.413019
# (fitnessFunction pid=15031) [123/500], time: 3.164s, train_loss: 0.094018, vali_loss: 0.066097, avg_real_loss: 1.186485, max_real_loss: 22.013054
# (fitnessFunction pid=15031) [124/500], time: 3.216s, train_loss: 0.093875, vali_loss: 0.065915, avg_real_loss: 1.166251, max_real_loss: 21.896124
# (fitnessFunction pid=15031) [125/500], time: 3.106s, train_loss: 0.092631, vali_loss: 0.066128, avg_real_loss: 1.172481, max_real_loss: 21.535631
# (fitnessFunction pid=15031) [126/500], time: 3.238s, train_loss: 0.094239, vali_loss: 0.068965, avg_real_loss: 1.209454, max_real_loss: 22.255657
# (fitnessFunction pid=15031) [127/500], time: 3.133s, train_loss: 0.097183, vali_loss: 0.070004, avg_real_loss: 1.233761, max_real_loss: 23.036963
# (fitnessFunction pid=15031) [128/500], time: 3.289s, train_loss: 0.095636, vali_loss: 0.068727, avg_real_loss: 1.217420, max_real_loss: 22.151199
# (fitnessFunction pid=15031) [129/500], time: 3.102s, train_loss: 0.094843, vali_loss: 0.066192, avg_real_loss: 1.174119, max_real_loss: 22.365055
# (fitnessFunction pid=15031) [130/500], time: 3.048s, train_loss: 0.095027, vali_loss: 0.068474, avg_real_loss: 1.235223, max_real_loss: 21.746119
# (fitnessFunction pid=15031) [131/500], time: 3.222s, train_loss: 0.096602, vali_loss: 0.066730, avg_real_loss: 1.168859, max_real_loss: 21.217312
# (fitnessFunction pid=15031) [132/500], time: 3.048s, train_loss: 0.095820, vali_loss: 0.065409, avg_real_loss: 1.159426, max_real_loss: 21.630209
# (fitnessFunction pid=15031) [133/500], time: 3.270s, train_loss: 0.094186, vali_loss: 0.068689, avg_real_loss: 1.210531, max_real_loss: 22.548658
# (fitnessFunction pid=15031) [134/500], time: 3.207s, train_loss: 0.092789, vali_loss: 0.069029, avg_real_loss: 1.223941, max_real_loss: 21.520300
# (fitnessFunction pid=15031) [135/500], time: 3.063s, train_loss: 0.093308, vali_loss: 0.071863, avg_real_loss: 1.280922, max_real_loss: 20.295992
# (fitnessFunction pid=15031) [136/500], time: 3.309s, train_loss: 0.093469, vali_loss: 0.064713, avg_real_loss: 1.149293, max_real_loss: 21.414312
# (fitnessFunction pid=15031) [137/500], time: 3.096s, train_loss: 0.095844, vali_loss: 0.065315, avg_real_loss: 1.163902, max_real_loss: 21.761961
# (fitnessFunction pid=15031) [138/500], time: 3.049s, train_loss: 0.094679, vali_loss: 0.065126, avg_real_loss: 1.145028, max_real_loss: 22.009277
# (fitnessFunction pid=15031) [139/500], time: 3.238s, train_loss: 0.093995, vali_loss: 0.065397, avg_real_loss: 1.165174, max_real_loss: 21.091982
# (fitnessFunction pid=15031) [140/500], time: 3.208s, train_loss: 0.095799, vali_loss: 0.065361, avg_real_loss: 1.154140, max_real_loss: 20.885847
# (fitnessFunction pid=15031) [141/500], time: 3.078s, train_loss: 0.093073, vali_loss: 0.066259, avg_real_loss: 1.171179, max_real_loss: 21.880625
# (fitnessFunction pid=15031) [142/500], time: 3.209s, train_loss: 0.092831, vali_loss: 0.064766, avg_real_loss: 1.146626, max_real_loss: 21.775091
# (fitnessFunction pid=15031) [143/500], time: 3.105s, train_loss: 0.094121, vali_loss: 0.064490, avg_real_loss: 1.146984, max_real_loss: 21.395151
# (fitnessFunction pid=15031) [144/500], time: 3.242s, train_loss: 0.093090, vali_loss: 0.062788, avg_real_loss: 1.119340, max_real_loss: 21.083426
# (fitnessFunction pid=15031) [145/500], time: 3.547s, train_loss: 0.093570, vali_loss: 0.065450, avg_real_loss: 1.160191, max_real_loss: 21.612959
# (fitnessFunction pid=15031) [146/500], time: 3.172s, train_loss: 0.092418, vali_loss: 0.065839, avg_real_loss: 1.167825, max_real_loss: 21.943224
# (fitnessFunction pid=15031) [147/500], time: 3.120s, train_loss: 0.089713, vali_loss: 0.064144, avg_real_loss: 1.147899, max_real_loss: 20.946632
# (fitnessFunction pid=15031) [148/500], time: 3.236s, train_loss: 0.090547, vali_loss: 0.066789, avg_real_loss: 1.202873, max_real_loss: 21.365959
# (fitnessFunction pid=15031) [149/500], time: 3.315s, train_loss: 0.090885, vali_loss: 0.062588, avg_real_loss: 1.115304, max_real_loss: 21.308840
# (fitnessFunction pid=15031) [150/500], time: 3.711s, train_loss: 0.094023, vali_loss: 0.066055, avg_real_loss: 1.155817, max_real_loss: 21.945303
# (fitnessFunction pid=15031) [151/500], time: 3.085s, train_loss: 0.092073, vali_loss: 0.065366, avg_real_loss: 1.142172, max_real_loss: 22.319424
# (fitnessFunction pid=15031) [152/500], time: 3.307s, train_loss: 0.093978, vali_loss: 0.064881, avg_real_loss: 1.141628, max_real_loss: 22.169451
# (fitnessFunction pid=15031) [153/500], time: 3.154s, train_loss: 0.093255, vali_loss: 0.064761, avg_real_loss: 1.138117, max_real_loss: 21.272655
# (fitnessFunction pid=15031) [154/500], time: 3.294s, train_loss: 0.090757, vali_loss: 0.064562, avg_real_loss: 1.147303, max_real_loss: 21.589014
# (fitnessFunction pid=15031) [155/500], time: 3.232s, train_loss: 0.091666, vali_loss: 0.064845, avg_real_loss: 1.135580, max_real_loss: 21.177624
# (fitnessFunction pid=15031) [156/500], time: 3.324s, train_loss: 0.090987, vali_loss: 0.062448, avg_real_loss: 1.112644, max_real_loss: 21.872921
# (fitnessFunction pid=15031) [157/500], time: 3.272s, train_loss: 0.090906, vali_loss: 0.063660, avg_real_loss: 1.150432, max_real_loss: 20.968439
# (fitnessFunction pid=15031) [158/500], time: 3.614s, train_loss: 0.092106, vali_loss: 0.064652, avg_real_loss: 1.150952, max_real_loss: 21.125120
# (fitnessFunction pid=15031) [159/500], time: 3.220s, train_loss: 0.092965, vali_loss: 0.064880, avg_real_loss: 1.155014, max_real_loss: 22.042603
# (fitnessFunction pid=15031) [160/500], time: 3.284s, train_loss: 0.091113, vali_loss: 0.063451, avg_real_loss: 1.118774, max_real_loss: 21.162598
# (fitnessFunction pid=15031) [161/500], time: 3.086s, train_loss: 0.090868, vali_loss: 0.065276, avg_real_loss: 1.173070, max_real_loss: 21.043104
# (fitnessFunction pid=15031) [162/500], time: 3.339s, train_loss: 0.090321, vali_loss: 0.063132, avg_real_loss: 1.122255, max_real_loss: 21.325085
# (fitnessFunction pid=15031) [163/500], time: 3.239s, train_loss: 0.092299, vali_loss: 0.062457, avg_real_loss: 1.114451, max_real_loss: 21.165321
# (fitnessFunction pid=15031) [164/500], time: 3.130s, train_loss: 0.091384, vali_loss: 0.066252, avg_real_loss: 1.164574, max_real_loss: 22.197710
# (fitnessFunction pid=15031) [165/500], time: 3.161s, train_loss: 0.091505, vali_loss: 0.063126, avg_real_loss: 1.134863, max_real_loss: 21.338911
# (fitnessFunction pid=15031) [166/500], time: 3.231s, train_loss: 0.089282, vali_loss: 0.064623, avg_real_loss: 1.150545, max_real_loss: 21.880625
# (fitnessFunction pid=15031) [167/500], time: 3.075s, train_loss: 0.089845, vali_loss: 0.063519, avg_real_loss: 1.120321, max_real_loss: 21.155453
# (fitnessFunction pid=15031) [168/500], time: 3.338s, train_loss: 0.091417, vali_loss: 0.065871, avg_real_loss: 1.169454, max_real_loss: 21.715065
# (fitnessFunction pid=15031) [169/500], time: 3.040s, train_loss: 0.091983, vali_loss: 0.065958, avg_real_loss: 1.157050, max_real_loss: 22.491474
# (fitnessFunction pid=15031) [170/500], time: 3.231s, train_loss: 0.089397, vali_loss: 0.064338, avg_real_loss: 1.159411, max_real_loss: 20.767752
# (fitnessFunction pid=15031) [171/500], time: 3.219s, train_loss: 0.089331, vali_loss: 0.064093, avg_real_loss: 1.136192, max_real_loss: 21.012775
# (fitnessFunction pid=15031) [172/500], time: 3.091s, train_loss: 0.088108, vali_loss: 0.067109, avg_real_loss: 1.206451, max_real_loss: 21.307785
# (fitnessFunction pid=15031) [173/500], time: 3.242s, train_loss: 0.089843, vali_loss: 0.062348, avg_real_loss: 1.095166, max_real_loss: 21.811037
# (fitnessFunction pid=15031) [174/500], time: 3.087s, train_loss: 0.090036, vali_loss: 0.062749, avg_real_loss: 1.107319, max_real_loss: 22.231041
# (fitnessFunction pid=15031) [175/500], time: 3.112s, train_loss: 0.090927, vali_loss: 0.064981, avg_real_loss: 1.139607, max_real_loss: 21.778738
# (fitnessFunction pid=15031) [176/500], time: 3.290s, train_loss: 0.086926, vali_loss: 0.063123, avg_real_loss: 1.113199, max_real_loss: 20.951582
# (fitnessFunction pid=15031) [177/500], time: 3.084s, train_loss: 0.089518, vali_loss: 0.068508, avg_real_loss: 1.238594, max_real_loss: 20.848936
# (fitnessFunction pid=15031) [178/500], time: 3.306s, train_loss: 0.088974, vali_loss: 0.067345, avg_real_loss: 1.213249, max_real_loss: 21.381388
# (fitnessFunction pid=15031) [179/500], time: 3.090s, train_loss: 0.089817, vali_loss: 0.063751, avg_real_loss: 1.116192, max_real_loss: 21.784870
# (fitnessFunction pid=15031) [180/500], time: 3.227s, train_loss: 0.089964, vali_loss: 0.065219, avg_real_loss: 1.164193, max_real_loss: 20.805300
# (fitnessFunction pid=15031) [181/500], time: 3.249s, train_loss: 0.088633, vali_loss: 0.063179, avg_real_loss: 1.117922, max_real_loss: 21.414518
# (fitnessFunction pid=15031) [182/500], time: 3.092s, train_loss: 0.086571, vali_loss: 0.062159, avg_real_loss: 1.087003, max_real_loss: 20.848072
# (fitnessFunction pid=15031) [183/500], time: 3.057s, train_loss: 0.090083, vali_loss: 0.063657, avg_real_loss: 1.113561, max_real_loss: 21.746439
# (fitnessFunction pid=15031) [184/500], time: 3.322s, train_loss: 0.086951, vali_loss: 0.064754, avg_real_loss: 1.153801, max_real_loss: 20.988857
# (fitnessFunction pid=15031) [185/500], time: 3.090s, train_loss: 0.088028, vali_loss: 0.065165, avg_real_loss: 1.135054, max_real_loss: 21.488905
# (fitnessFunction pid=15031) [186/500], time: 3.250s, train_loss: 0.089617, vali_loss: 0.062065, avg_real_loss: 1.091086, max_real_loss: 21.448505
# (fitnessFunction pid=15031) [187/500], time: 3.131s, train_loss: 0.088720, vali_loss: 0.068730, avg_real_loss: 1.191539, max_real_loss: 21.199469
# (fitnessFunction pid=15031) [188/500], time: 3.371s, train_loss: 0.087766, vali_loss: 0.063244, avg_real_loss: 1.095049, max_real_loss: 21.868031
# (fitnessFunction pid=15031) [189/500], time: 3.113s, train_loss: 0.088933, vali_loss: 0.063585, avg_real_loss: 1.105151, max_real_loss: 21.709553
# (fitnessFunction pid=15031) [190/500], time: 3.233s, train_loss: 0.091616, vali_loss: 0.062416, avg_real_loss: 1.102371, max_real_loss: 20.556082
# (fitnessFunction pid=15031) [191/500], time: 3.242s, train_loss: 0.089498, vali_loss: 0.063272, avg_real_loss: 1.108126, max_real_loss: 21.180836
# (fitnessFunction pid=15031) [192/500], time: 3.125s, train_loss: 0.087097, vali_loss: 0.063206, avg_real_loss: 1.099824, max_real_loss: 21.727131
# (fitnessFunction pid=15031) [193/500], time: 3.216s, train_loss: 0.086644, vali_loss: 0.064036, avg_real_loss: 1.120988, max_real_loss: 22.056089
# (fitnessFunction pid=15031) [194/500], time: 3.136s, train_loss: 0.088016, vali_loss: 0.062415, avg_real_loss: 1.089694, max_real_loss: 21.507271
# (fitnessFunction pid=15031) [195/500], time: 3.176s, train_loss: 0.085913, vali_loss: 0.064932, avg_real_loss: 1.150736, max_real_loss: 20.366947
# (fitnessFunction pid=15031) [196/500], time: 3.595s, train_loss: 0.087953, vali_loss: 0.064467, avg_real_loss: 1.132890, max_real_loss: 22.035492
# (fitnessFunction pid=15031) [197/500], time: 3.176s, train_loss: 0.086446, vali_loss: 0.065613, avg_real_loss: 1.162662, max_real_loss: 21.489809
# (fitnessFunction pid=15031) [198/500], time: 3.249s, train_loss: 0.088496, vali_loss: 0.063783, avg_real_loss: 1.123376, max_real_loss: 21.379757
# (fitnessFunction pid=15031) [199/500], time: 3.097s, train_loss: 0.087923, vali_loss: 0.066755, avg_real_loss: 1.176975, max_real_loss: 19.756365
# (fitnessFunction pid=15031) [200/500], time: 3.244s, train_loss: 0.087688, vali_loss: 0.064666, avg_real_loss: 1.131258, max_real_loss: 21.391523
# (fitnessFunction pid=15031) [201/500], time: 3.152s, train_loss: 0.086122, vali_loss: 0.063338, avg_real_loss: 1.094757, max_real_loss: 21.501909
# (fitnessFunction pid=15031) [202/500], time: 3.263s, train_loss: 0.088057, vali_loss: 0.062160, avg_real_loss: 1.093297, max_real_loss: 21.120541
# (fitnessFunction pid=15031) [203/500], time: 3.147s, train_loss: 0.085803, vali_loss: 0.060873, avg_real_loss: 1.071984, max_real_loss: 20.563244
# (fitnessFunction pid=15031) [204/500], time: 3.284s, train_loss: 0.085920, vali_loss: 0.062262, avg_real_loss: 1.105607, max_real_loss: 21.096073
# (fitnessFunction pid=15031) [205/500], time: 3.055s, train_loss: 0.084748, vali_loss: 0.064632, avg_real_loss: 1.118858, max_real_loss: 21.874687
# (fitnessFunction pid=15031) [206/500], time: 3.228s, train_loss: 0.087769, vali_loss: 0.064016, avg_real_loss: 1.109848, max_real_loss: 22.221655
# (fitnessFunction pid=15031) [207/500], time: 3.104s, train_loss: 0.086422, vali_loss: 0.063753, avg_real_loss: 1.098838, max_real_loss: 22.219229
# (fitnessFunction pid=15031) [208/500], time: 3.195s, train_loss: 0.086861, vali_loss: 0.062517, avg_real_loss: 1.082780, max_real_loss: 21.419001
# (fitnessFunction pid=15031) [209/500], time: 3.793s, train_loss: 0.087587, vali_loss: 0.062577, avg_real_loss: 1.096694, max_real_loss: 20.298923
# (fitnessFunction pid=15031) [210/500], time: 3.717s, train_loss: 0.086587, vali_loss: 0.060384, avg_real_loss: 1.081110, max_real_loss: 20.608381
# (fitnessFunction pid=15031) [211/500], time: 3.632s, train_loss: 0.084915, vali_loss: 0.063164, avg_real_loss: 1.102448, max_real_loss: 21.380066

# %%
if os.path.exists('./predict/predict1'):
    shutil.rmtree('./predict/predict1')
    shutil.rmtree('./predict')
os.mkdir('./predict')
os.mkdir('./predict/predict1')
os.system('cp model/model_9999/model.pkl temp_files/')
os.system('cd temp_files; cp normal_para.txt normal_para_predict.txt')
os.system('cp temp_files/* ./predict/predict1')

predict_model('./predict/predict1/predictset_with_scaled_normalized.txt',nfeatures)

result_conn() 
RMSE_calu()

result_conn2() 
RMSE_calu2()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 if os.path.exists('./predict/predict1'):
#       2     shutil.rmtree('./predict/predict1')
#       3     shutil.rmtree('./predict')
#
# NameError: name 'os' is not defined

# %% [markdown]
# ## Numerical Simulation with Pyscf
# Here we perform a numerical simulation using the `pyscf` library to compute the energy of a crystal structure. This is done to validate the performance of the neural network model.
# We will focus on the Si crystal structure.

# %%
import ase.io
from ase.visualize.plot import plot_atoms
import matplotlib.pyplot as plt
import random


# Randomly take a .xsf from the test dataset
file_to_read = './data/Si/raw_data/test'
file_to_read = '/Users/matteobalice/Desktop/swarm_intelligence/data/Si/raw_data/test/structure100024027113.xsf'#os.path.join(file_to_read, random.choice(os.listdir(file_to_read)))
print(f"Reading structure from: {file_to_read}")
ase_atom = ase.io.read(file_to_read)

fig, ax = plt.subplots()
plot_atoms(ase_atom, ax, radii=0.5, rotation=('45x,45y,0z'))
plt.title(f"Structure from {file_to_read}")
plt.show()
# Out:
# Reading structure from: /Users/matteobalice/Desktop/swarm_intelligence/data/Si/raw_data/test/structure100024027113.xsf

# %% [markdown]
# ## Periodic Boundary Conditions (PBC)
#
# In quantum chemistry and condensed matter physics, periodic boundary conditions are used to model infinite crystalline solids. The periodicity of the potential and electronic density in such systems reflects the translational symmetry of the crystal lattice. Each unit cell is repeated in all directions to mimic the behavior of a bulk material.
#
# ## Density Functional Theory (DFT)
#
# DFT is a widely used method for computing the electronic structure of many-body systems. It reformulates the many-electron problem in terms of the electron density, rather than the many-body wavefunction. The Kohn-Sham formulation introduces a set of non-interacting particles that reproduce the true density of the interacting system.
#
# ## Density Fitting
#
# To accelerate the calculation of two-electron integrals, especially in periodic systems, density fitting techniques are employed. These approximate the electron repulsion integrals using an auxiliary basis, such as a plane-wave basis, and reduce the computational scaling.
# DFT calculations are carried out iteratively through a self-consistent field procedure. At each step, the electron density is updated based on the solution of the Kohn-Sham equations, and the process continues until convergence is achieved. The result is a total energy that includes kinetic, Coulomb, exchange-correlation, and pseudopotential contributions.

# %%
from pyscf.pbc import gto, dft, df

now = time.time()

cell = gto.Cell()
cell.a = ase_atom.cell
cell.atom = list(zip(ase_atom.get_chemical_symbols(), ase_atom.get_positions()))
cell.basis = 'gth-dzvp'
cell.pseudo = 'gth-pbe'
cell.unit = 'A'
cell.exp_to_discard=0.1
cell.build()

kmesh = [4,4,4]
kpts = cell.make_kpts(kmesh)

mf = dft.KRKS(cell, kpts=kpts)
mf.with_df = df.FFTDF(cell)
mf.xc = 'pbe'
mf.conv_tol = 1e-8
mf.run()

n_atoms = len(ase_atom)
e_per_atom = mf.e_tot / n_atoms

time_pyscf = time.time() - now

print(f"Calculation time: {time_pyscf:.2f} seconds")
print(f"Total energy: {mf.e_tot:.2f} eV")
print(f"Energy per atom: {e_per_atom:.2f} eV/atom")
# Out:
# ---------------------------------------------------------------------------
# BasisNotFoundError                        Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyscf/gto/basis/__init__.py:758, in _load_external(module, filename_or_basisname, symb, **kwargs)
#     757 try:
# --> 758     return module.load(filename_or_basisname, symb, **kwargs)
#     759 except BasisNotFoundError:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyscf/gto/basis/parse_cp2k_pp.py:63, in load(pseudofile, symb, suffix)
#      60 '''Parse the *pseudofile's entry* for atom 'symb', return an internal
#      61 pseudo format which can be assigned to :attr:`Cell.pseudo`
#      62 '''
# ---> 63 return _parse(search_seg(pseudofile, symb, suffix))
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyscf/gto/basis/parse_cp2k_pp.py:107, in search_seg(pseudofile, symb, suffix)
#     106 if not dat:
# --> 107     raise BasisNotFoundError(f'Pseudopotential for {symb} in {pseudofile}')
#     108 return dat
#
# BasisNotFoundError: Pseudopotential for Si in /Users/matteobalice/qe/pseudos/Si.UPF
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 12
#      10 cell.unit = 'A'
#      11 cell.exp_to_discard=0.1
# ---> 12 cell.build()
#      14 # Aggiungi campionamento k-points equivalente a QE
#      15 kmesh = [4,4,4]  # Deve corrispondere a quello usato in QE
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyscf/pbc/gto/cell.py:1520, in Cell.build(self, dump_input, parse_arg, a, mesh, ke_cutoff, precision, nimgs, h, dimension, rcut, low_dim_ft_type, space_group_symmetry, symmorphic, use_loose_rcut, use_particle_mesh_ewald, fractional, *args, **kwargs)
#    1517     raise RuntimeError('Lattice parameters not specified')
#    1519 _built = self._built
# -> 1520 mole.MoleBase.build(self, False, parse_arg, *args, **kwargs)
#    1522 exp_min = np.array([self.bas_exp(ib).min() for ib in range(self.nbas)])
#    1523 if self.exp_to_discard is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyscf/gto/mole.py:2575, in MoleBase.build(self, dump_input, parse_arg, verbose, output, max_memory, atom, basis, unit, nucmod, ecp, pseudo, charge, spin, symmetry, symmetry_subgroup, cart, magmom)
#    2573 atoms_wo_ghost = [a for a in uniq_atoms if not is_ghost_atom(a)]
#    2574 _pseudo = _parse_default_basis(self.pseudo, atoms_wo_ghost)
# -> 2575 self._pseudo = _pseudo = self.format_pseudo(_pseudo)
#    2576 if _pseudo:
#    2577     conflicts = set(_pseudo).intersection(self._ecp)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyscf/gto/mole.py:765, in format_pseudo(pseudo_tab)
#     763 if isinstance(atom_pp, str):
#     764     stdsymb = _std_symbol_without_ghost(symb)
# --> 765     fmt_pseudo[symb] = load(atom_pp, stdsymb)
#     766 else:
#     767     fmt_pseudo[symb] = atom_pp
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyscf/gto/basis/__init__.py:741, in load_pseudo(filename_or_basisname, symb)
#     739 symb = ''.join([i for i in symb if i.isalpha()])
#     740 if os.path.isfile(filename_or_basisname):
# --> 741     return _load_external(parse_cp2k_pp, filename_or_basisname, symb)
#     743 name, suffix = _format_pseudo_name(filename_or_basisname)
#     744 if name in PP_ALIAS:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyscf/gto/basis/__init__.py:761, in _load_external(module, filename_or_basisname, symb, **kwargs)
#     759 except BasisNotFoundError:
#     760     with open(filename_or_basisname, 'r') as fin:
# --> 761         return module.parse(fin.read(), **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyscf/gto/basis/parse_cp2k_pp.py:57, in parse(string, symb)
#      54 else:
#      55     pseudotxt = [x.strip() for x in string.splitlines()
#      56                  if x.strip() and 'END' not in x and '#PSEUDOPOTENTIAL' not in x]
# ---> 57 return _parse(pseudotxt)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyscf/gto/basis/parse_cp2k_pp.py:67, in _parse(plines)
#      65 def _parse(plines):
#      66     header_ln = plines.pop(0)  # noqa: F841
# ---> 67     nelecs = [ int(nelec) for nelec in plines.pop(0).split() ]
#      68     rnc_ppl = plines.pop(0).split()
#      69     rloc = float(rnc_ppl[0])
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyscf/gto/basis/parse_cp2k_pp.py:67, in <listcomp>(.0)
#      65 def _parse(plines):
#      66     header_ln = plines.pop(0)  # noqa: F841
# ---> 67     nelecs = [ int(nelec) for nelec in plines.pop(0).split() ]
#      68     rnc_ppl = plines.pop(0).split()
#      69     rloc = float(rnc_ppl[0])
#
# ValueError: invalid literal for int() with base 10: '<PP_INFO>'
